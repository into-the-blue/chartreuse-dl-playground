# %%
 from transformers import Wav2Vec2Tokenizer, Wav2Vec2ForCTC
 from datasets import load_dataset
 import soundfile as sf
 import torch
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-56511cfe0754> in <module>
#       1 from transformers import Wav2Vec2Tokenizer, Wav2Vec2ForCTC
# ----> 2 from datasets import load_dataset
#       3 import soundfile as sf
#       4 import torch
#
# ModuleNotFoundError: No module named 'datasets'

# %%
# !pip install asrecognition
# Out:
# Collecting asrecognition
#   Downloading ASRecognition-0.0.2-py3-none-any.whl (5.2 kB)
# Collecting torch<2.0.0,>=1.9.0
#   Downloading torch-1.9.0-cp38-cp38-manylinux1_x86_64.whl (831.4 MB)
#      |███████████████████████████     | 699.0 MB 90.0 MB/s eta 0:00:02
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      |█████████████████████████████▏  | 756.4 MB 90.0 MB/s eta 0:00:01
#      |█████████████████████████████▎  | 760.5 MB 90.0 MB/s eta 0:00:01
#      |█████████████████████████████▍  | 764.6 MB 90.0 MB/s eta 0:00:01
#      |█████████████████████████████▋  | 768.7 MB 90.0 MB/s eta 0:00:01
#      |█████████████████████████████▊  | 772.8 MB 90.0 MB/s eta 0:00:01
#      |██████████████████████████████  | 776.9 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████  | 781.0 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████▏ | 785.2 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████▍ | 789.2 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████▌ | 793.4 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████▊ | 797.4 MB 80.9 MB/s eta 0:00:01
#      |██████████████████████████████▉ | 801.5 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████ | 805.5 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████▏| 809.7 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████▎| 813.8 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████▌| 817.9 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████▋| 822.0 MB 80.9 MB/s eta 0:00:01
#      |███████████████████████████████▉| 826.0 MB 80.9 MB/s eta 0:00:01
#      |████████████████████████████████| 830.1 MB 80.9 MB/s eta 0:00:01
#      |████████████████████████████████| 831.4 MB 80.9 MB/s eta 0:00:01
#      |████████████████████████████████| 831.4 MB 14 kB/s
# Collecting librosa<0.9.0,>=0.8.1
#   Downloading librosa-0.8.1-py3-none-any.whl (203 kB)
#      |████████████████████████████████| 203 kB 74.8 MB/s eta 0:00:01
# Collecting datasets<2.0.0,>=1.10.2
#   Downloading datasets-1.10.2-py3-none-any.whl (542 kB)
#      |████████████████████████████████| 542 kB 52.0 MB/s eta 0:00:01
# Collecting transformers<5.0.0,>=4.9.1
#   Downloading transformers-4.9.1-py3-none-any.whl (2.6 MB)
#      |████████████████████████████████| 2.6 MB 72.3 MB/s eta 0:00:01
# Collecting numba<0.54.0,>=0.53.1
#   Downloading numba-0.53.1-cp38-cp38-manylinux2014_x86_64.whl (3.4 MB)
#      |████████████████████████████████| 3.4 MB 74.2 MB/s eta 0:00:01
# Collecting llvmlite<0.37.0,>=0.36.0
#   Downloading llvmlite-0.36.0-cp38-cp38-manylinux2010_x86_64.whl (25.3 MB)
#      |████████████████████████████████| 25.3 MB 75.5 MB/s eta 0:00:01
# Requirement already satisfied: typing-extensions in /root/miniconda3/lib/python3.8/site-packages (from torch<2.0.0,>=1.9.0->asrecognition) (3.7.4.3)
# Requirement already satisfied: numpy>=1.15.0 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (1.19.2)
# Requirement already satisfied: scikit-learn!=0.19.0,>=0.14.0 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (0.24.1)
# Collecting audioread>=2.0.0
#   Downloading audioread-2.1.9.tar.gz (377 kB)
#      |████████████████████████████████| 377 kB 71.1 MB/s eta 0:00:01
# Requirement already satisfied: decorator>=3.0.0 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (5.0.6)
# Requirement already satisfied: packaging>=20.0 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (20.9)
# Collecting soundfile>=0.10.2
#   Downloading SoundFile-0.10.3.post1-py2.py3-none-any.whl (21 kB)
# Collecting pooch>=1.0
#   Downloading pooch-1.4.0-py3-none-any.whl (51 kB)
#      |████████████████████████████████| 51 kB 909 kB/s  eta 0:00:01
# Collecting resampy>=0.2.2
#   Downloading resampy-0.2.2.tar.gz (323 kB)
#      |████████████████████████████████| 323 kB 70.0 MB/s eta 0:00:01
# Requirement already satisfied: joblib>=0.14 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (1.0.1)
# Requirement already satisfied: scipy>=1.0.0 in /root/miniconda3/lib/python3.8/site-packages (from librosa<0.9.0,>=0.8.1->asrecognition) (1.6.1)
# Requirement already satisfied: requests>=2.19.0 in /root/miniconda3/lib/python3.8/site-packages (from datasets<2.0.0,>=1.10.2->asrecognition) (2.24.0)
# Collecting xxhash
#   Downloading xxhash-2.0.2-cp38-cp38-manylinux2010_x86_64.whl (243 kB)
#      |████████████████████████████████| 243 kB 73.2 MB/s eta 0:00:01
# Requirement already satisfied: pandas in /root/miniconda3/lib/python3.8/site-packages (from datasets<2.0.0,>=1.10.2->asrecognition) (1.2.3)
# Collecting huggingface-hub<0.1.0
#   Downloading huggingface_hub-0.0.15-py3-none-any.whl (43 kB)
#      |████████████████████████████████| 43 kB 3.1 MB/s  eta 0:00:01
# Requirement already satisfied: tqdm>=4.42 in /root/miniconda3/lib/python3.8/site-packages (from datasets<2.0.0,>=1.10.2->asrecognition) (4.51.0)
# Collecting multiprocess
#   Downloading multiprocess-0.70.12.2-py38-none-any.whl (128 kB)
#      |████████████████████████████████| 128 kB 71.4 MB/s eta 0:00:01
# Collecting fsspec>=2021.05.0
#   Downloading fsspec-2021.7.0-py3-none-any.whl (118 kB)
#      |████████████████████████████████| 118 kB 70.9 MB/s eta 0:00:01
# Collecting dill
#   Downloading dill-0.3.4-py2.py3-none-any.whl (86 kB)
#      |████████████████████████████████| 86 kB 9.3 MB/s  eta 0:00:01
# Collecting pyarrow!=4.0.0,>=1.0.0
#   Downloading pyarrow-5.0.0-cp38-cp38-manylinux2014_x86_64.whl (23.6 MB)
#      |████████████████████████████████| 23.6 MB 70.8 MB/s eta 0:00:01
# Requirement already satisfied: sacremoses in /root/miniconda3/lib/python3.8/site-packages/sacremoses-0.0.43-py3.8.egg (from transformers<5.0.0,>=4.9.1->asrecognition) (0.0.43)
# Requirement already satisfied: regex!=2019.12.17 in /root/miniconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.9.1->asrecognition) (2020.11.13)
# Requirement already satisfied: tokenizers<0.11,>=0.10.1 in /root/miniconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.9.1->asrecognition) (0.10.1)
# Requirement already satisfied: pyyaml>=5.1 in /root/miniconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.9.1->asrecognition) (5.4.1)
# Requirement already satisfied: filelock in /root/miniconda3/lib/python3.8/site-packages (from transformers<5.0.0,>=4.9.1->asrecognition) (3.0.12)
# Requirement already satisfied: setuptools in /root/miniconda3/lib/python3.8/site-packages (from numba<0.54.0,>=0.53.1->asrecognition) (50.3.1.post20201107)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /root/miniconda3/lib/python3.8/site-packages (from scikit-learn!=0.19.0,>=0.14.0->librosa<0.9.0,>=0.8.1->asrecognition) (2.1.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /root/miniconda3/lib/python3.8/site-packages (from packaging>=20.0->librosa<0.9.0,>=0.8.1->asrecognition) (2.4.7)
# Requirement already satisfied: cffi>=1.0 in /root/miniconda3/lib/python3.8/site-packages (from soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->asrecognition) (1.14.0)
# Collecting appdirs
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Requirement already satisfied: six>=1.3 in /root/miniconda3/lib/python3.8/site-packages (from resampy>=0.2.2->librosa<0.9.0,>=0.8.1->asrecognition) (1.15.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /root/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.10.2->asrecognition) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /root/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.10.2->asrecognition) (2.10)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /root/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.10.2->asrecognition) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in /root/miniconda3/lib/python3.8/site-packages (from requests>=2.19.0->datasets<2.0.0,>=1.10.2->asrecognition) (2020.12.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /root/miniconda3/lib/python3.8/site-packages (from pandas->datasets<2.0.0,>=1.10.2->asrecognition) (2.8.1)
# Requirement already satisfied: pytz>=2017.3 in /root/miniconda3/lib/python3.8/site-packages (from pandas->datasets<2.0.0,>=1.10.2->asrecognition) (2021.1)
# Requirement already satisfied: click in /root/miniconda3/lib/python3.8/site-packages (from sacremoses->transformers<5.0.0,>=4.9.1->asrecognition) (7.1.2)
# Requirement already satisfied: pycparser in /root/miniconda3/lib/python3.8/site-packages (from cffi>=1.0->soundfile>=0.10.2->librosa<0.9.0,>=0.8.1->asrecognition) (2.20)
# Building wheels for collected packages: audioread, resampy
#   Building wheel for audioread (setup.py) ... done
#   Created wheel for audioread: filename=audioread-2.1.9-py3-none-any.whl size=23140 sha256=91e34ff4b17310ebadda285f68d28a814b5d754bcc1ecf1ce37dc0a12d23da1b
#   Stored in directory: /root/.cache/pip/wheels/49/5a/e4/df590783499a992a88de6c0898991d1167453a3196d0d1eeb7
#   Building wheel for resampy (setup.py) ... done
#   Created wheel for resampy: filename=resampy-0.2.2-py3-none-any.whl size=320718 sha256=5554f3d8d850a1835f95088face25278a50b0d7047e3edf2cbfddda0be95cbc1
#   Stored in directory: /root/.cache/pip/wheels/6f/d1/5d/f13da53b1dcbc2624ff548456c9ffb526c914f53c12c318bb4
# Successfully built audioread resampy
# Installing collected packages: torch, llvmlite, numba, audioread, soundfile, appdirs, pooch, resampy, librosa, xxhash, huggingface-hub, dill, multiprocess, fsspec, pyarrow, datasets, transformers, asrecognition
#   Attempting uninstall: torch
#     Found existing installation: torch 1.7.1
#     Uninstalling torch-1.7.1:
#       Successfully uninstalled torch-1.7.1
#   Attempting uninstall: transformers
#     Found existing installation: transformers 4.3.3
#     Uninstalling transformers-4.3.3:
#       WARNING: Cannot remove entries from nonexistent file /root/miniconda3/lib/python3.8/site-packages/easy-install.pth
#       Successfully uninstalled transformers-4.3.3
# ERROR: After October 2020 you may experience errors when installing or updating packages. This is because pip will change the way that it resolves dependency conflicts.
#
# We recommend you use --use-feature=2020-resolver to test your packages with the new resolver before it becomes the default.
#
# fastai 2.2.7 requires torch<1.8,>=1.7.0, but you'll have torch 1.9.0 which is incompatible.
# transformers 4.9.1 requires huggingface-hub==0.0.12, but you'll have huggingface-hub 0.0.15 which is incompatible.
# Successfully installed appdirs-1.4.4 asrecognition-0.0.2 audioread-2.1.9 datasets-1.10.2 dill-0.3.4 fsspec-2021.7.0 huggingface-hub-0.0.15 librosa-0.8.1 llvmlite-0.36.0 multiprocess-0.70.12.2 numba-0.53.1 pooch-1.4.0 pyarrow-5.0.0 resampy-0.2.2 soundfile-0.10.3.post1 torch-1.9.0 transformers-4.9.1 xxhash-2.0.2
# Traceback (most recent call last):
#   File "/root/miniconda3/bin/pip", line 11, in <module>
#     sys.exit(main())
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/cli/main.py", line 75, in main
#     return command.main(cmd_args)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 121, in main
#     return self._main(args)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/cli/base_command.py", line 265, in _main
#     self.handle_pip_version_check(options)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 149, in handle_pip_version_check
#     session = self._build_session(
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/cli/req_command.py", line 90, in _build_session
#     session = PipSession(
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/network/session.py", line 249, in __init__
#     self.headers["User-Agent"] = user_agent()
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/network/session.py", line 159, in user_agent
#     setuptools_version = get_installed_version("setuptools")
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_internal/utils/misc.py", line 665, in get_installed_version
#     working_set = pkg_resources.WorkingSet()
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 567, in __init__
#     self.add_entry(entry)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 623, in add_entry
#     for dist in find_distributions(entry, True):
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1983, in find_eggs_in_zip
#     if metadata.has_metadata('PKG-INFO'):
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1414, in has_metadata
#     return self._has(path)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1854, in _has
#     return zip_path in self.zipinfo or zip_path in self._index()
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1731, in zipinfo
#     return self._zip_manifests.load(self.loader.archive)
#   File "/root/miniconda3/lib/python3.8/site-packages/pip/_vendor/pkg_resources/__init__.py", line 1688, in load
#     mtime = os.stat(path).st_mtime
# FileNotFoundError: [Errno 2] No such file or directory: '/root/miniconda3/lib/python3.8/site-packages/transformers-4.3.3-py3.8.egg'
