# %%
import pymongo
from pathlib import Path
import os
from dotenv import load_dotenv

# %%
from fastprogress import progress_bar
import json

# %%
from utils.langconv import Converter

# %%
Converter('zh-hans').convert('我是誰')
# Out:
# '我是谁'

# %%
pth = Path('.').joinpath('./mongo.env')
load_dotenv(pth)
# Out:
# True

# %% [markdown]
# ## UTILS

# %%
all_keys = ['abbreviations',
 'antonyms',
 'categories',
 'compounds',
 'coordinate_terms',
 'derived',
 'forms',
 'heads',
 'holonyms',
 'hypernyms',
 'hyphenation',
 'hyponyms',
 'inflection',
 'inflection_of',
 'lang',
 'lang_code',
 'meronyms',
 'pos',
 'proverbs',
 'related',
 'senses',
 'sounds',
 'synonyms',
 'translations',
 'troponyms',
 'wikipedia',
 'word']

def keep_desired_keys(*keys):
    return {
     k:0   for k in all_keys if k not in keys
    }

# %%
def query_words_by_key(key_name):
    return list(dict_col.find({
    key_name:{
        '$exists':True
    }
},{ **keep_desired_keys(key_name,'word') }))


def len_distribution(data, key_name):
    distr = {}
    samples = {}
    for h in data:
        len_h = len(h[key_name])
        if not distr.get(len_h):
            distr[len_h] = 1
            samples[len_h] = h
        else:
            distr[len_h] +=1
    d2 = {}       
    for k in sorted(distr.keys()):
        d2[k] = distr[k]
    return d2, samples

def get_uniq_tags(data, key_name):
    res = set()
    for item in data:
        res.update(item[key_name])
    return list(res)

def get_uniq_keys(arr):
    keys = set()
    samples = {}
    distr = {}
    for o in progress_bar(arr):
        _keys = list(o.keys())
        keys.update(_keys)
        for key in _keys:
            val = samples.get(key)
            if val is None:
                samples[key] = [o[key]]
            elif len(val) < 3:
                samples[key].append(o[key])
                
            if distr.get(key) is None:
                distr[key] = 1
            else:
                distr[key] += 1
    
    return list(keys), samples,distr

# %%
mongo_username, mongo_password = os.getenv('MONGO_INITDB_ROOT_USERNAME'), os.getenv('MONGO_INITDB_ROOT_PASSWORD')
conn = pymongo.MongoClient(
    host='localhost',
    port=27017,
    username=mongo_username,
    password=mongo_password
)

# %%
db_name = 'chartreuse'
dict_db = conn[db_name]
col_name = 'wiktionary'
dict_col = dict_db[col_name]

m_dict_col = dict_db['dictionary_en']
m_sense_col = dict_db['sense_en']

# %%
dict_pth = Path('.')/'wiktionary'/'dictionary-English.json'
dict_sense_pth = Path('.')/'wiktionary'/'English-all-senses.json'
dict_pth,dict_sense_pth

# %%
import json

# %%
def all_keys(pth):
    keys = set()
    with open(pth) as f:
        for line in f:
            json1 = json.loads(line)
            keys.update(json1.keys())
    return keys

keys = all_keys(dict_sense_pth)
keys

# %%
def count_key_lens(pth):
    max_dic = {}
    min_dic = {}
    key_lens_dic = {}
    with open(pth) as f:
        for line in f:
            json1 = json.loads(line)
            key_len = len(json1.keys())
#             if max_dic is None:
#                 max_dic = json1
#             if min_dic is None:
#                 min_dic = json1

            max_len = len(max_dic.keys())
            min_len = len(min_dic.keys())

            if key_len > max_len:
                max_dic = json1
            if min_len == 0 or key_len < min_len:
                min_dic = json1

            if key_lens_dic.get(key_len, None) is None:
                key_lens_dic[key_len] = 1
            else:
                key_lens_dic[key_len] +=1
    
    return max_dic, min_dic, key_lens_dic

# %%
max_dic, min_dic, key_lens = count_key_lens(dict_pth)

# %%
s_max_dic, s_min_dic, s_key_lens = count_key_lens(dict_sense_pth)

# %%
len(max_dic.keys()),max_dic.keys()

# %%
max_dic

# %%
len(min_dic.keys()), min_dic.keys(), min_dic

# %%
len(s_max_dic.keys()), s_max_dic.keys()

# %%
s_max_dic

# %%
len(s_min_dic.keys()), s_min_dic.keys(), s_min_dic

# %%
key_lens, s_key_lens

# %%
i = 0
for v in key_lens.values():
    i+= v
i

# %%
from tqdm import tqdm
import json
from datetime import datetime
with open(dict_sense_pth) as f:
    for line in tqdm(f):
        loaded = json.loads(line)
        dict_col.insert_one({
            **loaded,
        })

# %% [markdown]
#  ## HEADS
#
#  remove

# %%
## words with heads
lis = list(dict_col.find({
    'heads':{
        '$exists':True
    }
},{ **keep_desired_keys('heads','word') }))
len(lis)

# %%
lis[:10]

# %%
heads_greater_than_1 = [
    h
    for h in lis
    if len(h.get('heads',[])) > 1
]

# %%
heads_len_distribution = {}

for h in lis:
    len_h = len(h['heads'])
    if not heads_len_distribution.get(len_h):
        heads_len_distribution[len_h] = 1
    else:
        heads_len_distribution[len_h] +=1

heads_len_distribution

# %%
len(heads_greater_than_1)

# %%
heads_greater_than_1[5:10]

# %% [markdown]
# ## keys missing in words

# %%
keys = ['abbreviations',
 'antonyms',
 'categories',
 'compounds',
 'coordinate_terms',
 'derived',
 'forms',
 'heads',
 'holonyms',
 'hypernyms',
 'hyphenation',
 'hyponyms',
 'inflection',
 'inflection_of',
 'lang',
 'lang_code',
 'meronyms',
 'pos',
 'proverbs',
 'related',
 'senses',
 'sounds',
 'synonyms',
 'translations',
 'troponyms',
 'wikipedia',
 'word']

# %%
total_docs = 1021124
res = {}
for key in keys:
    cnt = dict_col.count_documents({
        key:{
            '$exists':True
        }
    })
    res[key] = {
         cnt: cnt,
        'missing': total_docs - cnt
    }
    if cnt < total_docs:
        print(key, cnt)

# %%
res

# %%
basic_keys = ['pos', 'word', 'lang', 'lang_code', 'senses']
alternative_keys = [
 'forms',
 'heads',
 'antonyms',
 'wikipedia'
 'abbreviations',
 'categories',
 'compounds',
 'coordinate_terms',
 'derived',
 'holonyms',
 'hypernyms',
 'hyphenation',
 'hyponyms',
 'inflection',
 'inflection_of',
 'meronyms',
 'proverbs',
 'related',
 'sounds',
 'synonyms',
 'translations',
 'troponyms',]

# %% [markdown]
# ## forms
#
# keep
#
# forms  string[]
#
# form_data  object[]

# %%
data = query_words_by_key('forms')
len(data)
# Out:
# 387771

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc19'),
#   'forms': [{'form': 'encyclopaedias', 'tags': ['plural']},
#    {'form': 'encyclopaediae', 'tags': ['plural']}],
#   'word': 'encyclopaedia'},
#  {'_id': ObjectId('60544a9311fe31d283dedc1c'),
#   'forms': [{'form': 'current event', 'tags': ['singular']}],
#   'word': 'current events'},
#  {'_id': ObjectId('60544a9311fe31d283dedc1e'),
#   'forms': [{'form': 'livres', 'tags': ['plural']}],
#   'word': 'livre'}]

# %%
all_forms = []
for item in data:
    all_forms.extend(item['forms'])
len(all_forms)
# Out:
# 589486

# %%
a,b,c = get_uniq_keys(all_forms)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='589486' class='' max='589486' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [589486/589486 00:01<00:00]
#     </div>

# %%
a,b,c
# Out:
# (['form', 'tags'],
#  {'form': ['encyclopaedias', 'encyclopaediae', 'current event'],
#   'tags': [['plural'], ['plural'], ['singular']]},
#  {'form': 589486, 'tags': 589486})

# %%
data[:5]

# %%
distribution,samples = len_distribution('forms')
distribution

# %%
samples

# %%
form_tags = set()

for item in lis:
    for f in item['forms']:
        form_tags.update(f['tags'])
form_tags

# %%
def get_tag_examples(data,tags):
    res = {}
    for item in data:
        forms = item['forms']
        for f in forms:
            _tags = f['tags']
            t = _tags[0]
            if res.get(t) is None:
                res[t] = [item]
            elif len(res[t]) < 3:
                res[t].append(item)
    return res

# %%
tag_examples = get_tag_examples(lis, form_tags)

# %%
tag_examples

# %% [markdown]
# ## antonyms
#
# keep
#
# antonyms string[]
#
# antonyms_missing string[]

# %%
from fastprogress import progress_bar

# %%
data = query_words_by_key('antonyms')
len(data)

# %%
all_ans = sum([o['antonyms'] for o in data], [])
an_keys, samples, distr = get_uniq_keys(all_ans)
an_keys, samples, distr

# %%
def check_if_antonyms_exists(data, extract_words):
    re = []
    
    existing_words = list(dict_col.find({}, keep_desired_keys('word')))
    print(len(existing_words))
    existing_words = set(
        [w['word'] for w in existing_words]
    )
    for item in progress_bar(data):
        words = extract_words(item)
        for word in words:
            if word not in existing_words:
                print('{},{}'.format(
                    item['word'],
                    word
                ))
                re.append(
                    (item['word'], word)
                )
    return re

# %%
data[:3]

# %%
def get_antonyms(item):
    return [i['word'] for i in item['antonyms']]

# %%
res = check_if_antonyms_exists(data, get_antonyms)

# %%
len(res) # 1112 antonyms missing

# %% [markdown]
# ## wikipedia
#
# remove

# %%
data = query_words_by_key('wikipedia')
len(data)

# %%
data[:4]

# %%
all_tags = set()
for item in data:
    all_tags.update(item['wikipedia'])
    
len(all_tags)

# %%
all_tags = list(all_tags)
all_tags[:10]

# %%
distribution,samples = len_distribution(data,'wikipedia')

# %%
distribution

# %%
samples

# %% [markdown]
# ## abbreviations
#
# keep
#
# abbreviations   string[]

# %%
data = query_words_by_key('abbreviations')
len(data)

# %%
data[:3]

# %%
distribution, samples = len_distribution(data, 'abbreviations')

# %%
distribution

# %%
samples

# %%
## keys in abbr
abbrs = sum([o['abbreviations'] for o in data],[])
abbr_keys,abbr_samples,distribution = get_uniq_keys(abbrs)
abbr_keys,abbr_samples, distribution

# %% [markdown]
#  ## categories
#
# keep
#
# wiktionary_categories string[]

# %%
data = query_words_by_key('categories')
len(data)

# %%
data[:3]

# %%
uniqued_categories = get_uniq_tags(data,'categories')
len(uniqued_categories)

# %%
distr, samples =len_distribution(data,'categories')

# %%
distr

# %%
uniqued_categories[:10]

# %% [markdown]
# ## compounds
#
# remove

# %%
data = query_words_by_key('compounds')
len(data)

# %%
data

# %% [markdown]
# ## coordinate_terms
#
# remove

# %%
data = query_words_by_key('coordinate_terms')
len(data)

# %%
data[3:5]

# %% [markdown]
# ## derived
#
# keep
#
# derived string[]

# %%
data = query_words_by_key('derived')
len(data)
# Out:
# 21125

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc20'),
#   'word': 'book',
#   'derived': [{'word': 'address book'},
#    {'word': 'audiobook'},
#    {'word': 'book account'},
#    {'word': 'book agent'},
#    {'word': 'book-answerer'},
#    {'word': 'book award'},
#    {'word': 'book-bearer'},
#    {'word': 'bookbinder'},
#    {'word': 'book-board'},
#    {'word': 'book-bosomed'},
#    {'word': 'book-bound'},
#    {'word': 'book-boy'},
#    {'word': 'book-burning'},
#    {'word': 'bookcase'},
#    {'word': 'book-cloth'},
#    {'word': 'book club'},
#    {'word': 'book canvasser'},
#    {'word': 'book concern'},
#    {'word': 'book-crab'},
#    {'word': 'book-credit'},
#    {'word': 'book-debt'},
#    {'word': 'book-edge gilder'},
#    {'word': 'book-edge marbler'},
#    {'word': 'book end'},
#    {'word': 'bookend'},
#    {'word': 'bookery'},
#    {'word': 'booketeria'},
#    {'word': 'book-farmer'},
#    {'word': 'book-folder'},
#    {'word': 'book-form'},
#    {'word': 'bookful'},
#    {'word': 'book-ghoul'},
#    {'word': 'book-gill'},
#    {'word': 'book hand'},
#    {'word': 'book-holder'},
#    {'word': 'bookhood'},
#    {'word': 'bookhouse'},
#    {'word': 'book-hunt'},
#    {'word': 'bookie'},
#    {'word': 'bookish'},
#    {'word': 'bookism'},
#    {'word': 'bookjacket'},
#    {'word': 'bookkeeper'},
#    {'word': 'bookkeeping'},
#    {'word': 'book-label'},
#    {'word': 'book-lare'},
#    {'word': 'book launch'},
#    {'word': 'book-law'},
#    {'word': 'book-lear'},
#    {'word': 'book-learned'},
#    {'word': 'book-learning'},
#    {'word': 'book-length'},
#    {'word': 'bookless'},
#    {'word': 'booklet'},
#    {'word': 'booklike'},
#    {'word': 'bookling'},
#    {'word': 'booklore'},
#    {'word': 'booklouse'},
#    {'word': 'booklover'},
#    {'word': 'book lover'},
#    {'word': 'book lung'},
#    {'word': 'bookly'},
#    {'word': 'bookmaker'},
#    {'word': 'bookmaking'},
#    {'word': 'bookman'},
#    {'word': 'bookmark'},
#    {'word': 'bookmarker'},
#    {'word': 'book match'},
#    {'word': 'book-mate'},
#    {'word': 'book-mindedness'},
#    {'word': 'book mite'},
#    {'word': 'bookmobile'},
#    {'word': 'book-muslin'},
#    {'word': 'book name'},
#    {'word': 'book-number'},
#    {'word': 'book-oath'},
#    {'word': 'book of condolence'},
#    {'word': 'book of first entry'},
#    {'word': 'Book of God'},
#    {'word': 'book of lading'},
#    {'word': 'book of life'},
#    {'word': 'book of original entry'},
#    {'word': 'book of rates'},
#    {'word': 'book of reference'},
#    {'word': 'Book of the Dead'},
#    {'word': 'book of the film'},
#    {'word': 'book of the living'},
#    {'word': 'book of words'},
#    {'word': 'book-packet'},
#    {'word': 'book piles'},
#    {'word': 'bookplate'},
#    {'word': 'book pocket'},
#    {'word': 'book-post'},
#    {'word': 'book-postage'},
#    {'word': 'book-press'},
#    {'word': 'book price'},
#    {'word': 'book prop'},
#    {'word': 'book-rate'},
#    {'word': 'book-read'},
#    {'word': 'bookrest'},
#    {'word': 'bookroom'},
#    {'word': 'book-scorpion'},
#    {'word': 'bookseller'},
#    {'word': 'bookselling'},
#    {'word': 'bookshelf'},
#    {'word': 'bookshop'},
#    {'word': 'book-shy'},
#    {'word': 'booksie'},
#    {'word': 'book-slide'},
#    {'word': 'book-society'},
#    {'word': 'book-stack'},
#    {'word': 'bookstaff'},
#    {'word': 'bookstall'},
#    {'word': 'book-stamp'},
#    {'word': 'bookstand'},
#    {'word': 'bookstore'},
#    {'word': 'book support'},
#    {'word': 'booksy'},
#    {'word': 'book-table'},
#    {'word': 'book token'},
#    {'word': 'book trade'},
#    {'word': 'book-tray'},
#    {'word': 'book-trough'},
#    {'word': 'book type'},
#    {'word': 'book value'},
#    {'word': 'bookwards'},
#    {'word': 'book-ways'},
#    {'word': 'bookwise'},
#    {'word': 'bookwork'},
#    {'word': 'book-world'},
#    {'word': 'bookworm'},
#    {'word': 'book-wright'},
#    {'word': 'booky'},
#    {'word': 'bring to book'},
#    {'word': 'burn book'},
#    {'word': 'by-book'},
#    {'word': 'by the book'},
#    {'word': 'casebook'},
#    {'word': 'cashbook'},
#    {'word': 'checkbook'},
#    {'word': 'chequebook'},
#    {'word': 'cheque book'},
#    {'word': 'closed book'},
#    {'word': 'close the books'},
#    {'word': 'coffee table book'},
#    {'word': 'coffee-table book'},
#    {'word': 'comic book'},
#    {'word': 'cookbook'},
#    {'word': 'cookery book'},
#    {'word': 'cook the books'},
#    {'word': 'copybook'},
#    {'word': 'coursebook'},
#    {'word': 'e-book'},
#    {'word': 'emblem book'},
#    {'word': 'exercise book'},
#    {'word': 'forebook'},
#    {'word': 'fuck book'},
#    {'word': 'Good Book'},
#    {'word': 'guest book'},
#    {'word': 'guidebook'},
#    {'word': 'handbook'},
#    {'word': 'hymn book'},
#    {'word': "in anyone's book"},
#    {'word': 'in my book'},
#    {'word': "in someone's bad books"},
#    {'word': "in someone's good books"},
#    {'word': 'in the books'},
#    {'word': 'know like a book'},
#    {'word': 'logbook'},
#    {'word': 'make book'},
#    {'word': 'matchbook'},
#    {'word': 'notebook'},
#    {'word': 'off the books'},
#    {'word': 'on the books'},
#    {'word': 'open book'},
#    {'word': 'passbook'},
#    {'word': 'pension book'},
#    {'word': 'phrasebook'},
#    {'word': 'pocketbook'},
#    {'word': 'prayer book'},
#    {'word': 'ration book'},
#    {'word': 'read like a book'},
#    {'word': 'reading book'},
#    {'word': 'record book'},
#    {'word': 'reference book'},
#    {'word': 'rough book'},
#    {'word': 'runbook'},
#    {'word': 'scrapbook'},
#    {'word': 'sketch book'},
#    {'word': 'spellbook'},
#    {'word': 'songbook'},
#    {'word': 'storybook'},
#    {'word': "suit one's book"},
#    {'word': "take a leaf out of someone's book"},
#    {'word': 'talk like a book'},
#    {'word': 'textbook'},
#    {'word': 'throw the book at'},
#    {'word': "visitors' book"},
#    {'word': 'without book'},
#    {'word': 'wordbook'},
#    {'word': 'workbook'},
#    {'word': 'yearbook'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc21'),
#   'word': 'book',
#   'derived': [{'word': 'bookable'},
#    {'word': 'booking'},
#    {'word': 'double-book'},
#    {'word': 'overbook'},
#    {'word': 'rebook'},
#    {'word': 'unbook'},
#    {'word': 'underbook'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc25'),
#   'word': 'portmanteau',
#   'derived': [{'word': 'portmanteau film'}, {'word': 'portmanteau word'}]}]

# %%
all_derived = sum([o['derived'] for o in data],[])
a,b,c = get_uniq_keys(all_derived)
a,b,c
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='144289' class='' max='144289' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [144289/144289 00:00<00:00]
#     </div>
# (['tags', 'topics', 'sense', 'word', 'translation'],
#  {'word': ['address book', 'audiobook', 'book account'],
#   'tags': [['Corvus coronoides'], ['Corvus ruficollis'], ['Corvus moriorum']],
#   'sense': ['assent and engagement by person on whom bill of exchange is drawn',
#    'assent and engagement by person on whom bill of exchange is drawn',
#    'typography'],
#   'translation': ['back slang',
#    'to talk at length in a foolish or boring way',
#    'that which skews something'],
#   'topics': [['grammar', 'linguistics'],
#    ['the',
#     'country',
#     'countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences'],
#    ['region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences']]},
#  {'word': 144289,
#   'tags': 7024,
#   'sense': 870,
#   'translation': 133,
#   'topics': 109})

# %% [markdown]
# ## holonyms
#
# discard
#
# holonyms string[]

# %%
data = query_words_by_key('holonyms')
len(data)
# Out:
# 74

# %%
[o['word'] for o in data]
# Out:
# ['zero',
#  'South Africa',
#  'New Zealand',
#  'Botswana',
#  'Mozambique',
#  'New Caledonia',
#  'Micronesia',
#  'ontology',
#  'antecedent',
#  'chocolate',
#  'room',
#  'rice',
#  'theory',
#  'bell',
#  'act',
#  'acorn',
#  'goat',
#  'badger',
#  'mountain',
#  'Hawaii',
#  'link',
#  'bishop',
#  'polynomial',
#  'Ethiopian',
#  'New Guinea',
#  'lion',
#  'pons',
#  'trimester',
#  'Holy Spirit',
#  'axiom',
#  'part',
#  'range',
#  'guy',
#  'client',
#  'atrium',
#  'poem',
#  'chameleon',
#  'geometry',
#  'amino acid',
#  'sucker',
#  'upright',
#  'cranium',
#  'buntline',
#  'stile',
#  'theorem',
#  'Genesis',
#  'conjunct',
#  'topology',
#  'authorization',
#  'consequent',
#  'Calgary',
#  'Algenib',
#  'Markab',
#  'sumti',
#  'legionary',
#  'cordage',
#  'purchasing',
#  'Minneapolis',
#  'Westphalian',
#  'clergywoman',
#  'self-awareness',
#  'Sichuan pepper',
#  'Manchuria',
#  'disjunct',
#  'trigram',
#  'open set',
#  'coalface',
#  'ultrafilter',
#  'onsen',
#  'Deep Web',
#  'Upper German',
#  'Central German',
#  'Dark Web',
#  'Almach']

# %%
all_holonyms = sum([o['holonyms'] for o in data],[])

# %%
a,b,c = get_uniq_keys(all_holonyms)
a,b,c
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='148' class='' max='148' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [148/148 00:00<00:00]
#     </div>
# (['word', 'topics', 'sense', 'tags'],
#  {'word': ['kernel', 'Subsahara', 'Polynesia'],
#   'sense': ["value of a function's variables at zero",
#    'in logic',
#    'structure housing bells'],
#   'topics': [['Roman', 'Catholicism', 'Catholicism', 'Christianity'],
#    ['Roman', 'Catholicism', 'Catholicism', 'Christianity'],
#    ['Roman', 'Catholicism', 'Catholicism', 'Christianity']],
#   'tags': [['Methodism', 'worldwide'],
#    ['Eastern Orthodoxy', 'worldwide'],
#    ['Eastern Orthodoxy', 'worldwide']]},
#  {'word': 148, 'sense': 47, 'topics': 3, 'tags': 16})

# %%
data[10:13]
# Out:
# [{'_id': ObjectId('60544a9a11fe31d283deec58'),
#   'word': 'room',
#   'holonyms': [{'word': 'house'},
#    {'word': 'building'},
#    {'word': 'structure'},
#    {'word': 'apartment'},
#    {'word': 'home'},
#    {'word': 'flat'},
#    {'word': 'hotel'},
#    {'word': 'hospital'}]},
#  {'_id': ObjectId('60544a9b11fe31d283deee59'),
#   'word': 'rice',
#   'holonyms': [{'word': 'bhelpuri'},
#    {'word': 'California roll'},
#    {'word': 'dosa'},
#    {'word': 'gumbo'},
#    {'word': 'idli'},
#    {'word': 'jambalaya'},
#    {'word': 'khir'},
#    {'word': 'mirin'},
#    {'word': 'mochi'},
#    {'word': 'nasi goreng'},
#    {'word': 'onigiri'},
#    {'word': 'pad thai'},
#    {'word': 'paella'},
#    {'word': 'pilaf'},
#    {'word': 'pilau'},
#    {'word': 'rangoli'},
#    {'word': 'rijsttafel'},
#    {'word': 'risotto'},
#    {'word': 'sake'},
#    {'word': 'samshu'},
#    {'word': 'sushi'}]},
#  {'_id': ObjectId('60544a9e11fe31d283def684'),
#   'word': 'theory',
#   'holonyms': [{'word': 'formal system', 'sense': 'in logic'}]}]

# %% [markdown]
# ## hypernyms
#
# keep
#
# hypernyms string[]

# %%
data = query_words_by_key('hypernyms')
len(data)
# Out:
# 935

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc29'),
#   'word': 'day',
#   'hypernyms': [{'word': 'month'},
#    {'word': 'time'},
#    {'word': 'week'},
#    {'word': 'year'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedcd1'),
#   'word': 'Sunday',
#   'hypernyms': [{'word': 'day'}]},
#  {'_id': ObjectId('60544a9411fe31d283dede70'),
#   'word': 'abscissa',
#   'hypernyms': [{'word': 'coordinate', 'sense': 'first of two coordinates'},
#    {'word': 'axis', 'sense': 'horizontal line'}]}]

# %%
all_hypernyms = sum([o['hypernyms'] for o in data],[])
a,b,c = get_uniq_keys(all_hypernyms)
a,b,c
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1521' class='' max='1521' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1521/1521 00:00<00:00]
#     </div>
# (['word', 'topics', 'sense', 'translation', 'tags'],
#  {'word': ['month', 'time', 'week'],
#   'sense': ['first of two coordinates', 'horizontal line', 'astronomy'],
#   'tags': [['includes list of coordinate terms'],
#    ['sometimes'],
#    ['may or may not be married']],
#   'translation': ['includes list of coordinate terms',
#    "sibling of someone's parent",
#    "sibling of someone's parent"],
#   'topics': [['order', 'theory', 'mathematics'],
#    ['finance', 'economics'],
#    ['design', 'arts', 'lifestyle']]},
#  {'word': 1521, 'sense': 483, 'tags': 91, 'translation': 39, 'topics': 5})

# %% [markdown]
# ## hyphenation
#
# keep
#
# processing: unique
#
# hyphenation

# %%
data = query_words_by_key('hyphenation')
len(data)
# Out:
# 11462

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc19'),
#   'word': 'encyclopaedia',
#   'hyphenation': ['en‧cy‧clo‧pe‧dia']},
#  {'_id': ObjectId('60544a9311fe31d283dedc1d'),
#   'hyphenation': ['flocci‧nauci‧ni‧hili‧pili‧fi‧ca‧tion'],
#   'word': 'floccinaucinihilipilification'},
#  {'_id': ObjectId('60544a9311fe31d283dedc2d'),
#   'word': 'denotation',
#   'hyphenation': ['de‧no‧ta‧tion']}]

# %%
distribution, samples = len_distribution(data,'hyphenation')

# %%
distribution,samples
# Out:
# ({1: 11294, 2: 124, 3: 29, 4: 15},
#  {1: {'_id': ObjectId('60544a9311fe31d283dedc19'),
#    'word': 'encyclopaedia',
#    'hyphenation': ['en‧cy‧clo‧pe‧dia']},
#   2: {'_id': ObjectId('60544a9311fe31d283deddb4'),
#    'hyphenation': ['aba‧cus', 'aba‧ci'],
#    'word': 'abacus'},
#   4: {'_id': ObjectId('60544a9511fe31d283dee166'),
#    'word': 'second',
#    'hyphenation': ['sec‧ond', 'sec‧ond', 'sec‧ond;', 'sec‧ond']},
#   3: {'_id': ObjectId('60544aa411fe31d283df01d2'),
#    'word': 'postulate',
#    'hyphenation': ['pos‧tu‧late;', 'pos‧tu‧late;', 'pos‧tu‧late']}})

# %% [markdown]
# ## hyponyms
#
# keep
#
# strings in form to processs: 'See Thesaurus:book'
#
# hyponyms

# %%
data = query_words_by_key('hyponyms')
len(data)
# Out:
# 1600

# %%
data[10:13]

# %%
all_items = sum([o['hyponyms'] for o in data],[])
a,b,c = get_uniq_keys(all_items)
a,b,c
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='11933' class='' max='11933' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [11933/11933 00:00<00:00]
#     </div>
# (['word', 'topics', 'sense', 'translation', 'tags'],
#  {'word': ['See Thesaurus:book', 'bad hair day', 'Bastille Day'],
#   'sense': ['domestic species', 'domestic species', 'domestic species'],
#   'tags': [['Japanese'], ['Chinese'], ['structurally']],
#   'translation': ['open a bit', 'young rooster', 'young'],
#   'topics': [['countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences',
#     'countries',
#     'of',
#     'Europe',
#     'countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences'],
#    ['countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences',
#     'countries',
#     'of',
#     'Europe',
#     'countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences'],
#    ['countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences',
#     'countries',
#     'of',
#     'Europe',
#     'countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences']]},
#  {'word': 11933, 'sense': 1778, 'tags': 339, 'translation': 53, 'topics': 120})

# %% [markdown]
# ## inflection
#
# discard

# %%
data = query_words_by_key('inflection')
len(data)
# Out:
# 172

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedcd0'),
#   'inflection': [{'template_name': 'en-conj-simple'}],
#   'word': 'verb'},
#  {'_id': ObjectId('60544a9311fe31d283deddc1'),
#   'inflection': [{'template_name': 'en-conj-simple'}],
#   'word': 'abhor'},
#  {'_id': ObjectId('60544a9411fe31d283dede48'),
#   'inflection': [{'1': 'es', 'template_name': 'en-conj-simple'}],
#   'word': 'abolish'}]

# %% [markdown]
# ## inflection_of
#
# discard

# %%
data = query_words_by_key('inflection_of')
len(data)
# Out:
# 9

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9b11fe31d283deefea'),
#   'inflection_of': ['they'],
#   'word': 'them'},
#  {'_id': ObjectId('60544a9e11fe31d283def65b'),
#   'inflection_of': ['the indefinite personal pronoun one'],
#   'word': 'oneself'},
#  {'_id': ObjectId('60544a9e11fe31d283def66c'),
#   'inflection_of': ['he'],
#   'word': 'himself'}]

# %% [markdown]
# ## meronyms
#
# discard

# %%
data = query_words_by_key('meronyms')
len(data)
# Out:
# 92

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc7c'),
#   'word': 'dialect',
#   'meronyms': [{'word': 'idiolect'}]},
#  {'_id': ObjectId('60544a9411fe31d283dee0d4'),
#   'word': 'century',
#   'meronyms': [{'word': 'cohort', 'sense': 'major unit of the Roman army'},
#    {'word': 'maniple', 'sense': 'major unit of the Roman army'},
#    {'word': 'legion', 'sense': 'major unit of the Roman army'}]},
#  {'_id': ObjectId('60544a9511fe31d283dee1f4'),
#   'word': 'flute',
#   'meronyms': [{'word': 'fipple', 'sense': 'music'},
#    {'word': 'labium', 'sense': 'music'}]}]

# %% [markdown]
# ## proverbs
# discard

# %%
data = query_words_by_key('proverbs')
data

# %% [markdown]
# ## related
# multi words
#
# keep
#
# action or environment related with word
#
# related string[]

# %%
data = query_words_by_key('related')
len(data)
# Out:
# 24297

# %%
all_items = []
for o in data:
    all_items.extend(o['related'])
    
a,b,c = get_uniq_keys(all_items)
a,b,c
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='85171' class='' max='85171' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [85171/85171 00:00<00:00]
#     </div>
# (['word', 'topics', 'sense', 'translation', 'tags'],
#  {'word': ['incunable', 'scroll', 'tome'],
#   'tags': [['cases and words'],
#    ['see more related terms'],
#    ['Hebrew calendar months']],
#   'topics': [['days', 'of', 'the', 'week', 'weekdays', 'time', 'property'],
#    ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property'],
#    ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']],
#   'sense': ['13th-c. counterfeit coin',
#    '13th-c. counterfeit coin',
#    '13th-c. counterfeit coin'],
#   'translation': ['thou', 'mathematics', 'mathematics']},
#  {'word': 85171,
#   'tags': 10433,
#   'topics': 4399,
#   'sense': 2649,
#   'translation': 362})

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc20'),
#   'word': 'book',
#   'related': [{'word': 'incunable'},
#    {'word': 'scroll'},
#    {'word': 'tome'},
#    {'word': 'volume'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc25'),
#   'word': 'portmanteau',
#   'related': [{'word': 'List of portmanteau words defined in Wiktionary'},
#    {'word': 'Wikipedia article on portmanteaus',
#     'tags': ['cases and words']}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc29'),
#   'word': 'day',
#   'related': [{'word': 'day of the week',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': 'Sunday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Monday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Tuesday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Wednesday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Thursday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Friday',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': '\u200e Saturday^ ^//dummy.host/index.php?title=Template%3Alist%3Adays+of+the+week%2Fen&action=edit edit',
#     'topics': ['days', 'of', 'the', 'week', 'weekdays', 'time', 'property']},
#    {'word': 'Sabbath'},
#    {'word': 'calendar'}]}]

# %% [markdown]
# ## sounds
#
# keep
#
# need to clean data
#
# remove keys:  text, homophone, enpr, other, audio

# %%
data = query_words_by_key('sounds')
len(data)
# Out:
# 114966

# %%
def sounds_data_with_key(key_name):
    res = []
    for item in data:
        for sound in item['sounds'] :
            if key_name in sound.keys():
                res.append(item)
    return res

# %%
sounds_data_with_key('text')[:2]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc19'),
#   'word': 'encyclopaedia',
#   'sounds': [{'ipa': '/ənˌsəɪ.kləˈpi.di.ə/', 'tags': ['Canada']},
#    {'ipa': '/ɪnˌsaɪ.kləˈpi(ː).di.ə/', 'tags': ['UK', 'US']},
#    {'rhymes': '-iːdiə'},
#    {'audio': 'en-us-encyclopedia.ogg', 'tags': ['US'], 'text': 'Audio (US)'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc1a'),
#   'word': 'pies',
#   'sounds': [{'ipa': '/paɪz/'},
#    {'rhymes': '-aɪz'},
#    {'audio': 'LL-Q1860 (eng)-Vealhurl-pies.wav',
#     'tags': ['UK'],
#     'text': 'Audio (UK)'}]}]

# %%
all_tags = set()
for item in all_items:
    if 'tags' in item.keys():
        all_tags.update(
            item['tags']
        )
len(all_tags), list(all_tags)
# Out:
# (880,
#  ['postpositive',
#   'Sense 2',
#   'some speakers',
#   'or a quintuplet',
#   'Gaia hypothesis',
#   'Australian English',
#   'rare',
#   'female given name',
#   'California English',
#   'past tense and past participle',
#   'unstressed or',
#   'Ontario',
#   'especially in Dublin',
#   'military',
#   'found in the US',
#   'Estuary English',
#   'Slang',
#   'New Jersey',
#   'sense 1',
#   'London',
#   'dialects with the father-bother merger',
#   '“to sleep”',
#   'Estuary',
#   'Midwestern US',
#   'Rare',
#   'CA synth',
#   'dialectal',
#   'US military command',
#   'variant',
#   'modern',
#   'English Midlands',
#   'Inland North',
#   'US with /u/',
#   'merged vowel',
#   'Washington',
#   "'a rabbit'",
#   'sense 2',
#   'US Inland North',
#   'trap-bath split',
#   'Western Canada',
#   'in the medical sense',
#   'Southern',
#   'what he said',
#   'yod coalescence',
#   'laxly',
#   'city in Washington',
#   'possibly dated outside the local dialect',
#   'now nonstandard in reference to the state',
#   'no weak vowel merger',
#   'US and Central Canada',
#   'US (varieties with the cot-caught merger)',
#   'Classical',
#   'mountain',
#   'careful',
#   'uncommon',
#   'North Durham',
#   'Cultivated Australian',
#   'parts of the US and Canada',
#   'Standard Canadian',
#   'Northern Ireland',
#   'New England',
#   'all senses',
#   'in compounds like "twopenny"',
#   'Maritimes',
#   'longer pronunciation',
#   'General New Zealand',
#   'Philadelphia',
#   'UK',
#   'regional',
#   'without wine-whine',
#   'plural of synapse',
#   'UK and US',
#   'some New England and Southern American dialects',
#   'regional US and England',
#   'Southern US',
#   'soft g',
#   '</span><span class="ib-content qualifier-content">[[w:Australian English phonology|General Australian]]</span><span class="ib-brac qualifier-brac">',
#   'with the',
#   'Tripoli',
#   'Appalachia',
#   'enunciated',
#   'Liverpool usually',
#   'because',
#   'wine-whine merger',
#   'New York',
#   'northern cities vowel shift',
#   'West',
#   'in',
#   'yod-coalescence',
#   'as an unstressed',
#   'Hong Kong',
#   'after vowel sound',
#   'now virtually obsolete',
#   'town in Massachusetts',
#   'by haplology',
#   'some US dialects',
#   'as a French name',
#   'hockey team',
#   'village in Ohio',
#   'synthesized',
#   'British Isles',
#   'irregular',
#   'r-dissimilation',
#   'partly anglicised',
#   'cot-caught merger',
#   'no wine-whine merger',
#   'occasionally',
#   'noun and adjective',
#   'now chiefly dialect',
#   'hypercorrection',
#   'beis din',
#   'Tasmanian',
#   'US South',
#   'w:northern cities vowel shift',
#   'AAVE',
#   'slang',
#   'diminutive of Giles',
#   'non-standard except Ireland',
#   'naval',
#   'northern Hiberno-English',
#   'paragon',
#   'anglicized',
#   'university',
#   'Singapore',
#   'adjective: clearly evident',
#   'Spanish-influenced',
#   'Norfolk',
#   'SIN',
#   'Canadian',
#   'given name',
#   'traditional British pronunciation',
#   'usa',
#   'Contemporary RP',
#   'Quebec English',
#   'sometimes',
#   'County Durham',
#   'Virginia',
#   'wholly-holy split',
#   'verb senses relating to guiding or conducting',
#   'near-square merger',
#   'in dialects with the',
#   'US and Canada',
#   'Canada: Ontario',
#   'multicultural London also',
#   'informal',
#   'Conservative RP',
#   'colloquial',
#   'plural of periphrasis',
#   'now commonly',
#   'Midland English dialect',
#   '/æ/ raising',
#   'antepenultimate stress',
#   'UK male',
#   'Alternative form',
#   'more anglicized',
#   'some other US dialects',
#   'Hindustani',
#   'UK RP',
#   'or /θ/',
#   'esp. Bolton',
#   'town in Kent',
#   '(Ireland)',
#   'other dialects in the UK',
#   'reduced',
#   'Broad Geordie',
#   'local',
#   'diminutive of Wiliam',
#   'with weak-vowel merger',
#   'colloquially',
#   'unstressed elsewhere',
#   'by analogy to arc',
#   'Julian',
#   'URP',
#   '/t/',
#   'US-Rhode Island',
#   'American',
#   'non-rhotic accents',
#   'Macquarie Dictionary',
#   'Yiddish-influenced',
#   'sometimes in Northern England',
#   'with intrusive r',
#   'without wholly-holy split',
#   'North Wales',
#   'derogatory',
#   'rural areas of Scotland',
#   'meal eaten after religious fasting',
#   'nonstandard',
#   'Structured Query Language',
#   'many US accents',
#   'non-naturalized pronunciation',
#   'French',
#   'parts of South Africa',
#   '‘to forget’',
#   'river starting in the Cairngorms',
#   'AU/NZ',
#   'anatomy sense',
#   'Scottish',
#   'other senses',
#   'especially',
#   'Audio',
#   'without the wine-whine merger',
#   'Aus/NZ',
#   'Verb',
#   'parts of Ontario',
#   'Northern English accents',
#   '“to be”',
#   "diphthong /aɪ̯/ for ''i'' in ''anti-''",
#   'England',
#   'respectively',
#   'more common realization',
#   'slow speech',
#   'Germany',
#   'India',
#   '[æntaɪ]',
#   'Caribbean',
#   'Germanic',
#   'traditional elsewhere',
#   'pin-pen merger',
#   'with and',
#   'with syncope',
#   'Boston',
#   'Lincolnshire',
#   'proscribed',
#   'Northern and Western',
#   'some Irish speakers',
#   'for one pronunciation',
#   'anglicised',
#   'Alberta',
#   'Noun',
#   'has to',
#   'plural of antipode',
#   'Quebec',
#   'Irish English',
#   'Jewish',
#   'Ulster English',
#   'Gillingham FC person',
#   'in dialects without the',
#   'Canada: British Columbia',
#   'Italian-like',
#   'SAfrica',
#   'Spanish given name',
#   'poetic',
#   'US-Inland North',
#   'hooray',
#   'MLE',
#   'Georgia',
#   'weak vowel',
#   'Cornwall',
#   'faithful to Latin original',
#   'imitation of snoring',
#   'after voiceless consonants /p/',
#   'town in Dorset',
#   'Us',
#   'with diphthong',
#   "women's voice",
#   'beit din',
#   'Puerto Rican',
#   'when conjugated as contributing or contributed',
#   'now regional',
#   'English village',
#   'closer to Arabic',
#   'Pakistan',
#   'perhaps modeled on piece etc',
#   'Great Lakes',
#   'UK (places)',
#   'noun',
#   'Britain',
#   'Individual Retirement Account',
#   'computing',
#   'locally',
#   'anglicized pronunciation',
#   'paeans',
#   'ante 44-27 BC',
#   'UK dialectal',
#   'article',
#   'obsolete',
#   'Geordie',
#   'Irish Republican Army',
#   'predicative adjective',
#   'after a voiceless consonant other than a /t/',
#   'town in County Durham',
#   'Northumbrian',
#   'other accents without the "Hurry-furry" merger',
#   'Austr',
#   'river',
#   'cousin',
#   'soft C',
#   "''US''",
#   'some Northern Enɡlish dialects',
#   'architecture and zoology',
#   'some US',
#   'unstressed before a vowel',
#   'on a minute scale',
#   'predicative',
#   'US cot-caught merged',
#   'UK &ndash',
#   'one pronunciation',
#   'after a vowel or a voiced consonant other than a sibilant',
#   'also UK',
#   'attributive',
#   'French placename',
#   'but common',
#   'US /kɑləˈrædoʊ/ variant',
#   'abbreviation',
#   'in the local dialect',
#   'plural of periphrase',
#   'US regional',
#   'younger speakers in the UK',
#   'emphatic',
#   'Indiana',
#   'Switzerland',
#   'after /t/',
#   'proscribed spelling pronunciation',
#   'original Russian',
#   'otherwise',
#   'lax',
#   'Eastern New England',
#   'Demi Lovato etc.',
#   'variously',
#   'Wisconsin',
#   'short vowel',
#   'CDP in Pennsylvania',
#   'Demi Moore',
#   'Sense 1',
#   'nautical',
#   'formerly also UK',
#   'weak',
#   'sometimes proscribed',
#   'rapid',
#   'English',
#   'present',
#   'cot-caught merged',
#   'Pakistani English',
#   'initialism',
#   'nonstandard but traditional',
#   'in accents with the cot-caught merger',
#   'accents without the "Hurry-furry" merger',
#   'Rioplatense',
#   'nickname of New York',
#   'distinguished from proscribe',
#   'North-East England',
#   'intrusive R',
#   'Standard Hawaiian English',
#   'Polish pronunciation',
#   'British Columbia',
#   'Yorkshire',
#   'haplology',
#   'Somerset',
#   'Dutch',
#   'before vowels',
#   'nonstandard UK',
#   'alternatively',
#   'have to',
#   'A musical or piquet term',
#   'Northern',
#   'Netherlands',
#   'US /kɑləˈrɑdoʊ/ variant',
#   'Lojban-like',
#   'emulating French',
#   'in casual speech',
#   'rural folk speech of New England and Upstate New York',
#   'alternate UK pronunciation',
#   '/t͡ʃ/',
#   'Santa Clara',
#   'verb',
#   'also especially the variant "Mariah"',
#   'double-I-H-F',
#   'AU',
#   'weak-vowel merger',
#   '"a ticket"',
#   'old-fashioned RP',
#   'UK English',
#   'northern US',
#   'county in Georgia',
#   'Mayan',
#   'Francophone',
#   'SE',
#   'more common in casual speech',
#   'General American',
#   'Received Pronunciation',
#   'accents with the "Hurry-furry" merger',
#   'cathedral',
#   'short pronunciation',
#   'stressed',
#   'preposition',
#   'town in Georgia',
#   'USA',
#   'strong',
#   'Philippine',
#   'Scouse',
#   'past',
#   'native pronunciation',
#   'of the adjectival and singular nounal sense',
#   'Rochdale',
#   'A fencing term',
#   'widespread spelling pronunciation',
#   'rivers in England and Canada',
#   'of the plural nounal sense',
#   '/k/',
#   'setting of the Batman franchise',
#   'video games',
#   'humourous',
#   'obsolete elsewhere',
#   'Aust',
#   'depending on the word taking the suffix',
#   '1',
#   'German origin',
#   'with Grecian stress',
#   'Welsh English',
#   'traditional New England',
#   'very dated',
#   'happening every minute',
#   'Northern England',
#   'emulating Japanese',
#   'Gillian',
#   'Western US',
#   'Scots',
#   'proper-noun',
#   'North American also',
#   'as in tartare sauce',
#   'Canada',
#   'Des Moines',
#   'Regional American',
#   'Kerala',
#   'Weak-vowel merger',
#   'Minnesota native dialect',
#   'past tense and participle',
#   'close-in weapon system',
#   'Mary-marry-merry merger',
#   'plural',
#   'some accents',
#   'in some senses',
#   'it',
#   'Bristolian',
#   'formerly',
#   'Magdalen College',
#   'Georgian',
#   'places in China',
#   'Ecclesiastical',
#   'non-rhotic',
#   'main allophones',
#   'without weak vowel merger',
#   'Midland American English',
#   'Scottish English',
#   'without diphthong',
#   'electronics',
#   'Greek pronunciation',
#   'Northern California',
#   'after a vowel',
#   'Hiberno-English',
#   'non standard',
#   'Midlands',
#   'Old-fashioned RP',
#   'Cajun',
#   'South West England',
#   'Scot',
#   'Kenya',
#   'verb form',
#   'Scotland',
#   'commonly',
#   'in accents without the merger',
#   'regional US',
#   'sometimes the surname',
#   '9/11',
#   'masculine',
#   'for the decade',
#   'South African',
#   'US placename',
#   'after a vowel or a voiced consonant other than a /d/',
#   'New York State',
#   'CAN',
#   'GenAm',
#   '<span class="IPA">/beɪˈdʒɪŋ/</span>',
#   'Wales',
#   'Eastern US',
#   'without the horse-hoarse merger',
#   'Philippine English',
#   'US - Variant 1',
#   'native',
#   'GenAM',
#   'some Lithuanian Ashkenazim',
#   'river in Wales',
#   'Latinized',
#   'nonstandard outside dialects',
#   'imitating the French pronunciation',
#   'most US speakers',
#   'to approximate the French pronunciation',
#   'before consonants',
#   'especially in the U.S.',
#   'past of use',
#   'to',
#   'male US voice',
#   'past participle',
#   'Ocracoke Island (in the Outer Banks of North Carolina)',
#   'southern Hiberno-English',
#   'BR',
#   "short vowel /i/ in ''anti-''",
#   'ga',
#   'colloquial or dialectal',
#   'recycling plant',
#   'Thai',
#   'alternative for adjective or noun senses',
#   'US historical',
#   'river in Connecticut',
#   'and Estuary English',
#   'I-E-E',
#   'Canadian raising',
#   'town and village in New York',
#   'in accents with the wine-whine merger',
#   'General South African',
#   'rhotic accents',
#   'archaic',
#   'simple past',
#   'Hawaii',
#   'Southern American English',
#   'what she said',
#   "especially in the sense ‘an ailment'",
#   'Essex',
#   'older southern US',
#   '“to translate”',
#   'town and river in England',
#   'transitive',
#   'New Hampshire',
#   'approximating the Norse and Icelandic pronunciation',
#   'Northern US',
#   'Cockney',
#   'peens',
#   'T-flapping',
#   'US/UK',
#   'verb senses derived from the noun',
#   'U.S.',
#   'United Kingdom',
#   'computer science meaning',
#   'London avenue',
#   'particularly common in the Great Lakes',
#   'after sibilant',
#   'acronym',
#   'I-I-H-F',
#   'older',
#   'UK with /ʊ/',
#   'some Northern English accents',
#   'Mauricie',
#   'several locations',
#   'auxiliary',
#   'extremely rare',
#   'North America',
#   'engineering',
#   'medical',
#   'George Everest and family',
#   'team sports senses',
#   'noun senses derived from the verb',
#   'Francophonic',
#   'sculpture',
#   'especially Nevada',
#   '/æ/ tensing',
#   'Midland',
#   'Vermont',
#   'some Ashkenazim',
#   'IPA',
#   'Hampshire',
#   'parts of the UK',
#   'two',
#   'North American',
#   'technical',
#   'Australian',
#   'some US speakers',
#   'Chicago',
#   'US female',
#   'Indian English',
#   'placenames in Oxford and Cambridge',
#   'distinctive cot-caught',
#   'intensifier',
#   "''stressed''",
#   'singular',
#   'Malaysia & Singapore',
#   'Australia',
#   'weak vowel distinction',
#   'letter name',
#   'plural-only',
#   'Latinate',
#   'US only',
#   'Canadian English',
#   'parts of US',
#   'US',
#   'other regions',
#   'UK also',
#   'fast speech',
#   'now dialectal',
#   'Dublin / East',
#   'Nigeria',
#   '2',
#   'chiefly US',
#   'Upper Midwest',
#   "without ''Mary-marry-merry'' merger",
#   'German',
#   'Hindi style',
#   'anglicized alternative pronunciation of the given name',
#   'Upper RP Triphthong Smoothing',
#   'adverb',
#   'Rhode Island',
#   'francophonic',
#   'NCVS',
#   'Anglicised',
#   'town in New Zealand',
#   'RP spelling pronunciation',
#   'approximating the Norse and Icelandic pronunciations',
#   'South Asia',
#   'California',
#   'without the merger',
#   'with Latinate stress',
#   'see note',
#   '</span><span class="ib-content qualifier-content">US</span><span class="ib-brac qualifier-brac">',
#   'letter',
#   '(traditional) Eastern New England Irish English',
#   'chiefly Midwestern',
#   'US-California',
#   'Italian',
#   'dated RP',
#   'Tidewater',
#   'in Notts also',
#   'Texas',
#   'postconsonantal',
#   'when "do" is unstressed and the next word starts with /j/',
#   'attributive adjective',
#   'county',
#   "with ''Mary-marry-merry merger''",
#   'Southern and Midland US',
#   'Malaysian English',
#   'plural of synapsis',
#   'Latin',
#   'after voiceless consonants except /s/',
#   'US-Southwest',
#   'otherwise obsolete',
#   'especially Northeastern US',
#   'hypercorrect',
#   'infinitive',
#   'sometimes US',
#   'AusE',
#   'hyperforeign',
#   'less commonly also',
#   'by dissimilation',
#   'East Coast',
#   'without /æ/-tensing',
#   'mainly noun',
#   'male given name',
#   'long vowel',
#   'Spanish',
#   'city in Maine',
#   'East Anglia',
#   'Malayalam style',
#   'computer science sense',
#   'less common',
#   'father-bother merger',
#   'Northern English',
#   'some non-rhotic accents',
#   'some dialects',
#   'Québecois',
#   'yod dropping',
#   'goodbye',
#   'due to confusion with "our"',
#   'Northern UK',
#   'capitalised title',
#   'village in South Yorkshire',
#   'Canadian Vowel Shift',
#   'UK female',
#   'from French',
#   'accents with the',
#   'United States',
#   'informal or dialectal',
#   'strictly',
#   'traditional or dated for the city in France',
#   'Adjective',
#   'some North American dialects',
#   'as spelled',
#   'GP',
#   'City in England',
#   'Swiss',
#   'Italianate',
#   'humorous',
#   'Some southern English accents',
#   'elsewhere',
#   'Oregon',
#   "''unstressed''",
#   'RP',
#   'US?',
#   'noun form',
#   'grammar',
#   'non-merged vowel',
#   'Singapore English',
#   'infinitive and present tense',
#   'Queensland',
#   'I-double-E',
#   'adjective',
#   'non-standard',
#   'some other UK accents',
#   'th-fronting',
#   'United States of America',
#   'with added n',
#   'Filipino Diaspora',
#   'not past tense or past participle',
#   'with synaeresis',
#   'Malaysia',
#   'International',
#   'Manchester',
#   'Tasmania',
#   'with triphthong smoothing',
#   'dough-door merger',
#   'flapped',
#   'Jamaica',
#   'GAm',
#   'æ-tensing',
#   'U.S.A.',
#   'with cot-caught merger',
#   'St. Louis (Missouri)',
#   'post 44-27 BC',
#   'US also',
#   'Kansas',
#   'Mid-Atlantic',
#   'also',
#   'weak vowel merger',
#   'phoneme',
#   'parts of North America',
#   '/d/ also',
#   'anatomy and zoology',
#   '⟨i⟩ commonly pronounced shorter than in this example',
#   'Western Pennsylvania',
#   'Ohio',
#   'surname',
#   'intransitive',
#   'New Zealand',
#   'especially in the UK',
#   'South Wales',
#   'preconsonantal',
#   'Singaporean English',
#   'dated',
#   'S Africa',
#   'without the',
#   'Aust.',
#   'in the Limbu language',
#   'television',
#   'Washington DC park',
#   'Hungarian',
#   'Iowa',
#   'hard g',
#   'perhaps under influence from Italian',
#   'intrusive r',
#   'Commonwealth',
#   'AUS',
#   'postvocalic',
#   'properly',
#   'beth din',
#   'US - Variant 2',
#   'SA',
#   "''Gryllus pennsylvanicus''",
#   'intervocalic alveolar flapping',
#   'without cot-caught merger',
#   'usually',
#   'older UK',
#   'borrowed from Etymology 2',
#   'Southeastern Midwest of the U.S.',
#   'hyperforeignism',
#   'Aus.',
#   'GB',
#   'less commonly',
#   'rhotic',
#   '[ænti(ː)]',
#   'Gen',
#   'sometimes Southern US',
#   'of a will',
#   'local?',
#   'in rapid speech',
#   'CA - Variant',
#   'sports',
#   'locally also',
#   "men's voice",
#   'US accents',
#   'GA',
#   'for the plural spelled marquis',
#   'Massachusetts',
#   'organic chemistry',
#   'West Country',
#   'Middlesbrough',
#   'Goddess of the Earth',
#   'Child US',
#   '/f/',
#   'RP dated',
#   'US (varieties without the cot-caught merger)',
#   'CA',
#   'spelling pronunciation',
#   'anglicised pronunciation',
#   'Armenian',
#   'noun usage',
#   'rural US',
#   'Irish',
#   'gb',
#   'US city',
#   'Victoria',
#   'Northumberland',
#   'NYC',
#   '/ʃ/',
#   'for some speakers',
#   'with /æ/-tensing',
#   'botany and zoology',
#   'General Australian',
#   'some US cities',
#   'uncommon or dialectal',
#   'Chinese state',
#   'southern US',
#   'surname?',
#   'Jesus of Nazareth',
#   'US dialects',
#   'Classical Latin',
#   'pen-pin merger',
#   'furs',
#   'North East England',
#   'Can',
#   'some US municipalities',
#   'IN',
#   'penultimate stress',
#   'Midwest',
#   'Northeast England',
#   'also found in the US',
#   'cure-force merger',
#   'standard',
#   'mainly verb',
#   'mostly nonstandard',
#   'US dialectal',
#   'US-merged',
#   'for the noun plural',
#   'feminine',
#   'rarely US',
#   'pre-/ŋ/ tensing',
#   'New York City',
#   "without Rosa's roses merger",
#   'noun senses relating to the metal',
#   'South Carolina',
#   "Rosa's roses merger",
#   '9-1-1',
#   'other varieties without the',
#   'The USA',
#   'chemistry',
#   'Southern US folk speech',
#   'NZ',
#   'regional or nonstandard',
#   'Uk',
#   'too',
#   'or the South Vietnamese pronunciation',
#   'obsolete or poetic',
#   'Ireland',
#   'Northern Cities Vowel Shift',
#   'PH',
#   'northeastern US',
#   'interjection',
#   'phone',
#   'bending at the waist',
#   'some other US areas',
#   'w:cot-caught merger',
#   'whine-wine merger',
#   'MI',
#   'street in Manhattan',
#   'especially Philadelphia',
#   'US cot-caught merger',
#   'Appalachian',
#   'formal',
#   'vulgar',
#   'especially sense 3',
#   'US and traditional British English',
#   'Vincent van Gogh',
#   'unstressed',
#   'Mary-marry-merry distinction',
#   'varieties of fruit',
#   'nonstandard US',
#   'alternative pronunciation of the verb',
#   'Southern England',
#   'North of England',
#   'Michigan',
#   'antiquated',
#   'Received Prononunciation',
#   'most places elsewhere',
#   'cure-fir merger'])

# %%
tags_distr = {}
for item in all_items:
    if item.get('tags',None) is None:
        continue
    for tag in item.get('tags'):
        if tags_distr.get(tag) is None:
            tags_distr[tag] = 1
        else:
            tags_distr[tag] +=1
tags_distr

# %%
kvs = [(k,v) for k,v in tags_distr.items()]
kvs = sorted(kvs, key = lambda x: x[1], reverse=True)
tags_distr = {k:v for k,v in kvs}
tags_distr
# Out:
# {'US': 49316,
#  'UK': 36016,
#  'AU': 22623,
#  'Received Pronunciation': 21615,
#  'General American': 19667,
#  'Canada': 2027,
#  'GA': 1444,
#  'General Australian': 1304,
#  'RP': 904,
#  'General New Zealand': 845,
#  'cot-caught merger': 735,
#  'without the horse-hoarse merger': 645,
#  'verb': 488,
#  'noun': 446,
#  'Scotland': 392,
#  'non-rhotic': 385,
#  'rhotic': 373,
#  'CA': 342,
#  'adjective': 306,
#  'Ireland': 284,
#  'Northern England': 251,
#  'phoneme': 244,
#  'NYC': 201,
#  'obsolete': 186,
#  'unstressed': 171,
#  'Northern California': 163,
#  'AUS': 154,
#  'weak vowel merger': 130,
#  'pin-pen merger': 119,
#  'stressed': 118,
#  'Southern American English': 114,
#  'Singapore': 106,
#  'æ-tensing': 100,
#  'dated': 92,
#  'letter name': 87,
#  'AAVE': 84,
#  'also': 82,
#  'Mary-marry-merry merger': 79,
#  'New England': 77,
#  'rare': 74,
#  'nonstandard': 67,
#  'California': 65,
#  'General South African': 64,
#  'without the wine-whine merger': 64,
#  'Wales': 61,
#  'dialectal': 59,
#  'Australia': 55,
#  'main allophones': 55,
#  'India': 53,
#  'Boston': 52,
#  'UK male': 50,
#  'Indian English': 50,
#  'Mary-marry-merry distinction': 49,
#  'US-Inland North': 46,
#  'GB': 44,
#  'colloquial': 43,
#  'U.S.A.': 40,
#  'CAN': 40,
#  'West Country': 39,
#  'MLE': 37,
#  'Southern England': 36,
#  'Conservative RP': 35,
#  'some accents': 35,
#  'adverb': 34,
#  'Midland American English': 32,
#  'Geordie': 31,
#  'Singapore English': 30,
#  'Anglicised': 30,
#  'usually': 29,
#  'Mid-Atlantic': 28,
#  'GenAM': 28,
#  'Classical': 28,
#  'Northern US': 27,
#  'Philadelphia': 27,
#  'it': 26,
#  'archaic': 25,
#  'interjection': 25,
#  'regional US': 25,
#  'Northern Cities Vowel Shift': 25,
#  'Midwestern US': 24,
#  'non-standard': 22,
#  'Tasmanian': 21,
#  'GenAm': 21,
#  'Cockney': 21,
#  'emulating Japanese': 21,
#  'informal': 20,
#  'Southern US folk speech': 19,
#  'US cot-caught merged': 19,
#  'French': 18,
#  'Malaysia': 17,
#  'non-merged vowel': 17,
#  'Appalachia': 16,
#  'North American also': 16,
#  'Southern US': 15,
#  'Estuary English': 15,
#  'Verb': 14,
#  'merged vowel': 14,
#  'UK female': 13,
#  'anglicised': 13,
#  'near-square merger': 13,
#  'St. Louis (Missouri)': 13,
#  'sometimes': 13,
#  'Midlands': 13,
#  'northern cities vowel shift': 13,
#  'sometimes in Northern England': 13,
#  'North America': 13,
#  'verb form': 13,
#  'USA': 12,
#  '/æ/ raising': 12,
#  'pre-/ŋ/ tensing': 12,
#  'Upper RP Triphthong Smoothing': 12,
#  'Ecclesiastical': 12,
#  'uncommon': 11,
#  'imitating the French pronunciation': 11,
#  'Canadian': 11,
#  '(Ireland)': 11,
#  'letter': 11,
#  'r-dissimilation': 11,
#  'Hong Kong': 11,
#  'Australian': 11,
#  'NZ': 11,
#  'Norfolk': 11,
#  'weak vowel distinction': 11,
#  'spelling pronunciation': 11,
#  'now dialectal': 10,
#  'proscribed': 10,
#  'father-bother merger': 10,
#  'for some speakers': 10,
#  'South African': 10,
#  'cure-fir merger': 10,
#  'Irish': 10,
#  'article': 10,
#  'Latinate': 10,
#  'Noun': 10,
#  'England': 9,
#  'Scottish': 9,
#  'standard': 9,
#  'with triphthong smoothing': 9,
#  'otherwise obsolete': 9,
#  'other varieties without the': 9,
#  'without wine-whine': 9,
#  'surname': 9,
#  'wholly-holy split': 9,
#  'Eastern New England': 8,
#  'informal or dialectal': 8,
#  'Yorkshire': 8,
#  'intrusive r': 8,
#  'enunciated': 8,
#  'South Wales': 8,
#  'AusE': 8,
#  'Philippine': 8,
#  'Jesus of Nazareth': 8,
#  'Spanish given name': 8,
#  'by analogy to arc': 8,
#  'Latin': 8,
#  'anglicized': 8,
#  'Chinese state': 8,
#  'noun form': 8,
#  'for the noun plural': 8,
#  'rural areas of Scotland': 8,
#  'northern US': 8,
#  'nautical': 7,
#  'Jamaica': 7,
#  "''unstressed''": 7,
#  'Nigeria': 7,
#  'in accents with the wine-whine merger': 7,
#  'Swiss': 7,
#  'US with /u/': 7,
#  'some US dialects': 7,
#  'Northern English': 7,
#  'non-rhotic accents': 7,
#  'Yiddish-influenced': 7,
#  'plural': 7,
#  'English Midlands': 7,
#  'Sense 1': 7,
#  'Sense 2': 7,
#  'IPA': 7,
#  'Welsh English': 7,
#  'British Isles': 6,
#  'East Coast': 6,
#  'regional': 6,
#  'after a vowel': 6,
#  'Appalachian': 6,
#  'intrusive R': 6,
#  'have to': 6,
#  'nonstandard but traditional': 6,
#  'several locations': 6,
#  "''stressed''": 6,
#  "''US''": 6,
#  'to': 6,
#  'New York': 6,
#  'alternative pronunciation of the verb': 6,
#  'naval': 6,
#  'US and Canada': 6,
#  'Northern UK': 6,
#  'after voiceless consonants except /s/': 6,
#  '/ʃ/': 6,
#  '/t͡ʃ/': 6,
#  'elsewhere': 6,
#  'after /t/': 6,
#  '/d/ also': 6,
#  'in some senses': 6,
#  'predicative adjective': 6,
#  'with syncope': 6,
#  'strictly': 6,
#  'cot-caught merged': 6,
#  '9/11': 6,
#  'especially Philadelphia': 6,
#  'New Jersey': 6,
#  'sometimes Southern US': 6,
#  'non-standard except Ireland': 6,
#  'Austr': 6,
#  'long vowel': 6,
#  'short vowel': 6,
#  'Ulster English': 6,
#  'depending on the word taking the suffix': 6,
#  'southern US': 6,
#  'Malaysian English': 6,
#  'Virginia': 5,
#  'th-fronting': 5,
#  'in': 5,
#  'strong': 5,
#  'Tidewater': 5,
#  'UK with /ʊ/': 5,
#  'Northern': 5,
#  'Michigan': 5,
#  'US-merged': 5,
#  'some New England and Southern American dialects': 5,
#  'CA - Variant': 5,
#  'other dialects in the UK': 5,
#  'rhotic accents': 5,
#  'more common realization': 5,
#  'local': 5,
#  'CA synth': 5,
#  'dough-door merger': 5,
#  'without the': 5,
#  'locally': 5,
#  'singular': 5,
#  'sometimes proscribed': 5,
#  'humorous': 5,
#  'U.S.': 5,
#  'sports': 5,
#  'Australian English': 5,
#  'given name': 5,
#  'anglicised pronunciation': 5,
#  'attributive': 4,
#  'variant': 4,
#  'due to confusion with "our"': 4,
#  'parts of South Africa': 4,
#  'unstressed or': 4,
#  'perhaps modeled on piece etc': 4,
#  'or the South Vietnamese pronunciation': 4,
#  'parts of the US and Canada': 4,
#  'mostly nonstandard': 4,
#  'Commonwealth': 4,
#  'some speakers': 4,
#  'colloquially': 4,
#  'Western US': 4,
#  'w:cot-caught merger': 4,
#  'w:northern cities vowel shift': 4,
#  'Manchester': 4,
#  'when "do" is unstressed and the next word starts with /j/': 4,
#  'some other US dialects': 4,
#  'more anglicized': 4,
#  'not past tense or past participle': 4,
#  'past tense and past participle': 4,
#  'Adjective': 4,
#  'US/UK': 4,
#  'in accents with the cot-caught merger': 4,
#  'paragon': 4,
#  'UK dialectal': 4,
#  'obsolete elsewhere': 4,
#  "'a rabbit'": 4,
#  'some Northern English accents': 4,
#  'regional or nonstandard': 4,
#  'rural US': 4,
#  'poetic': 4,
#  'obsolete or poetic': 4,
#  'hyperforeign': 4,
#  'Received Prononunciation': 4,
#  'with the': 4,
#  'North East England': 4,
#  'preposition': 4,
#  'television': 4,
#  '2': 4,
#  'Uk': 4,
#  'RP dated': 4,
#  'as an unstressed': 4,
#  'capitalised title': 4,
#  'before consonants': 4,
#  'before vowels': 4,
#  'regional US and England': 4,
#  'less commonly': 4,
#  'New York City': 4,
#  'less common': 4,
#  'auxiliary': 4,
#  'hypercorrection': 4,
#  'Northern English accents': 4,
#  'some other UK accents': 4,
#  'US accents': 4,
#  'slang': 4,
#  'US and Central Canada': 4,
#  'some North American dialects': 4,
#  'adjective: clearly evident': 4,
#  'anatomy and zoology': 4,
#  'botany and zoology': 4,
#  'architecture and zoology': 4,
#  'chemistry': 4,
#  'organic chemistry': 4,
#  'US dialectal': 4,
#  'yod-coalescence': 4,
#  'especially Northeastern US': 4,
#  'US only': 4,
#  'and Estuary English': 4,
#  'after sibilant': 4,
#  "Rosa's roses merger": 4,
#  'Singaporean English': 4,
#  'transitive': 4,
#  'past': 4,
#  'GAm': 4,
#  'proper-noun': 4,
#  'Canadian English': 4,
#  'antepenultimate stress': 4,
#  'penultimate stress': 4,
#  'Classical Latin': 4,
#  'Us': 4,
#  'postpositive': 3,
#  'preconsonantal': 3,
#  'Canada: British Columbia': 3,
#  'Canada: Ontario': 3,
#  'Dublin / East': 3,
#  'multicultural London also': 3,
#  'Cajun': 3,
#  'weak': 3,
#  'nonstandard US': 3,
#  'New Zealand': 3,
#  'some Northern Enɡlish dialects': 3,
#  'esp. Bolton': 3,
#  'Liverpool usually': 3,
#  'past participle': 3,
#  'North-East England': 3,
#  'Great Lakes': 3,
#  'yod coalescence': 3,
#  "without ''Mary-marry-merry'' merger": 3,
#  "with ''Mary-marry-merry merger''": 3,
#  'Northern and Western': 3,
#  'Southern': 3,
#  'rarely US': 3,
#  'Tasmania': 3,
#  'Middlesbrough': 3,
#  'North American': 3,
#  'yod dropping': 3,
#  'all senses': 3,
#  'alternative for adjective or noun senses': 3,
#  'UK RP': 3,
#  'after a vowel or a voiced consonant other than a /d/': 3,
#  'after a voiceless consonant other than a /t/': 3,
#  'formerly also UK': 3,
#  'now chiefly dialect': 3,
#  'Francophone': 3,
#  'alternatively': 3,
#  'US Inland North': 3,
#  'US military command': 3,
#  'German': 3,
#  'irregular': 3,
#  'but common': 3,
#  'borrowed from Etymology 2': 3,
#  'Child US': 3,
#  'South Asia': 3,
#  'attributive adjective': 3,
#  'Oregon': 3,
#  'Pakistani English': 3,
#  'female given name': 3,
#  'especially Nevada': 3,
#  'Eastern US': 3,
#  'Rhode Island': 3,
#  'military': 3,
#  '9-1-1': 3,
#  'S Africa': 3,
#  'also especially the variant "Mariah"': 3,
#  'US historical': 3,
#  'abbreviation': 3,
#  'without wholly-holy split': 3,
#  'emphatic': 3,
#  'slow speech': 3,
#  'fast speech': 3,
#  'Germanic': 3,
#  'technical': 3,
#  'Spanish': 3,
#  'native pronunciation': 3,
#  'of the adjectival and singular nounal sense': 3,
#  'of the plural nounal sense': 3,
#  'Dutch': 3,
#  'GP': 3,
#  '[ænti(ː)]': 3,
#  '⟨i⟩ commonly pronounced shorter than in this example': 3,
#  '[æntaɪ]': 3,
#  'Bristolian': 3,
#  'noun and adjective': 3,
#  'Wisconsin': 3,
#  'town in Dorset': 3,
#  'grammar': 2,
#  'engineering': 2,
#  'anatomy sense': 2,
#  'other regions': 2,
#  '“to be”': 2,
#  "especially in the sense ‘an ailment'": 2,
#  'Weak-vowel merger': 2,
#  'PH': 2,
#  'phone': 2,
#  'sculpture': 2,
#  'Broad Geordie': 2,
#  'Kenya': 2,
#  'in the medical sense': 2,
#  'Macquarie Dictionary': 2,
#  '/æ/ tensing': 2,
#  'particularly common in the Great Lakes': 2,
#  'Midwest': 2,
#  'in compounds like "twopenny"': 2,
#  'Scouse': 2,
#  'northeastern US': 2,
#  'older southern US': 2,
#  'uncommon or dialectal': 2,
#  'in rapid speech': 2,
#  'Victoria': 2,
#  '“to translate”': 2,
#  'distinctive cot-caught': 2,
#  'closer to Arabic': 2,
#  'some dialects': 2,
#  'Upper Midwest': 2,
#  'Contemporary RP': 2,
#  '“to sleep”': 2,
#  'US South': 2,
#  'many US accents': 2,
#  'parts of Ontario': 2,
#  'Ontario': 2,
#  'electronics': 2,
#  'computing': 2,
#  'video games': 2,
#  'dialects with the father-bother merger': 2,
#  'very dated': 2,
#  'Can': 2,
#  'Canadian raising': 2,
#  'meal eaten after religious fasting': 2,
#  'Hawaii': 2,
#  'parts of North America': 2,
#  'parts of the UK': 2,
#  'Inland North': 2,
#  'pen-pin merger': 2,
#  'medical': 2,
#  'less commonly also': 2,
#  'too': 2,
#  'two': 2,
#  'Slang': 2,
#  'Iowa': 2,
#  'some US speakers': 2,
#  'most US speakers': 2,
#  'some Irish speakers': 2,
#  'US regional': 2,
#  'Some southern English accents': 2,
#  '"a ticket"': 2,
#  'cure-force merger': 2,
#  'with diphthong': 2,
#  'without diphthong': 2,
#  'United States': 2,
#  'no weak vowel merger': 2,
#  'soft C': 2,
#  'other senses': 2,
#  'more common in casual speech': 2,
#  'Southeastern Midwest of the U.S.': 2,
#  'South Carolina': 2,
#  'Italianate': 2,
#  'locally also': 2,
#  'Irish English': 2,
#  'US also': 2,
#  'team sports senses': 2,
#  'especially in the U.S.': 2,
#  'non standard': 2,
#  'Northumberland': 2,
#  'Aust': 2,
#  'US dialects': 2,
#  'especially': 2,
#  'formal': 2,
#  'gb': 2,
#  'Estuary': 2,
#  'Cultivated Australian': 2,
#  'cousin': 2,
#  'because': 2,
#  'rural folk speech of New England and Upstate New York': 2,
#  'US cot-caught merger': 2,
#  'without cot-caught merger': 2,
#  'past of use': 2,
#  'US (varieties without the cot-caught merger)': 2,
#  'US (varieties with the cot-caught merger)': 2,
#  'Western Pennsylvania': 2,
#  'other accents without the "Hurry-furry" merger': 2,
#  'SA': 2,
#  'weak-vowel merger': 2,
#  'noun usage': 2,
#  'derogatory': 2,
#  'vulgar': 2,
#  'Washington': 2,
#  'American': 2,
#  'United Kingdom': 2,
#  'by dissimilation': 2,
#  'Western Canada': 2,
#  'possibly dated outside the local dialect': 2,
#  'in the local dialect': 2,
#  'with synaeresis': 2,
#  'Individual Retirement Account': 2,
#  'URP': 2,
#  'laxly': 2,
#  'Somerset': 2,
#  'male given name': 2,
#  'older': 2,
#  'Chicago': 2,
#  'US-Rhode Island': 2,
#  'masculine': 2,
#  'unstressed before a vowel': 2,
#  'unstressed elsewhere': 2,
#  'accents with the': 2,
#  'Regional American': 2,
#  'short pronunciation': 2,
#  'Filipino Diaspora': 2,
#  'some non-rhotic accents': 2,
#  'Latinized': 2,
#  'mainly noun': 2,
#  'mainly verb': 2,
#  'computer science meaning': 2,
#  'Northern Ireland': 2,
#  'Goddess of the Earth': 2,
#  'AU/NZ': 2,
#  'London': 2,
#  'South West England': 2,
#  'diminutive of Giles': 2,
#  'Julian': 2,
#  'Gillian': 2,
#  'diminutive of Wiliam': 2,
#  'Gillingham FC person': 2,
#  'younger speakers in the UK': 2,
#  'accents with the "Hurry-furry" merger': 2,
#  'accents without the "Hurry-furry" merger': 2,
#  'original Russian': 2,
#  'as spelled': 2,
#  'imitation of snoring': 2,
#  'The USA': 2,
#  'modern': 2,
#  'alternate UK pronunciation': 2,
#  'noun senses relating to the metal': 2,
#  'verb senses derived from the noun': 2,
#  'verb senses relating to guiding or conducting': 2,
#  'noun senses derived from the verb': 2,
#  'traditional New England': 2,
#  'CDP in Pennsylvania': 2,
#  'after a vowel or a voiced consonant other than a sibilant': 2,
#  'after voiceless consonants /p/': 2,
#  '/t/': 2,
#  '/k/': 2,
#  '/f/': 2,
#  'or /θ/': 2,
#  'reduced': 2,
#  '1': 2,
#  'Spanish-influenced': 2,
#  'trap-bath split': 2,
#  'careful': 2,
#  'intensifier': 2,
#  'bending at the waist': 2,
#  'old-fashioned RP': 2,
#  'some Lithuanian Ashkenazim': 2,
#  'after vowel sound': 2,
#  'RP spelling pronunciation': 2,
#  'especially sense 3': 2,
#  'partly anglicised': 2,
#  'Gen': 2,
#  'as a French name': 2,
#  'on a minute scale': 2,
#  'happening every minute': 2,
#  "''Gryllus pennsylvanicus''": 2,
#  'A musical or piquet term': 2,
#  'or a quintuplet': 2,
#  'plural of synapse': 2,
#  'plural of synapsis': 2,
#  'UK and US': 2,
#  'Des Moines': 2,
#  'with and': 2,
#  'Italian': 2,
#  'Magdalen College': 2,
#  'placenames in Oxford and Cambridge': 2,
#  'varieties of fruit': 2,
#  'weak vowel': 2,
#  'US?': 2,
#  'Netherlands': 2,
#  'Vincent van Gogh': 2,
#  'Caribbean': 2,
#  'plural of periphrase': 2,
#  'plural of periphrasis': 2,
#  'Alternative form': 2,
#  'native': 2,
#  'non-naturalized pronunciation': 2,
#  'Scot': 2,
#  'UK English': 2,
#  'hockey team': 2,
#  'properly': 2,
#  'commonly': 2,
#  'beit din': 2,
#  'beis din': 2,
#  'whine-wine merger': 2,
#  'Jewish': 2,
#  'Malayalam style': 2,
#  'Hindi style': 2,
#  'county': 2,
#  'North Wales': 2,
#  'in dialects without the': 2,
#  'in dialects with the': 2,
#  'village in South Yorkshire': 2,
#  'city in Washington': 2,
#  'Canadian Vowel Shift': 2,
#  'hyperforeignism': 2,
#  'Aust.': 2,
#  'East Anglia': 2,
#  'Essex': 2,
#  'Hampshire': 2,
#  'New Hampshire': 2,
#  'French placename': 2,
#  'approximating the Norse and Icelandic pronunciations': 2,
#  'Rochdale': 2,
#  'variously': 2,
#  'antiquated': 1,
#  'International': 1,
#  'US-Southwest': 1,
#  'West': 1,
#  'Indiana': 1,
#  'Puerto Rican': 1,
#  'in accents without the merger': 1,
#  'sometimes US': 1,
#  'US and traditional British English': 1,
#  'some US': 1,
#  'some other US areas': 1,
#  'Maritimes': 1,
#  'occasionally': 1,
#  'Midland': 1,
#  'North of England': 1,
#  'Structured Query Language': 1,
#  'United States of America': 1,
#  'in the Limbu language': 1,
#  'IN': 1,
#  '‘to forget’': 1,
#  'infinitive': 1,
#  'simple past': 1,
#  'now regional': 1,
#  'nonstandard UK': 1,
#  'by haplology': 1,
#  'some US cities': 1,
#  'UK &ndash': 1,
#  'especially in Dublin': 1,
#  '(traditional) Eastern New England Irish English': 1,
#  'chiefly Midwestern': 1,
#  'also found in the US': 1,
#  'found in the US': 1,
#  'perhaps under influence from Italian': 1,
#  'British Columbia': 1,
#  'Tripoli': 1,
#  'distinguished from proscribe': 1,
#  'with weak-vowel merger': 1,
#  'when conjugated as contributing or contributed': 1,
#  'traditional British pronunciation': 1,
#  'now virtually obsolete': 1,
#  'humourous': 1,
#  'otherwise': 1,
#  'of a will': 1,
#  'Midland English dialect': 1,
#  "women's voice": 1,
#  'Minnesota native dialect': 1,
#  "men's voice": 1,
#  'has to': 1,
#  'to approximate the French pronunciation': 1,
#  'mountain': 1,
#  'George Everest and family': 1,
#  'North Durham': 1,
#  'from French': 1,
#  'Thai': 1,
#  'hypercorrect': 1,
#  'lax': 1,
#  'flapped': 1,
#  'francophonic': 1,
#  'Rare': 1,
#  'postvocalic': 1,
#  'postconsonantal': 1,
#  'Northeast England': 1,
#  'with cot-caught merger': 1,
#  'extremely rare': 1,
#  'Scots': 1,
#  'in casual speech': 1,
#  'see note': 1,
#  'Standard Canadian': 1,
#  'Irish Republican Army': 1,
#  'Audio': 1,
#  'US female': 1,
#  'one pronunciation': 1,
#  'haplology': 1,
#  'US /kɑləˈrɑdoʊ/ variant': 1,
#  'US /kɑləˈrædoʊ/ variant': 1,
#  'now nonstandard in reference to the state': 1,
#  'some US municipalities': 1,
#  'Vermont': 1,
#  'with added n': 1,
#  'without weak vowel merger': 1,
#  'river starting in the Cairngorms': 1,
#  'UK also': 1,
#  'town in Massachusetts': 1,
#  'town and village in New York': 1,
#  'Standard Hawaiian English': 1,
#  'plural of antipode': 1,
#  'Polish pronunciation': 1,
#  'synthesized': 1,
#  'feminine': 1,
#  'without /æ/-tensing': 1,
#  'with /æ/-tensing': 1,
#  'Kerala': 1,
#  '<span class="IPA">/beɪˈdʒɪŋ/</span>': 1,
#  'colloquial or dialectal': 1,
#  'Old-fashioned RP': 1,
#  'longer pronunciation': 1,
#  'Southern and Midland US': 1,
#  'formerly': 1,
#  'now commonly': 1,
#  'US - Variant 1': 1,
#  'US - Variant 2': 1,
#  'predicative': 1,
#  'with Grecian stress': 1,
#  'with Latinate stress': 1,
#  'Santa Clara': 1,
#  'Francophonic': 1,
#  'also UK': 1,
#  'NCVS': 1,
#  'Gaia hypothesis': 1,
#  'T-flapping': 1,
#  'California English': 1,
#  'places in China': 1,
#  'most places elsewhere': 1,
#  'anglicized alternative pronunciation of the given name': 1,
#  'older UK': 1,
#  'initialism': 1,
#  'acronym': 1,
#  'river': 1,
#  'Philippine English': 1,
#  'especially in the UK': 1,
#  'for one pronunciation': 1,
#  'US-California': 1,
#  'London avenue': 1,
#  'Washington DC park': 1,
#  'rivers in England and Canada': 1,
#  'town in New Zealand': 1,
#  'river in Connecticut': 1,
#  'Lojban-like': 1,
#  'for the plural spelled marquis': 1,
#  'without the merger': 1,
#  'usa': 1,
#  'nonstandard outside dialects': 1,
#  'Hungarian': 1,
#  'Demi Moore': 1,
#  'Demi Lovato etc.': 1,
#  'dated RP': 1,
#  'for the decade': 1,
#  'rapid': 1,
#  'intervocalic alveolar flapping': 1,
#  'past tense and participle': 1,
#  'some Ashkenazim': 1,
#  'Rioplatense': 1,
#  'nickname of New York': 1,
#  'setting of the Batman franchise': 1,
#  'English village': 1,
#  'Armenian': 1,
#  'emulating French': 1,
#  'with intrusive r': 1,
#  'city in Maine': 1,
#  'traditional or dated for the city in France': 1,
#  'intransitive': 1,
#  'soft g': 1,
#  'hard g': 1,
#  'county in Georgia': 1,
#  'street in Manhattan': 1,
#  'sometimes the surname': 1,
#  'infinitive and present tense': 1,
#  '</span><span class="ib-content qualifier-content">US</span><span class="ib-brac qualifier-brac">': 1,
#  "without Rosa's roses merger": 1,
#  'A fencing term': 1,
#  'Italian-like': 1,
#  'chiefly US': 1,
#  '</span><span class="ib-content qualifier-content">[[w:Australian English phonology|General Australian]]</span><span class="ib-brac qualifier-brac">': 1,
#  'furs': 1,
#  'peens': 1,
#  'paeans': 1,
#  'German origin': 1,
#  'Scottish English': 1,
#  'no wine-whine merger': 1,
#  'wine-whine merger': 1,
#  'cathedral': 1,
#  'university': 1,
#  'Quebec English': 1,
#  'town in Georgia': 1,
#  'present': 1,
#  'Québecois': 1,
#  'close-in weapon system': 1,
#  'computer science sense': 1,
#  'ante 44-27 BC': 1,
#  'post 44-27 BC': 1,
#  'Switzerland': 1,
#  'Germany': 1,
#  'Aus/NZ': 1,
#  'as in tartare sauce': 1,
#  'respectively': 1,
#  'hooray': 1,
#  'goodbye': 1,
#  'faithful to Latin original': 1,
#  'recycling plant': 1,
#  "short vowel /i/ in ''anti-''": 1,
#  "diphthong /aɪ̯/ for ''i'' in ''anti-''": 1,
#  'beth din': 1,
#  'Kansas': 1,
#  'BR': 1,
#  'English': 1,
#  'Hindustani': 1,
#  'MI': 1,
#  'Mayan': 1,
#  'Hiberno-English': 1,
#  'Georgian': 1,
#  'SAfrica': 1,
#  'town in County Durham': 1,
#  'what she said': 1,
#  'what he said': 1,
#  'Britain': 1,
#  'sense 1': 1,
#  'sense 2': 1,
#  'Queensland': 1,
#  'SE': 1,
#  'double-I-H-F': 1,
#  'I-I-H-F': 1,
#  'plural-only': 1,
#  'US city': 1,
#  'anglicized pronunciation': 1,
#  'Greek pronunciation': 1,
#  'proscribed spelling pronunciation': 1,
#  'Northumbrian': 1,
#  'village in Ohio': 1,
#  'Pakistan': 1,
#  'town in Kent': 1,
#  'City in England': 1,
#  'Alberta': 1,
#  'Ocracoke Island (in the Outer Banks of North Carolina)': 1,
#  'ga': 1,
#  'SIN': 1,
#  'Quebec': 1,
#  'I-double-E': 1,
#  'I-E-E': 1,
#  'local?': 1,
#  'in Notts also': 1,
#  'UK (places)': 1,
#  'Massachusetts': 1,
#  'northern Hiberno-English': 1,
#  'southern Hiberno-English': 1,
#  'Aus.': 1,
#  'surname?': 1,
#  'Texas': 1,
#  'US placename': 1,
#  'Georgia': 1,
#  'traditional elsewhere': 1,
#  'widespread spelling pronunciation': 1,
#  'New York State': 1,
#  'Ohio': 1,
#  'Malaysia & Singapore': 1,
#  'Cornwall': 1,
#  'Mauricie': 1,
#  'town and river in England': 1,
#  'river in Wales': 1,
#  'parts of US': 1,
#  'approximating the Norse and Icelandic pronunciation': 1,
#  'male US voice': 1,
#  'County Durham': 1,
#  'Lincolnshire': 1}

# %%
general_tags = ['US','UK','AU','Received Pronunciation','General American','Canada']

# %%
# 36541 ['US','UK','AU','Received Pronunciation','General American','Canada']
# 53822 ['US','UK','Received Pronunciation','General American','Canada']  - AU
# 55407 ['US','UK','Received Pronunciation']
# 38031 ['US','UK','Received Pronunciation','AU']
# 37874 ['US','UK','Received Pronunciation','AU','Canada']
# 36682 ['US','UK','Received Pronunciation','AU','General American']
# 53973 ['US','UK','Received Pronunciation','General American']
# 64273 ['US','UK']

# %%
def test_sounds_with_general_tags():
    n_word_missing = 0
    examples = []
    for word in data:
        sounds = word['sounds']
        flag = False
        for sound in sounds:
            if sound.get('tags') is None:
                continue
            else:
                intersected = set(sound['tags']).intersection(general_tags)
                if len(intersected) > 0:
                    flag = True
        if not flag:
            n_word_missing +=1
            examples.append(word)
    return n_word_missing, examples

word_missing, examples = test_sounds_with_general_tags()

word_missing
# Out:
# 64273

# %%
def sounds_without_tags():
    n_word_missing = 0
    examples = []
    for word in data:
        sounds = word['sounds']
        all_keys = set(
            sum(
                [list(s.keys()) for s in sounds],
                []
            )
        )
        if 'tags' not in all_keys:
            n_word_missing+=1
            examples.append(word)
    return n_word_missing, examples

# %%
def sounds_without_ipa():
    n_word_missing = 0
    examples = []
    for word in data:
        sounds = word['sounds']
        all_keys = set(
            sum(
                [list(s.keys()) for s in sounds],
                []
            )
        )
        if 'ipa' not in all_keys:
            n_word_missing+=1
            examples.append(word)
    return n_word_missing, examples

# %%
n2,ex2 = sounds_without_ipa()
n2, ex2[:10]
# Out:
# (25248,
#  [{'_id': ObjectId('60544a9311fe31d283dedc2b'),
#    'word': 'rain cats and dogs',
#    'sounds': [{'audio': 'En-au-rain cats and dogs.ogg',
#      'tags': ['AU'],
#      'text': 'Audio (AU)'}]},
#   {'_id': ObjectId('60544a9311fe31d283dedc6c'),
#    'word': 'fabaceous',
#    'sounds': [{'rhymes': '-eɪʃəs'}]},
#   {'_id': ObjectId('60544a9311fe31d283dedc89'),
#    'word': 'abacination',
#    'sounds': [{'rhymes': '-eɪʃən'}]},
#   {'_id': ObjectId('60544a9311fe31d283deddad'),
#    'word': 'abluvion',
#    'sounds': [{'rhymes': '-uːviən'}]},
#   {'_id': ObjectId('60544a9411fe31d283dede0d'),
#    'word': 'abray',
#    'sounds': [{'rhymes': '-eɪ'}]},
#   {'_id': ObjectId('60544a9411fe31d283dede86'),
#    'word': 'crude oil',
#    'sounds': [{'audio': 'En-uk-crude oil.ogg',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'}]},
#   {'_id': ObjectId('60544a9411fe31d283dedf2a'),
#    'word': 'acceptilation',
#    'sounds': [{'rhymes': '-eɪʃən'}]},
#   {'_id': ObjectId('60544a9411fe31d283dedf31'),
#    'word': 'accessive',
#    'sounds': [{'rhymes': '-ɛsɪv'}]},
#   {'_id': ObjectId('60544a9411fe31d283dedf32'),
#    'word': 'accessive',
#    'sounds': [{'rhymes': '-ɛsɪv'}]},
#   {'_id': ObjectId('60544a9411fe31d283dedf59'),
#    'word': 'accombination',
#    'sounds': [{'rhymes': '-eɪʃən'}]}])

# %%
n,ex = sounds_without_tags()
n
# Out:
# 35273

# %%
all_items = []
for o in data:
    all_items.extend(o['sounds'])
    
a,b,c = get_uniq_keys(all_items)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='283939' class='' max='283939' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [283939/283939 00:00<00:00]
#     </div>

# %%
a,b,c
# Out:
# (['other', 'audio', 'homophone', 'ipa', 'tags', 'rhymes', 'enpr', 'text'],
#  {'ipa': ['/ənˌsəɪ.kləˈpi.di.ə/', '/ɪnˌsaɪ.kləˈpi(ː).di.ə/', '/paɪz/'],
#   'tags': [['Canada'], ['UK', 'US'], ['US']],
#   'rhymes': ['-iːdiə', '-aɪz', '-aɪz'],
#   'audio': ['en-us-encyclopedia.ogg',
#    'LL-Q1860 (eng)-Vealhurl-pies.wav',
#    'LL-Q1860 (eng)-Vealhurl-pies.wav'],
#   'text': ['Audio (US)', 'Audio (UK)', 'Audio (UK)'],
#   'homophone': ['book', 'book', 'book'],
#   'enpr': ['bo͝ok', 'bo͞ok', 'bo͝ok'],
#   'other': ['/j/', '/ˈfɛb.ɹi/', '/ɹə.ɹi/']},
#  {'ipa': 147804,
#   'tags': 157236,
#   'rhymes': 44114,
#   'audio': 65111,
#   'text': 64840,
#   'homophone': 11019,
#   'enpr': 14691,
#   'other': 1200})

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc19'),
#   'word': 'encyclopaedia',
#   'sounds': [{'ipa': '/ənˌsəɪ.kləˈpi.di.ə/', 'tags': ['Canada']},
#    {'ipa': '/ɪnˌsaɪ.kləˈpi(ː).di.ə/', 'tags': ['UK', 'US']},
#    {'rhymes': '-iːdiə'},
#    {'audio': 'en-us-encyclopedia.ogg', 'tags': ['US'], 'text': 'Audio (US)'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc1a'),
#   'word': 'pies',
#   'sounds': [{'ipa': '/paɪz/'},
#    {'rhymes': '-aɪz'},
#    {'audio': 'LL-Q1860 (eng)-Vealhurl-pies.wav',
#     'tags': ['UK'],
#     'text': 'Audio (UK)'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc1b'),
#   'word': 'pies',
#   'sounds': [{'ipa': '/paɪz/'},
#    {'rhymes': '-aɪz'},
#    {'audio': 'LL-Q1860 (eng)-Vealhurl-pies.wav',
#     'tags': ['UK'],
#     'text': 'Audio (UK)'}]}]

# %%
distr,samples = len_distribution(data,'sounds')

# %%
distr, samples
# Out:
# ({1: 50623,
#   2: 23686,
#   3: 16438,
#   4: 10303,
#   5: 5488,
#   6: 3245,
#   7: 1750,
#   8: 1097,
#   9: 721,
#   10: 487,
#   11: 326,
#   12: 211,
#   13: 154,
#   14: 112,
#   15: 58,
#   16: 50,
#   17: 49,
#   18: 43,
#   19: 18,
#   20: 16,
#   21: 28,
#   22: 21,
#   23: 4,
#   24: 7,
#   26: 3,
#   27: 3,
#   33: 4,
#   36: 2,
#   40: 2,
#   43: 13,
#   44: 2,
#   48: 2},
#  {4: {'_id': ObjectId('60544a9311fe31d283dedc19'),
#    'word': 'encyclopaedia',
#    'sounds': [{'ipa': '/ənˌsəɪ.kləˈpi.di.ə/', 'tags': ['Canada']},
#     {'ipa': '/ɪnˌsaɪ.kləˈpi(ː).di.ə/', 'tags': ['UK', 'US']},
#     {'rhymes': '-iːdiə'},
#     {'audio': 'en-us-encyclopedia.ogg',
#      'tags': ['US'],
#      'text': 'Audio (US)'}]},
#   3: {'_id': ObjectId('60544a9311fe31d283dedc1a'),
#    'word': 'pies',
#    'sounds': [{'ipa': '/paɪz/'},
#     {'rhymes': '-aɪz'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-pies.wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'}]},
#   2: {'_id': ObjectId('60544a9311fe31d283dedc1e'),
#    'word': 'livre',
#    'sounds': [{'ipa': '/ˈliːvɹə/'}, {'ipa': '/ˈliːvə(ɹ)/'}]},
#   9: {'_id': ObjectId('60544a9311fe31d283dedc20'),
#    'word': 'book',
#    'sounds': [{'ipa': '/bʊk/'},
#     {'ipa': '/buːk/'},
#     {'rhymes': '-ʊk'},
#     {'homophone': 'book'},
#     {'audio': 'en-us-book.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-books.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'En-uk-book.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'enpr': 'bo͝ok'},
#     {'enpr': 'bo͞ok'}]},
#   7: {'_id': ObjectId('60544a9311fe31d283dedc23'),
#    'word': 'portmanteau',
#    'sounds': [{'ipa': '/pɔːtˈmæn.təʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/pɔːɹtˈmæntoʊ/', 'tags': ['US']},
#     {'ipa': '/ˌpɔːɹtmænˈtoʊ/', 'tags': ['US']},
#     {'audio': 'en-us-portmanteau-1.ogg',
#      'tags': ['US'],
#      'text': 'Audio 1 (US)'},
#     {'audio': 'en-us-portmanteau-2.ogg',
#      'tags': ['US'],
#      'text': 'Audio 2 (US)'},
#     {'audio': 'en-au-portmanteau.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'},
#     {'enpr': "pôrtmă'ntō"}]},
#   1: {'_id': ObjectId('60544a9311fe31d283dedc2b'),
#    'word': 'rain cats and dogs',
#    'sounds': [{'audio': 'En-au-rain cats and dogs.ogg',
#      'tags': ['AU'],
#      'text': 'Audio (AU)'}]},
#   6: {'_id': ObjectId('60544a9311fe31d283dedc30'),
#    'word': 'august',
#    'sounds': [{'ipa': '/ɔːˈɡʌst/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɔːˈɡʌst/', 'tags': ['General American']},
#     {'ipa': '/ə-/', 'tags': ['General American']},
#     {'rhymes': '-ʌst'},
#     {'audio': 'en-us-august.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'audio': 'en-au-august.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'}]},
#   10: {'_id': ObjectId('60544a9311fe31d283dedc41'),
#    'word': 'cat',
#    'sounds': [{'ipa': '/kæt/', 'tags': ['US', 'UK']},
#     {'ipa': '[kʰæt]', 'tags': ['US', 'UK']},
#     {'ipa': '[kʰæt̚]', 'tags': ['US', 'UK']},
#     {'ipa': '/kat/', 'tags': ['UK']},
#     {'rhymes': '-æt'},
#     {'homophone': 'cat'},
#     {'audio': 'En-uk-a cat.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'audio': 'En-us-cat.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'En-us-inlandnorth-cat.ogg',
#      'tags': ['US-Inland North'],
#      'text': 'Audio (US-Inland North)'},
#     {'enpr': 'kăt'}]},
#   5: {'_id': ObjectId('60544a9311fe31d283dedc51'),
#    'word': 'October',
#    'sounds': [{'ipa': '/ɒkˈtəʊbə/', 'tags': ['UK']},
#     {'ipa': '/ɑkˈtoʊbəɹ/', 'tags': ['US']},
#     {'ipa': '[ɑkˈtʰoʊbɚ]', 'tags': ['US']},
#     {'audio': 'en-us-October.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'äk-tōʹbər'}]},
#   8: {'_id': ObjectId('60544a9311fe31d283dedc74'),
#    'word': 'September',
#    'sounds': [{'ipa': '/sɛpˈtɛmbə/', 'tags': ['UK']},
#     {'ipa': '/səpˈ-/', 'tags': ['UK']},
#     {'ipa': '/sɛpˈtɛmbəɹ/', 'tags': ['US']},
#     {'ipa': '/səpˈ-/', 'tags': ['US']},
#     {'rhymes': '-ɛmbə(r)'},
#     {'audio': 'en-us-September.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'sĕp-tĕmʹbə'},
#     {'enpr': 'sĕp-tĕmʹbər'}]},
#   11: {'_id': ObjectId('60544a9311fe31d283dedca1'),
#    'word': 'Wednesday',
#    'sounds': [{'ipa': '/ˈwɛnzdeɪ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈwɛnzdi/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈwɛnzdɪ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈwɛdnz-/', 'tags': ['Received Pronunciation']},
#     {'ipa': '[ˈwɛ-~ˈwe-]', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈwɛnzdeɪ/', 'tags': ['General American']},
#     {'ipa': '/ˈwɛnzdi/', 'tags': ['General American']},
#     {'ipa': '/ˈwenzdæe/', 'tags': ['General New Zealand']},
#     {'ipa': '/ˈwɛ(ʔə)nzde/', 'tags': ['Scotland']},
#     {'audio': 'en-us-Wednesday.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'En-uk-Wednesday.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'}]},
#   14: {'_id': ObjectId('60544a9311fe31d283dedca5'),
#    'word': 'February',
#    'sounds': [{'ipa': '/ˈfɛb.ɹʊ.ə.ɹi/', 'tags': ['UK']},
#     {'ipa': '/ˈfɛb.j(ʊ.)ə.ɹi/', 'tags': ['UK']},
#     {'ipa': '/ˈfɛb.ɹə.ɹi/', 'tags': ['UK']},
#     {'ipa': '/ˈfɛb.ɹi/', 'tags': ['UK']},
#     {'ipa': '/ˈfɛb.ɹuˌɛɹi/', 'tags': ['US']},
#     {'ipa': '/ˈfɛb.juˌɛ(ə)ɹi/', 'tags': ['US']},
#     {'other': '/j/'},
#     {'other': '/ˈfɛb.ɹi/'},
#     {'other': '/ɹə.ɹi/'},
#     {'other': '/ˈfɛb.ɹə.ɹi/'},
#     {'other': '/ɹi/'},
#     {'audio': 'en-us-February.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'audio': 'en-uk-february.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'enpr': "fĕbʹro͞o-ĕr'-ē"}]},
#   12: {'_id': ObjectId('60544a9311fe31d283dedd9a'),
#    'word': 'minute',
#    'sounds': [{'ipa': '/ˈmɪnɪt/'},
#     {'rhymes': '-ɪnɪt'},
#     {'audio': 'en-uk-a minute.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'audio': 'en-us-minute-noun.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': "mĭn'ĭt"},
#     {'ipa': '/maɪˈnjuːt/', 'tags': ['UK']},
#     {'ipa': '/maɪˈn(j)ut/', 'tags': ['US']},
#     {'ipa': '/məˈn(j)ut/', 'tags': ['US']},
#     {'rhymes': '-uːt'},
#     {'audio': 'en-us-minute-adjective.ogg',
#      'tags': ['US'],
#      'text': 'Audio (US)'},
#     {'enpr': "mīnyo͞ot'"},
#     {'enpr': "mīn(y)o͞ot'"}]},
#   19: {'_id': ObjectId('60544a9411fe31d283dedfe0'),
#    'word': 'the',
#    'sounds': [{'ipa': '/ˈðiː/'},
#     {'rhymes': '-iː'},
#     {'ipa': '/ˈðʌ/', 'tags': ['variant', 'preconsonantal']},
#     {'ipa': '/ði/'},
#     {'ipa': '/ðə/'},
#     {'other': '/ðiː/'},
#     {'other': '/ðə/'},
#     {'other': '/ð/'},
#     {'other': '/jiː/'},
#     {'other': '/ðeː/'},
#     {'other': '/jiː/'},
#     {'audio': 'en-us-the-stressed.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-ca-the.ogg', 'tags': ['CA'], 'text': 'Audio (CA)'},
#     {'audio': 'en-us-the-unstressed.ogg',
#      'tags': ['US'],
#      'text': 'Audio (US)'},
#     {'audio': 'LL-Q1860 (eng)-Back ache-The.wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': "''th''ē"},
#     {'enpr': "''th''ŭ"},
#     {'enpr': "''th''ē"},
#     {'enpr': "''th''ə"}]},
#   13: {'_id': ObjectId('60544a9411fe31d283dee078'),
#    'sounds': [{'ipa': '/ˈɒɹɨn(d)ʒ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈɑɹɪ̈nd͡ʒ/', 'tags': ['US', 'East Coast']},
#     {'ipa': '/ˈɒɹ-/', 'tags': ['US', 'East Coast']},
#     {'ipa': '/ˈɔɹɪ̈nd͡ʒ/', 'tags': ['General American', 'Canada']},
#     {'ipa': '/ˈɔɹ(ɪ)nd͡ʒ/', 'tags': ['General American']},
#     {'ipa': '/ˈɔɹənt͡ʃ/', 'tags': ['General American']},
#     {'homophone': 'orange'},
#     {'rhymes': '-ɒɹɪndʒ'},
#     {'audio': 'En-uk-orange.ogg',
#      'tags': ['UK'],
#      'text': 'Audio (UK) [ˈɔɹɪnd͡ʒ]'},
#     {'audio': 'En-ca-orange.ogg',
#      'tags': ['CA'],
#      'text': 'Audio (CA) [ˈɔɹənd͡ʒ]'},
#     {'enpr': 'ŏrʹĭnj'},
#     {'enpr': 'ärʹĭnj'},
#     {'enpr': 'ôrʹĭnj'}],
#    'word': 'orange'},
#   17: {'_id': ObjectId('60544a9411fe31d283dee0ef'),
#    'word': 'grass',
#    'sounds': [{'ipa': '/ɡɹɑːs/'},
#     {'ipa': '[ɡɹ̠ɑːs]', 'tags': ['Received Pronunciation']},
#     {'ipa': '[ɡɹ̠äːs]', 'tags': ['General Australian', 'General New Zealand']},
#     {'ipa': '[ɡɹ̠ɐːs]', 'tags': ['General Australian', 'General New Zealand']},
#     {'rhymes': '-ɑːs'},
#     {'ipa': '/ɡɹæs/'},
#     {'ipa': '[ɡɹ̠æs]', 'tags': ['US', 'Canada']},
#     {'ipa': '[ɡɹ̠ɛəs]', 'tags': ['US', 'Canada']},
#     {'ipa': '[ɡɹ̠eəs]', 'tags': ['US', 'Canada']},
#     {'ipa': '[ɡɹ̠as]', 'tags': ['Northern England', 'Ireland']},
#     {'ipa': '[ɡɹ̠æs]', 'tags': ['Northern England', 'Ireland']},
#     {'rhymes': '-æs'},
#     {'audio': 'En-uk-grass.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'audio': 'LL-Q1860 (eng)-Back ache-grass.wav', 'text': 'Audio'},
#     {'audio': 'en-us-grass.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'gräs'},
#     {'enpr': 'grăs'}]},
#   16: {'_id': ObjectId('60544a9511fe31d283dee112'),
#    'word': 'four',
#    'sounds': [{'ipa': '/fɔː/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/fo(ː)ɹ/', 'tags': ['Scotland']},
#     {'ipa': '/fɔɹ/', 'tags': ['General American']},
#     {'ipa': '/fo(ː)ɹ/', 'tags': ['rhotic', 'without the horse-hoarse merger']},
#     {'ipa': '/foə/',
#      'tags': ['non-rhotic', 'without the horse-hoarse merger']},
#     {'ipa': '/foː/', 'tags': ['General Australian', 'General New Zealand']},
#     {'rhymes': '-əʊə(r)'},
#     {'rhymes': '-ɔː(ɹ)'},
#     {'homophone': 'four'},
#     {'homophone': 'four'},
#     {'audio': 'en-us-ne-four.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-four.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-au-four.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'},
#     {'enpr': 'fô'},
#     {'enpr': 'fôr'},
#     {'enpr': 'fōr'}]},
#   27: {'_id': ObjectId('60544a9511fe31d283dee130'),
#    'word': 'are',
#    'sounds': [{'ipa': '/ɑː(ɹ)/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɑɹ/', 'tags': ['General American']},
#     {'ipa': '/ɐː(ɹ)/', 'tags': ['General Australian', 'General New Zealand']},
#     {'ipa': '/ɛə(ɹ)/', 'tags': ['now dialectal']},
#     {'ipa': '/ɛː(ɹ)/', 'tags': ['now dialectal']},
#     {'ipa': '/aʊɚ/',
#      'tags': ['proscribed', 'rare', 'due to confusion with "our"']},
#     {'ipa': '/aʊə/',
#      'tags': ['proscribed', 'rare', 'due to confusion with "our"']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'homophone': 'are'},
#     {'homophone': 'are'},
#     {'ipa': '/ə(ɹ)/',
#      'tags': ['Received Pronunciation', 'General Australian']},
#     {'ipa': '/ɘ(ɹ)/', 'tags': ['General New Zealand']},
#     {'ipa': '/ɚ/', 'tags': ['General American']},
#     {'audio': 'en-us-are.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'är'},
#     {'enpr': 'ar'},
#     {'enpr': 'är'},
#     {'enpr': 'är'},
#     {'ipa': '/ɛə/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɛː/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɛəɹ/', 'tags': ['General American']},
#     {'ipa': '/ɛɹ/', 'tags': ['General American']},
#     {'rhymes': '-ɛə(ɹ)'},
#     {'homophone': 'are'},
#     {'homophone': 'are'},
#     {'homophone': 'are'},
#     {'enpr': 'âr'}]},
#   22: {'_id': ObjectId('60544a9511fe31d283dee15d'),
#    'word': 'can',
#    'sounds': [{'ipa': '/ˈkæn/', 'tags': ['Received Pronunciation', 'Ireland']},
#     {'ipa': '[ˈkʰan]', 'tags': ['Received Pronunciation', 'Ireland']},
#     {'ipa': '[ˈkʰæn]', 'tags': ['Received Pronunciation', 'Ireland']},
#     {'ipa': '/ˈkæn/', 'tags': ['General American', 'Canada']},
#     {'ipa': '[ˈkʰæn]', 'tags': ['General American', 'Canada']},
#     {'ipa': '[ˈkʰɛən]', 'tags': ['General American', 'Canada']},
#     {'ipa': '[ˈkʰeən]', 'tags': ['General American', 'Canada']},
#     {'ipa': '/æ/', 'tags': ['General American', 'Canada']},
#     {'rhymes': '-æn'},
#     {'ipa': '/kən/'},
#     {'ipa': '[kʰən]'},
#     {'ipa': '[kʰn̩]'},
#     {'audio': 'en-us-can.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-US can (unstressed).ogg',
#      'tags': ['US', "''unstressed''"],
#      'text': "Audio (US; ''unstressed'')"},
#     {'enpr': 'kăn'},
#     {'ipa': '/ˈkæn/', 'tags': ['Received Pronunciation', 'General American']},
#     {'rhymes': '-æn'},
#     {'ipa': '/ˈkæːn/', 'tags': ['General Australian', 'Southern England']},
#     {'rhymes': '-æːn'},
#     {'ipa': '[ˈkeən]', 'tags': ['æ-tensing']},
#     {'audio': 'LL-Q1860 (eng)-I learned some phrases-can.wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'kăn'}]},
#   20: {'_id': ObjectId('60544a9511fe31d283dee166'),
#    'word': 'second',
#    'sounds': [{'ipa': '/ˈsɛkənd/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈsɛk.(ə)nd/', 'tags': ['US']},
#     {'ipa': '/ˈsɛk.(ə)nt/', 'tags': ['US']},
#     {'ipa': '/ˈsɛkɪnd/', 'tags': ['Canada']},
#     {'audio': 'en-uk-a second.ogg',
#      'tags': ['UK'],
#      'text': "Audio - 'a second' (UK)"},
#     {'audio': 'en-us-second.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'sĕʹkənd'},
#     {'ipa': '/ˈsɛk.(ə)nd/'},
#     {'ipa': '/ˈsɛk.(ə)nd/', 'tags': ['US']},
#     {'ipa': '/ˈsɛk.(ə)nt/', 'tags': ['US']},
#     {'audio': 'en-us-second.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'sĕʹkənd'},
#     {'ipa': '/səˈkɒnd/'},
#     {'rhymes': '-ɒnd'},
#     {'ipa': '/ˈsɛk.(ə)nd/'},
#     {'ipa': '/ˈsɛk.(ə)nd/', 'tags': ['US']},
#     {'ipa': '/ˈsɛk.(ə)nt/', 'tags': ['US']},
#     {'audio': 'en-us-second.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': "səkŏnd'"},
#     {'enpr': 'sĕʹkənd'}]},
#   15: {'_id': ObjectId('60544a9511fe31d283dee1e7'),
#    'word': 'and',
#    'sounds': [{'ipa': '/ænd/', 'tags': ['stressed']},
#     {'ipa': '/ɛnd/', 'tags': ['stressed']},
#     {'rhymes': '-ænd'},
#     {'rhymes': '-ɛnd'},
#     {'ipa': '/ənd/', 'tags': ['unstressed']},
#     {'ipa': '/ən/', 'tags': ['unstressed']},
#     {'ipa': '/ɛn/', 'tags': ['unstressed']},
#     {'ipa': '/ɛnd/', 'tags': ['unstressed']},
#     {'ipa': '/n̩d/', 'tags': ['unstressed']},
#     {'ipa': '/n̩/', 'tags': ['unstressed']},
#     {'homophone': 'and',
#      'tags': ['unstressed or', 'for some speakers', 'stressed']},
#     {'audio': 'en-us-and.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-ham-and-eggs.ogg',
#      'tags': ['US'],
#      'text': 'Audio (US) (ham and eggs)'},
#     {'enpr': 'ănd'},
#     {'enpr': 'ən(d)'}]},
#   23: {'_id': ObjectId('60544a9511fe31d283dee2da'),
#    'word': 'mobile',
#    'sounds': [{'ipa': '/ˈməʊbaɪl/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈməʊbʌɪl/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈmoʊbəl/', 'tags': ['US']},
#     {'ipa': '/ˈmoʊbil/', 'tags': ['US']},
#     {'ipa': '/ˈmoʊbaɪl/', 'tags': ['US']},
#     {'ipa': '/ˈmoʊbil/', 'tags': ['US']},
#     {'ipa': '/ˈməʊ.baɪl/', 'tags': ['UK']},
#     {'rhymes': '-əʊbaɪl'},
#     {'ipa': '/ˈmoʊbəl/', 'tags': ['US']},
#     {'rhymes': '-əʊbəl'},
#     {'ipa': '/ˈməʊ.baɪl/', 'tags': ['UK']},
#     {'rhymes': '-əʊbaɪl'},
#     {'ipa': '/ˈmoʊbəl/', 'tags': ['US', 'phone']},
#     {'rhymes': '-əʊbəl'},
#     {'ipa': '/ˈmoʊbil/', 'tags': ['US', 'sculpture']},
#     {'rhymes': '-oʊbiːl'},
#     {'homophone': 'mobile'},
#     {'audio': 'En-uk-mobile.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'audio': 'en-uk-mobile.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'audio': 'en-uk-mobile.ogg', 'tags': ['UK'], 'text': 'Audio (UK)'},
#     {'enpr': 'mōʹbəl'},
#     {'enpr': 'mōʹbəl'},
#     {'enpr': 'mōʹbēl'}]},
#   21: {'_id': ObjectId('60544a9611fe31d283dee347'),
#    'word': 'thou',
#    'sounds': [{'ipa': '/ðaʊ/',
#      'tags': ['Received Pronunciation', 'General American']},
#     {'rhymes': '-aʊ'},
#     {'audio': 'En-us-thou.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'enpr': "''th''ou"},
#     {'ipa': '/ðaʊ/', 'tags': ['Received Pronunciation', 'General American']},
#     {'rhymes': '-aʊ'},
#     {'audio': 'En-us-thou.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'enpr': "''th''ou"},
#     {'ipa': '/θaʊ/', 'tags': ['Received Pronunciation', 'General American']},
#     {'rhymes': '-aʊ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-thou (number).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'thou'},
#     {'ipa': '/θaʊ/', 'tags': ['Received Pronunciation', 'General American']},
#     {'rhymes': '-aʊ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-thou (number).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'thou'},
#     {'ipa': '/ðəʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ðoʊ/', 'tags': ['General American']},
#     {'audio': 'En-us-though.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'enpr': "''th''ō"},
#     {'enpr': "''th''ō"}]},
#   18: {'_id': ObjectId('60544a9711fe31d283dee51b'),
#    'sounds': [{'ipa': '/ɒˈstɹeɪljə/',
#      'tags': ['General Australian', 'Macquarie Dictionary']},
#     {'ipa': '/əˈstɹeɪljə/',
#      'tags': ['General Australian', 'Macquarie Dictionary']},
#     {'ipa': '/əˈstɹæɪljə/', 'tags': ['General Australian']},
#     {'ipa': '/əˈstɹæɪliːə/', 'tags': ['General Australian']},
#     {'ipa': '/əˈstɹæɪjə/', 'tags': ['General Australian']},
#     {'ipa': '/əˈstɹɛliːə/', 'tags': ['Tasmanian']},
#     {'ipa': '/ɒˈstɹeɪliːə/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɒˈstɹeɪlijə/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɔːˈstɹeɪlɪə/', 'tags': ['Received Pronunciation', 'dated']},
#     {'ipa': '/ɔːˈstɹeɪlɪjə/', 'tags': ['Received Pronunciation', 'dated']},
#     {'ipa': '/ɔˈstɹeɪliə/', 'tags': ['General American']},
#     {'ipa': '/ɔˈstɹeɪljə/', 'tags': ['General American']},
#     {'ipa': '/ɑˈstɹeɪliə/', 'tags': ['cot-caught merger', 'Canada']},
#     {'ipa': '/ɑˈstɹeɪljə/', 'tags': ['cot-caught merger', 'Canada']},
#     {'rhymes': '-eɪliə'},
#     {'audio': 'en-au-Australia.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'},
#     {'audio': 'en-us-Australia.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'En-Australia.oga', 'text': 'Audio'}],
#    'word': 'Australia'},
#   26: {'_id': ObjectId('60544a9711fe31d283dee6ac'),
#    'word': 'you',
#    'sounds': [{'ipa': '/juː/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ju/', 'tags': ['General American']},
#     {'ipa': '/jʉː/', 'tags': ['General Australian']},
#     {'rhymes': '-uː'},
#     {'ipa': '/ju/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/jə/', 'tags': ['General American', 'General Australian']},
#     {'homophone': 'you'},
#     {'homophone': 'you'},
#     {'homophone': 'you'},
#     {'homophone': 'you'},
#     {'homophone': 'you'},
#     {'other': '/t/'},
#     {'other': '/d/'},
#     {'other': '/s/'},
#     {'other': '/z/'},
#     {'other': '/j/'},
#     {'other': '/tʃ/'},
#     {'other': '/dʒ/'},
#     {'other': '/ʃ/'},
#     {'other': '/ʒ/'},
#     {'audio': 'LL-Q1860 (eng)-Back ache-you.wav', 'text': 'Audio'},
#     {'enpr': 'yo͞o'},
#     {'enpr': 'yo͞o'},
#     {'enpr': 'yo͞o'},
#     {'enpr': 'yo͞o'},
#     {'enpr': 'yə'}]},
#   36: {'_id': ObjectId('60544aae11fe31d283df1a06'),
#    'sounds': [{'ipa': '/ɹaʊ/'},
#     {'rhymes': '-aʊ'},
#     {'audio': 'en-us-row-fight.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'rou'},
#     {'ipa': '/ˈɹəʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈɹoʊ/', 'tags': ['US']},
#     {'homophone': 'row'},
#     {'homophone': 'row'},
#     {'rhymes': '-əʊ'},
#     {'audio': 'en-us-row.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'rō'},
#     {'enpr': 'rō'},
#     {'ipa': '/ɹəʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɹoʊ/', 'tags': ['US']},
#     {'homophone': 'row'},
#     {'homophone': 'row'},
#     {'rhymes': '-əʊ'},
#     {'audio': 'en-us-row.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'rō'},
#     {'enpr': 'rō'},
#     {'ipa': '/ˈɹəʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈɹoʊ/', 'tags': ['US']},
#     {'homophone': 'row'},
#     {'homophone': 'row'},
#     {'rhymes': '-əʊ'},
#     {'audio': 'en-us-row.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'rō'},
#     {'enpr': 'rō'},
#     {'ipa': '/ɹəʊ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɹoʊ/', 'tags': ['US']},
#     {'homophone': 'row'},
#     {'homophone': 'row'},
#     {'rhymes': '-əʊ'},
#     {'audio': 'en-us-row.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'rō'},
#     {'enpr': 'rō'}],
#    'word': 'row'},
#   48: {'_id': ObjectId('60544ab411fe31d283df2b40'),
#    'sounds': [{'ipa': '/ˈkæɹəl/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ˈkæɹəl/', 'tags': ['General American']},
#     {'rhymes': '-æɹəl'},
#     {'other': '[ page 87]'},
#     {'other': '[to the mystery plays]'},
#     {'other': '[ Carolle]'},
#     {'other': '[obert]'},
#     {'other': '[ondoner]'},
#     {'other': '[eminine]'},
#     {'other': '[[w:Henry Wadsworth Longfellow|Henry W[adsworth]'},
#     {'other': '[[w:John Townsend Trowbridge|J[ohn]'},
#     {'other': '[ownsend]'},
#     {'other': '[pseudonym; ]'},
#     {'other': '[ page 123]'},
#     {'other': '/ And wild and sweet /'},
#     {'other': '/ Jack Frost nipping at your nose /'},
#     {'other': '/web.archive.org/'},
#     {'other': '/20171120110909/'},
#     {'other': '/www.billboard.com/'},
#     {'other': '/columns/'},
#     {'other': '/6814199/'},
#     {'other': '[ the original]'},
#     {'other': '[ page 91]'},
#     {'other': '[ page 207]'},
#     {'other': '/ Carrols to the evening loud; /'},
#     {'other': '[James Beattie]'},
#     {'other': '[harles]'},
#     {'other': '[illiam]'},
#     {'other': '[ page 5]'},
#     {'other': '/ While warbling larks on russet pinions float: /'},
#     {'other': '[Peter Christen Asbjørnsen; Jørgen Engebretsen Moe]'},
#     {'other': '[...]'},
#     {'other': '[ pages 81-82]'},
#     {'other': '[ page 263]'},
#     {'other': '[ page 389]'},
#     {'other': '[ page 48]'},
#     {'other': '[ page 80]'},
#     {'other': '[ The Third Month Called May hath xxxj Dayes]'},
#     {'other': '[...]'},
#     {'other': '/ Will entertain him in their arms. /'},
#     {'other': '/ Which whilom were with-drawn ſo long. /'},
#     {'other': '[thew]'},
#     {'other': '[ page 222]'},
#     {'other': '[ page 64]'},
#     {'other': '[...]'},
#     {'other': '/ And ye who cultivate the fertile glebe /'},
#     {'other': '/ Shall wave with wheaten harveſts; and the gale /'},
#     {'audio': 'en-au-carol.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'}],
#    'word': 'carol'},
#   24: {'_id': ObjectId('60544abc11fe31d283df40a2'),
#    'word': 'tush',
#    'sounds': [{'ipa': '/tʌʃ/'},
#     {'rhymes': '-ʌʃ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (u).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'tŭsh'},
#     {'ipa': '/tʊʃ/'},
#     {'rhymes': '-ʊʃ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (uh).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'audio': 'En-au-tush.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'},
#     {'enpr': 'to͝osh'},
#     {'ipa': '/tʌʃ/'},
#     {'rhymes': '-ʌʃ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (u).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'tŭsh'},
#     {'ipa': '/tʊʃ/'},
#     {'ipa': '/tʌʃ/'},
#     {'rhymes': '-ʊʃ'},
#     {'rhymes': '-ʌʃ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (u).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (uh).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'to͝osh'},
#     {'ipa': '/tʌʃ/'},
#     {'rhymes': '-ʌʃ'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-tush (u).wav',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'enpr': 'tŭsh'}]},
#   33: {'_id': ObjectId('60544abd11fe31d283df4458'),
#    'sounds': [{'ipa': '/jeɪ/'},
#     {'rhymes': '-eɪ'},
#     {'homophone': 'yea'},
#     {'audio': 'en-us-yea.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'enpr': 'yā'},
#     {'ipa': '/ˈjɛ(ə)/'},
#     {'ipa': '/ˈjæ.ə/'},
#     {'rhymes': '-ɛə'},
#     {'audio': 'en-us-yeah.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-yeah-interjection.ogg',
#      'tags': ['US', 'interjection'],
#      'text': 'Audio (US, interjection)'},
#     {'ipa': '/jeɪ/'},
#     {'enpr': 'yā'},
#     {'ipa': '/ˈjɛ(ə)/'},
#     {'ipa': '/ˈjæ.ə/'},
#     {'rhymes': '-ɛə'},
#     {'audio': 'en-us-yeah.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-yeah-interjection.ogg',
#      'tags': ['US', 'interjection'],
#      'text': 'Audio (US, interjection)'},
#     {'ipa': '/jeɪ/'},
#     {'enpr': 'yā'},
#     {'ipa': '/ˈjɛ(ə)/'},
#     {'ipa': '/ˈjæ.ə/'},
#     {'rhymes': '-ɛə'},
#     {'audio': 'en-us-yeah.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-yeah-interjection.ogg',
#      'tags': ['US', 'interjection'],
#      'text': 'Audio (US, interjection)'},
#     {'ipa': '/jeɪ/'},
#     {'enpr': 'yā'},
#     {'ipa': '/ˈjɛ(ə)/'},
#     {'ipa': '/ˈjæ.ə/'},
#     {'rhymes': '-ɛə'},
#     {'audio': 'en-us-yeah.ogg', 'tags': ['US'], 'text': 'Audio (US)'},
#     {'audio': 'en-us-yeah-interjection.ogg',
#      'tags': ['US', 'interjection'],
#      'text': 'Audio (US, interjection)'},
#     {'ipa': '/jeɪ/'},
#     {'enpr': 'yā'}],
#    'word': 'yea'},
#   40: {'_id': ObjectId('60544ac311fe31d283df5608'),
#    'sounds': [{'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '[tʃɑɹ]', 'tags': ['US']},
#     {'ipa': '[tʃɑ˞]', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'audio': 'LL-Q1860 (eng)-Vealhurl-char.wav ',
#      'tags': ['UK'],
#      'text': 'Audio (UK)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '[tʃɑɹ]', 'tags': ['US']},
#     {'ipa': '[tʃɑ˞]', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '[tʃɑɹ]', 'tags': ['US']},
#     {'ipa': '[tʃɑ˞]', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/kɛə/', 'tags': ['UK']},
#     {'ipa': '/kɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '/kɛɹ/', 'tags': ['US']},
#     {'ipa': '/kɑɹ/', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '[tʃɑɹ]', 'tags': ['US']},
#     {'ipa': '[tʃɑ˞]', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '[tʃɑɹ]', 'tags': ['US']},
#     {'ipa': '[tʃɑ˞]', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'},
#     {'ipa': '/tʃɑː/', 'tags': ['UK']},
#     {'ipa': '/kɛə/', 'tags': ['UK']},
#     {'ipa': '/kɑː/', 'tags': ['UK']},
#     {'ipa': '/tʃɑɹ/', 'tags': ['US']},
#     {'ipa': '/kɛɹ/', 'tags': ['US']},
#     {'ipa': '/kɑɹ/', 'tags': ['US']},
#     {'rhymes': '-ɑː(ɹ)'}],
#    'word': 'char'},
#   43: {'_id': ObjectId('60544ac611fe31d283df5cf2'),
#    'word': 'rout',
#    'sounds': [{'ipa': '/ɹaʊt/',
#      'tags': ['Received Pronunciation', 'General American']},
#     {'ipa': '[ɹʌʊt]', 'tags': ['Canada']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/', 'tags': ['Received Pronunciation', 'General American']},
#     {'ipa': '[ɹʌʊt]', 'tags': ['Canada']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/', 'tags': ['Received Pronunciation', 'General American']},
#     {'ipa': '/ɹʌʊt/', 'tags': ['Scotland']},
#     {'ipa': '/ɹut/', 'tags': ['Scotland']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/',
#      'tags': ['Received Pronunciation', 'General American', 'Ireland']},
#     {'ipa': '/ɹʌʊt/', 'tags': ['Scotland']},
#     {'ipa': '/ɹut/', 'tags': ['Scotland']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/', 'tags': ['Received Pronunciation', 'General American']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/', 'tags': ['Received Pronunciation', 'General American']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'},
#     {'ipa': '/ɹaʊt/', 'tags': ['Received Pronunciation', 'General American']},
#     {'ipa': '/ɹʌʊt/', 'tags': ['Scotland']},
#     {'ipa': '/ɹut/', 'tags': ['Scotland']},
#     {'homophone': 'rout'},
#     {'rhymes': '-aʊt'},
#     {'audio': 'En-uk-rout.ogg', 'tags': ['RP'], 'text': 'Audio (RP)'},
#     {'audio': 'En-us-route.ogg', 'tags': ['GA'], 'text': 'Audio (GA)'}]},
#   44: {'_id': ObjectId('60544b7911fe31d283e2007c'),
#    'word': 'retrench',
#    'sounds': [{'ipa': '/ɹɪˈtɹɛn(t)ʃ/', 'tags': ['Received Pronunciation']},
#     {'ipa': '/ɹəˈtɹɛn(t)ʃ/', 'tags': ['General American']},
#     {'rhymes': '-ɛntʃ'},
#     {'other': "[[w:Dodona's Grove|ΔΕΝΔΡΟΛΟΓΊΑ [DENDROLOGIA]"},
#     {'other': '[ page 189]'},
#     {'other': '[…]'},
#     {'other': '[…]'},
#     {'other': '[…]'},
#     {'other': '[…]'},
#     {'other': '[amuel]'},
#     {'other': '[[w:Jacob Tonson|J[acob]'},
#     {'other': '[ page 89]'},
#     {'other': '[Thomas]'},
#     {'other': '[letter]'},
#     {'other': '[…]'},
#     {'other': '[…]'},
#     {'other': '[[w:Joseph Johnson (publisher)|J[oseph]'},
#     {'other': '[et al.]'},
#     {'other': '[ page 147]'},
#     {'other': '[ page 238]'},
#     {'other': '[...]'},
#     {'other': '[ pages 271-272]'},
#     {'other': '[…]'},
#     {'other': '[[w:Henry Curzon|H[enry]'},
#     {'other': '[...]'},
#     {'other': '[ page 243]'},
#     {'other': '[...]'},
#     {'other': '[ page 186]'},
#     {'other': '[I]'},
#     {'other': '[[w:Eugène Viollet-le-Duc|E[ugène]'},
#     {'other': '[[w:James R. Osgood|James R[ipley]'},
#     {'other': '[ page 335]'},
#     {'other': '[ page 109]'},
#     {'other': '[[w:Barack Obama|[Barack]'},
#     {'other': '[ page vii]'},
#     {'other': '/web.archive.org/'},
#     {'other': '/20170713183842/'},
#     {'other': '/www.economist.com/'},
#     {'other': '[ the original]'},
#     {'other': '/web.archive.org/'},
#     {'other': '/20171204101924/'},
#     {'other': '/tv.avclub.com/'},
#     {'other': '[ the original]'},
#     {'audio': 'en-au-retrench.ogg', 'tags': ['AU'], 'text': 'Audio (AU)'}]}})

# %% [markdown]
# ## synonyms
# keep
#
# data cleaning needed

# %%
data = query_words_by_key('synonyms')
len(data)
# Out:
# 14563

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc20'),
#   'word': 'book',
#   'synonyms': [{'word': 'See Thesaurus:book'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc2f'),
#   'word': 'thesaurus',
#   'synonyms': [{'word': 'synonymicon'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc34'),
#   'word': 'connotation',
#   'synonyms': [{'word': 'intension'}]}]

# %%
all_items = sum([o['synonyms'] for o in data],[])

# %%
a,b,c = get_uniq_keys(all_items)
a
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='44403' class='' max='44403' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [44403/44403 00:00<00:00]
#     </div>
# ['word', 'topics', 'sense', 'translation', 'tags']

# %%
b,c
# Out:
# ({'word': ['See Thesaurus:book', 'synonymicon', 'intension'],
#   'sense': ['any member of the suborder (sometimes superfamily) Feliformia or Feloidea',
#    'any member of the suborder (sometimes superfamily) Feliformia or Feloidea',
#    'any member of the subfamily Felinae, genera Puma, Acinonyx, Lynx, Leopardus, and Felis)'],
#   'tags': [['sensu stricto'], ['sensu stricto'], ['sensu stricto']],
#   'translation': ['not informal', 'dialectal, obsolete', 'very rare'],
#   'topics': [['country',
#     'countries',
#     'region',
#     'geography',
#     'location',
#     'property',
#     'natural-sciences',
#     'sciences'],
#    ['grammar', 'linguistics'],
#    ['pool', 'games']]},
#  {'word': 44403,
#   'sense': 27851,
#   'tags': 4730,
#   'translation': 1134,
#   'topics': 320})

# %%
dist,samples = len_distribution(data,'synonyms')
dist, samples
# Out:
# ({1: 6179,
#   2: 2775,
#   3: 1732,
#   4: 1129,
#   5: 693,
#   6: 516,
#   7: 385,
#   8: 296,
#   9: 184,
#   10: 144,
#   11: 114,
#   12: 91,
#   13: 59,
#   14: 52,
#   15: 34,
#   16: 36,
#   17: 18,
#   18: 27,
#   19: 13,
#   20: 8,
#   21: 10,
#   22: 10,
#   23: 10,
#   24: 8,
#   25: 8,
#   26: 9,
#   27: 2,
#   29: 2,
#   30: 3,
#   31: 1,
#   32: 2,
#   33: 1,
#   34: 3,
#   35: 1,
#   36: 1,
#   38: 1,
#   41: 1,
#   46: 2,
#   52: 3},
#  {1: {'_id': ObjectId('60544a9311fe31d283dedc20'),
#    'word': 'book',
#    'synonyms': [{'word': 'See Thesaurus:book'}]},
#   12: {'_id': ObjectId('60544a9311fe31d283dedc41'),
#    'word': 'cat',
#    'synonyms': [{'word': 'feliform (carnivoran)',
#      'sense': 'any member of the suborder (sometimes superfamily) Feliformia or Feloidea'},
#     {'word': 'feloid (compare Caniformia, Canoidea)',
#      'sense': 'any member of the suborder (sometimes superfamily) Feliformia or Feloidea'},
#     {'word': 'feline cat',
#      'sense': 'any member of the subfamily Felinae, genera Puma, Acinonyx, Lynx, Leopardus, and Felis)'},
#     {'word': 'a feline',
#      'sense': 'any member of the subfamily Felinae, genera Puma, Acinonyx, Lynx, Leopardus, and Felis)'},
#     {'word': 'pantherine cat',
#      'sense': 'any member of the subfamily Pantherinae, genera Panthera, Uncia and Neofelis'},
#     {'word': 'a pantherine',
#      'sense': 'any member of the subfamily Pantherinae, genera Panthera, Uncia and Neofelis'},
#     {'word': 'panther (i.e. tiger, lion, jaguar, leopard)',
#      'sense': 'technically, all members of the genus Panthera'},
#     {'word': '(narrow sense) panther (i.e. black panther)',
#      'sense': 'technically, all members of the genus Panthera'},
#     {'word': 'Smilodontini',
#      'sense': 'any member of the extinct subfamily Machairodontinae, genera Smilodon, Homotherium, Miomachairodus, etc.'},
#     {'word': 'Machairodontini (Homotherini)',
#      'sense': 'any member of the extinct subfamily Machairodontinae, genera Smilodon, Homotherium, Miomachairodus, etc.'},
#     {'word': 'Metailurini',
#      'sense': 'any member of the extinct subfamily Machairodontinae, genera Smilodon, Homotherium, Miomachairodus, etc.'},
#     {'word': '(saber-tooth)',
#      'sense': 'any member of the extinct subfamily Machairodontinae, genera Smilodon, Homotherium, Miomachairodus, etc.'}]},
#   2: {'_id': ObjectId('60544a9311fe31d283dedc4d'),
#    'word': 'word',
#    'synonyms': [{'word': 'vocable'}, {'word': 'see also Thesaurus:word'}]},
#   4: {'_id': ObjectId('60544a9311fe31d283dedc53'),
#    'word': 'barter',
#    'synonyms': [{'word': 'quid pro quo'},
#     {'word': 'swap'},
#     {'word': 'swop'},
#     {'word': 'trade'}]},
#   3: {'_id': ObjectId('60544a9311fe31d283dedc5c'),
#    'word': 'quid pro quo',
#    'synonyms': [{'word': 'barter', 'sense': 'exchange transaction'},
#     {'word': 'swap', 'sense': 'exchange transaction'},
#     {'word': 'trade', 'sense': 'exchange transaction'}]},
#   14: {'_id': ObjectId('60544a9311fe31d283dedcaf'),
#    'word': 'pound',
#    'synonyms': [{'word': 'hammer', 'sense': 'strike hard'},
#     {'word': 'pelt', 'sense': 'strike hard'},
#     {'word': 'see also Thesaurus:hit', 'sense': 'strike hard'},
#     {'word': 'pulverate', 'sense': 'crush to pieces'},
#     {'word': 'triturate', 'sense': 'crush to pieces'},
#     {'word': 'bolt', 'sense': 'eat or drink very quickly'},
#     {'word': 'down', 'sense': 'eat or drink very quickly'},
#     {'word': 'chug', 'sense': 'eat or drink very quickly'},
#     {'word': 'see also Thesaurus:eat or Thesaurus:drink',
#      'sense': 'eat or drink very quickly'},
#     {'word': 'drill', 'sense': 'penetrate sexually'},
#     {'word': 'get up in', 'sense': 'penetrate sexually'},
#     {'word': 'nail', 'sense': 'penetrate sexually'},
#     {'word': 'poke', 'sense': 'penetrate sexually'},
#     {'word': 'see also Thesaurus:copulate with',
#      'sense': 'penetrate sexually'}]},
#   6: {'_id': ObjectId('60544a9311fe31d283dedcbe'),
#    'word': 'noun',
#    'synonyms': [{'word': 'name'},
#     {'word': 'nameword'},
#     {'word': 'noun substantive', 'tags': ['sensu stricto']},
#     {'word': 'substantive noun', 'tags': ['sensu stricto']},
#     {'word': 'substantive', 'tags': ['sensu stricto']},
#     {'word': 'naming word', 'tags': ['sensu stricto']}]},
#   5: {'_id': ObjectId('60544a9311fe31d283dedccd'),
#    'word': 'hour',
#    'synonyms': [{'word': 'stound',
#      'tags': ['obsolete'],
#      'sense': 'period of sixty minutes'},
#     {'word': 'Singular: h'},
#     {'word': 'hr'},
#     {'word': 'Plural: h'},
#     {'word': 'hrs'}]},
#   18: {'_id': ObjectId('60544a9311fe31d283dedd0f'),
#    'word': 'abasement',
#    'synonyms': [{'word': 'abjection'},
#     {'word': 'debasement'},
#     {'word': 'degeneracy'},
#     {'word': 'degeneration'},
#     {'word': 'degradation'},
#     {'word': 'depravation'},
#     {'word': 'depression'},
#     {'word': 'deterioration'},
#     {'word': 'discredit'},
#     {'word': 'dishonor'},
#     {'word': 'fall'},
#     {'word': 'humiliation'},
#     {'word': 'lowering'},
#     {'word': 'perversion'},
#     {'word': 'reduction'},
#     {'word': 'shame'},
#     {'word': 'subserviency'},
#     {'word': 'vitiation'}]},
#   24: {'_id': ObjectId('60544a9311fe31d283dedd20'),
#    'word': 'abatement',
#    'synonyms': [{'word': 'allowance'},
#     {'word': 'assuagement'},
#     {'word': 'declension'},
#     {'word': 'decline'},
#     {'word': 'decrease'},
#     {'word': 'deduction'},
#     {'word': 'depreciation'},
#     {'word': 'diminution'},
#     {'word': 'discount'},
#     {'word': 'drawback'},
#     {'word': 'ebb'},
#     {'word': 'evanishment'},
#     {'word': 'fading'},
#     {'word': 'lessening'},
#     {'word': 'lowering'},
#     {'word': 'mitigation'},
#     {'word': 'moderation'},
#     {'word': 'rebate'},
#     {'word': 'reduction'},
#     {'word': 'remission'},
#     {'word': 'settling'},
#     {'word': 'sinking'},
#     {'word': 'subsidence'},
#     {'word': 'waning'}]},
#   10: {'_id': ObjectId('60544a9311fe31d283dedd2f'),
#    'word': 'abelmosk',
#    'synonyms': [{'word': 'annual hibiscus', 'sense': 'A. moschatus'},
#     {'word': 'tropical jewel hibiscus (dated)', 'sense': 'A. moschatus'},
#     {'word': 'ambrette', 'sense': 'A. moschatus'},
#     {'word': 'muskdana', 'sense': 'A. moschatus'},
#     {'word': 'musk mallow', 'sense': 'A. moschatus'},
#     {'word': 'musk okra', 'sense': 'A. moschatus'},
#     {'word': 'ornamental okra', 'sense': 'A. moschatus'},
#     {'word': 'rose mallow', 'sense': 'A. moschatus'},
#     {'word': 'Yorka okra', 'sense': 'A. moschatus'},
#     {'word': 'musk seed', 'sense': 'A. moschatus'}]},
#   33: {'_id': ObjectId('60544a9311fe31d283dedd68'),
#    'word': 'abandoned',
#    'synonyms': [{'word': 'bad'},
#     {'word': 'careless'},
#     {'word': 'cast aside'},
#     {'word': 'corrupt'},
#     {'word': 'demoralized'},
#     {'word': 'depraved'},
#     {'word': 'deserted'},
#     {'word': 'discarded'},
#     {'word': 'dissolute'},
#     {'word': 'forsaken'},
#     {'word': 'graceless'},
#     {'word': 'hardened'},
#     {'word': 'impetuous'},
#     {'word': 'impenitent'},
#     {'word': 'incorrigible'},
#     {'word': 'irreclaimable'},
#     {'word': 'licentious'},
#     {'word': 'lost'},
#     {'word': 'obdurate'},
#     {'word': 'profligate'},
#     {'word': 'reckless'},
#     {'word': 'rejected'},
#     {'word': 'reprobate'},
#     {'word': 'shameless'},
#     {'word': 'sinful'},
#     {'word': 'uninhibited'},
#     {'word': 'unprincipled'},
#     {'word': 'unrestrained'},
#     {'word': 'vicious'},
#     {'word': 'vile'},
#     {'word': 'wanton'},
#     {'word': 'wicked'},
#     {'word': 'wild'}]},
#   8: {'_id': ObjectId('60544a9311fe31d283dedd86'),
#    'word': 'abduct',
#    'synonyms': [{'word': 'carry off'},
#     {'word': 'drag away'},
#     {'word': 'kidnap'},
#     {'word': 'run away with'},
#     {'word': 'seize'},
#     {'word': 'spirit away'},
#     {'word': 'stretch'},
#     {'word': 'take away'}]},
#   15: {'_id': ObjectId('60544a9311fe31d283dedd9d'),
#    'word': 'abandonment',
#    'synonyms': [{'word': 'abandoning'},
#     {'word': 'abdication'},
#     {'word': 'abjuration'},
#     {'word': 'abnegation'},
#     {'word': 'abrogation'},
#     {'word': 'cession'},
#     {'word': 'defection'},
#     {'word': 'demission'},
#     {'word': 'dereliction'},
#     {'word': 'desertion'},
#     {'word': 'rejection'},
#     {'word': 'relinquishment'},
#     {'word': 'renunciation'},
#     {'word': 'resignation'},
#     {'word': 'surrender'}]},
#   25: {'_id': ObjectId('60544a9311fe31d283deddb5'),
#    'word': 'abdicate',
#    'synonyms': [{'word': 'abandon'},
#     {'word': 'abjure'},
#     {'word': 'cast aside'},
#     {'word': 'cast off'},
#     {'word': 'cede'},
#     {'word': 'desert'},
#     {'word': 'disinherit'},
#     {'word': 'disown'},
#     {'word': 'forego'},
#     {'word': 'forsake'},
#     {'word': 'give up'},
#     {'word': 'quit'},
#     {'word': 'refuse'},
#     {'word': 'reject'},
#     {'word': 'relent'},
#     {'word': 'relinquish'},
#     {'word': 'renounce'},
#     {'word': 'repudiate'},
#     {'word': 'resign'},
#     {'word': 'retire'},
#     {'word': 'stand down'},
#     {'word': 'surrender'},
#     {'word': 'vacate'},
#     {'word': 'waive'},
#     {'word': 'yield'}]},
#   22: {'_id': ObjectId('60544a9311fe31d283deddc5'),
#    'word': 'abet',
#    'synonyms': [{'word': 'incite',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'instigate',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'set on',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'egg on',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'foment',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'advocate',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'countenance',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'encourage',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'second',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'uphold',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'aid',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'assist',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'support',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'sustain',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'back',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'connive at',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'promote',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'sanction',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'advocate',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'embolden',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'favor',
#      'sense': 'to instigate or encourage by aid or countenance'},
#     {'word': 'cooperate with',
#      'sense': 'to instigate or encourage by aid or countenance'}]},
#   9: {'_id': ObjectId('60544a9311fe31d283deddd0'),
#    'word': 'abjure',
#    'synonyms': [{'word': 'disavow', 'sense': 'to renounce upon oath'},
#     {'word': 'forswear', 'sense': 'to renounce upon oath'},
#     {'word': 'renounce', 'sense': 'to renounce upon oath'},
#     {'word': 'See also Thesaurus:repudiate or Thesaurus:recant',
#      'sense': 'to renounce upon oath'},
#     {'word': 'disclaim', 'sense': 'to reject with solemnity'},
#     {'word': 'repudiate', 'sense': 'to reject with solemnity'},
#     {'word': 'avoid', 'sense': 'to abstain from'},
#     {'word': 'shun', 'sense': 'to abstain from'},
#     {'word': 'See also Thesaurus:avoid', 'sense': 'to abstain from'}]},
#   23: {'_id': ObjectId('60544a9411fe31d283dedddf'),
#    'word': 'deal',
#    'synonyms': [{'word': 'apportion',
#      'sense': 'distribute among a number of recipients'},
#     {'word': 'divvy up', 'sense': 'distribute among a number of recipients'},
#     {'word': 'share', 'sense': 'distribute among a number of recipients'},
#     {'word': 'share out', 'sense': 'distribute among a number of recipients'},
#     {'word': 'portion out',
#      'sense': 'distribute among a number of recipients'},
#     {'word': 'administer', 'sense': 'administer in portions'},
#     {'word': 'allot', 'sense': 'administer in portions'},
#     {'word': 'deal out', 'sense': 'administer in portions'},
#     {'word': 'dish out', 'sense': 'administer in portions'},
#     {'word': 'dispense', 'sense': 'administer in portions'},
#     {'word': 'distribute', 'sense': 'administer in portions'},
#     {'word': 'dole out', 'sense': 'administer in portions'},
#     {'word': 'hand out', 'sense': 'administer in portions'},
#     {'word': 'lot', 'sense': 'administer in portions'},
#     {'word': 'mete out', 'sense': 'administer in portions'},
#     {'word': 'parcel out', 'sense': 'administer in portions'},
#     {'word': 'shell out', 'sense': 'administer in portions'},
#     {'word': 'pitch', 'sense': 'baseball slang: to pitch'},
#     {'word': 'throw', 'sense': 'baseball slang: to pitch'},
#     {'word': 'sell', 'sense': 'trade'},
#     {'word': 'trade', 'sense': 'trade'},
#     {'word': 'bargain', 'sense': 'trade'},
#     {'word': 'sell', 'sense': 'sell (illicit drugs)'}]},
#   11: {'_id': ObjectId('60544a9411fe31d283deddf7'),
#    'word': 'abject',
#    'synonyms': [{'word': 'beggarly'},
#     {'word': 'contemptible'},
#     {'word': 'cringing'},
#     {'word': 'degraded'},
#     {'word': 'groveling'},
#     {'word': 'ignoble'},
#     {'word': 'mean'},
#     {'word': 'mean-spirited'},
#     {'word': 'slavish'},
#     {'word': 'vile'},
#     {'word': 'worthless'}]},
#   31: {'_id': ObjectId('60544a9411fe31d283dede22'),
#    'word': 'abate',
#    'synonyms': [{'word': 'lessen', 'sense': 'bring down or reduce'},
#     {'word': 'diminish', 'sense': 'bring down or reduce'},
#     {'word': 'contract', 'sense': 'bring down or reduce'},
#     {'word': 'moderate', 'sense': 'bring down or reduce'},
#     {'word': 'cut short', 'sense': 'bring down or reduce'},
#     {'word': 'decrease', 'sense': 'bring down or reduce'},
#     {'word': 'lower', 'sense': 'bring down or reduce'},
#     {'word': 'suppress', 'sense': 'bring down or reduce'},
#     {'word': 'terminate', 'sense': 'bring down or reduce'},
#     {'word': 'remove', 'sense': 'bring down or reduce'},
#     {'word': 'remit', 'sense': 'bring down or reduce'},
#     {'word': 'slacken', 'sense': 'bring down or reduce'},
#     {'word': 'diminish', 'sense': 'diminish in force or intensity'},
#     {'word': 'subside', 'sense': 'diminish in force or intensity'},
#     {'word': 'decline', 'sense': 'diminish in force or intensity'},
#     {'word': 'wane', 'sense': 'diminish in force or intensity'},
#     {'word': 'ebb', 'sense': 'diminish in force or intensity'},
#     {'word': 'mitigate', 'sense': 'diminish in force or intensity'},
#     {'word': 'assuage', 'sense': 'diminish in force or intensity'},
#     {'word': 'temper', 'sense': 'diminish in force or intensity'},
#     {'word': 'alleviate', 'sense': 'diminish in force or intensity'},
#     {'word': 'relax', 'sense': 'diminish in force or intensity'},
#     {'word': 'humble', 'sense': 'bring someone down'},
#     {'word': 'depress', 'sense': 'bring someone down'},
#     {'word': 'appease', 'sense': 'bring someone down'},
#     {'word': 'pacify', 'sense': 'bring someone down'},
#     {'word': 'soothe', 'sense': 'bring someone down'},
#     {'word': 'soften', 'sense': 'bring someone down'},
#     {'word': 'tranquilize', 'sense': 'bring someone down'},
#     {'word': 'fall through', 'sense': 'come to naught'},
#     {'word': 'fail', 'sense': 'come to naught'}]},
#   16: {'_id': ObjectId('60544a9411fe31d283dede2d'),
#    'word': 'abide',
#    'synonyms': [{'word': 'hold on', 'sense': 'endure without yielding'},
#     {'word': 'resist', 'sense': 'endure without yielding'},
#     {'word': 'See also Thesaurus:persevere',
#      'sense': 'endure without yielding'},
#     {'word': 'brook', 'sense': 'bear patiently'},
#     {'word': 'put up with', 'sense': 'bear patiently'},
#     {'word': 'See also Thesaurus:tolerate', 'sense': 'bear patiently'},
#     {'word': 'hold on', 'sense': 'wait in expectation'},
#     {'word': 'stay', 'sense': 'wait in expectation'},
#     {'word': 'See also Thesaurus:wait', 'sense': 'wait in expectation'},
#     {'word': 'dwell', 'sense': "have one's abode"},
#     {'word': 'live', 'sense': "have one's abode"},
#     {'word': 'See also Thesaurus:reside', 'sense': "have one's abode"},
#     {'word': 'See also Thesaurus:persist', 'sense': 'endure; remain; last'},
#     {'word': 'await', 'sense': 'stand ready for'},
#     {'word': 'wait for', 'sense': 'stand ready for'},
#     {'word': 'See also Thesaurus:wait for', 'sense': 'stand ready for'}]},
#   13: {'_id': ObjectId('60544a9411fe31d283dede5f'),
#    'word': 'ability',
#    'synonyms': [{'word': 'capacity',
#      'sense': 'quality or state of being able'},
#     {'word': 'faculty', 'sense': 'quality or state of being able'},
#     {'word': 'capability', 'sense': 'quality or state of being able'},
#     {'word': 'See Thesaurus:skill', 'sense': 'a skill or competence'},
#     {'word': 'talent', 'sense': 'high level of skill or capability'},
#     {'word': 'cleverness', 'sense': 'high level of skill or capability'},
#     {'word': 'dexterity', 'sense': 'high level of skill or capability'},
#     {'word': 'aptitude', 'sense': 'high level of skill or capability'},
#     {'word': 'capability',
#      'sense': 'suitability or receptiveness to be acted upon'},
#     {'word': 'faculty',
#      'sense': 'suitability or receptiveness to be acted upon'},
#     {'word': 'capacity',
#      'sense': 'suitability or receptiveness to be acted upon'},
#     {'word': 'aptness',
#      'sense': 'suitability or receptiveness to be acted upon'},
#     {'word': 'aptitude',
#      'sense': 'suitability or receptiveness to be acted upon'}]},
#   36: {'_id': ObjectId('60544a9411fe31d283dede61'),
#    'word': 'abandon',
#    'synonyms': [{'word': 'abdicate'},
#     {'word': 'abjure'},
#     {'word': 'blin'},
#     {'word': 'cast aside'},
#     {'word': 'cease'},
#     {'word': 'cede'},
#     {'word': 'deliver up'},
#     {'word': 'depart from'},
#     {'word': 'desert'},
#     {'word': 'desist from'},
#     {'word': 'discontinue'},
#     {'word': 'dispense with'},
#     {'word': 'drop'},
#     {'word': 'forgo'},
#     {'word': 'forlet'},
#     {'word': 'forsake'},
#     {'word': 'forswear'},
#     {'word': 'give up'},
#     {'word': 'jilt'},
#     {'word': 'leave behind'},
#     {'word': 'part with'},
#     {'word': 'quit'},
#     {'word': 'recant'},
#     {'word': 'relinquish'},
#     {'word': 'renounce'},
#     {'word': 'repudiate'},
#     {'word': 'resign'},
#     {'word': 'retire'},
#     {'word': 'retract'},
#     {'word': 'run out on'},
#     {'word': 'surrender'},
#     {'word': 'vacate'},
#     {'word': 'waive'},
#     {'word': 'withdraw from'},
#     {'word': 'withsake'},
#     {'word': 'yield'}]},
#   34: {'_id': ObjectId('60544a9411fe31d283dede69'),
#    'word': 'abrogate',
#    'synonyms': [{'word': 'abolish', 'sense': 'to annul by authoritative act'},
#     {'word': 'annul', 'sense': 'to annul by authoritative act'},
#     {'word': 'countermand', 'sense': 'to annul by authoritative act'},
#     {'word': 'invalidate', 'sense': 'to annul by authoritative act'},
#     {'word': 'nullify', 'sense': 'to annul by authoritative act'},
#     {'word': 'overrule', 'sense': 'to annul by authoritative act'},
#     {'word': 'overturn', 'sense': 'to annul by authoritative act'},
#     {'word': 'quash', 'sense': 'to annul by authoritative act'},
#     {'word': 'repeal', 'sense': 'to annul by authoritative act'},
#     {'word': 'rescind', 'sense': 'to annul by authoritative act'},
#     {'word': 'retract', 'sense': 'to annul by authoritative act'},
#     {'word': 'reverse', 'sense': 'to annul by authoritative act'},
#     {'word': 'revoke', 'sense': 'to annul by authoritative act'},
#     {'word': 'set aside', 'sense': 'to annul by authoritative act'},
#     {'word': 'supersede', 'sense': 'to annul by authoritative act'},
#     {'word': 'suspend', 'sense': 'to annul by authoritative act'},
#     {'word': 'undo', 'sense': 'to annul by authoritative act'},
#     {'word': 'veto', 'sense': 'to annul by authoritative act'},
#     {'word': 'void', 'sense': 'to annul by authoritative act'},
#     {'word': 'waive', 'sense': 'to annul by authoritative act'},
#     {'word': 'withdraw', 'sense': 'to annul by authoritative act'},
#     {'word': 'abjure', 'sense': 'to put an end to'},
#     {'word': 'annihilate', 'sense': 'to put an end to'},
#     {'word': 'cancel', 'sense': 'to put an end to'},
#     {'word': 'dissolve', 'sense': 'to put an end to'},
#     {'word': 'do away with', 'sense': 'to put an end to'},
#     {'word': 'end', 'sense': 'to put an end to'},
#     {'word': 'obliterate', 'sense': 'to put an end to'},
#     {'word': 'obviate', 'sense': 'to put an end to'},
#     {'word': 'recant', 'sense': 'to put an end to'},
#     {'word': 'subvert', 'sense': 'to put an end to'},
#     {'word': 'terminate', 'sense': 'to put an end to'},
#     {'word': 'vitiate', 'sense': 'to put an end to'},
#     {'word': 'wipe out', 'sense': 'to put an end to'}]},
#   7: {'_id': ObjectId('60544a9411fe31d283dedf37'),
#    'word': 'abstain',
#    'synonyms': [{'word': 'deny oneself'},
#     {'word': 'forbear'},
#     {'word': 'forgo'},
#     {'word': 'give up'},
#     {'word': 'refrain'},
#     {'word': 'relinquish'},
#     {'word': 'withhold'}]},
#   19: {'_id': ObjectId('60544a9511fe31d283dee139'),
#    'word': 'nigger',
#    'synonyms': [{'word': 'blackie',
#      'sense': 'derogatory term for black person'},
#     {'word': 'nigga', 'sense': 'derogatory term for black person'},
#     {'word': 'coon', 'sense': 'derogatory term for black person'},
#     {'word': 'darkie', 'sense': 'derogatory term for black person'},
#     {'word': 'gator bait', 'sense': 'derogatory term for black person'},
#     {'word': 'groid', 'sense': 'derogatory term for black person'},
#     {'word': 'jigaboo', 'sense': 'derogatory term for black person'},
#     {'word': 'jungle bunny', 'sense': 'derogatory term for black person'},
#     {'word': 'kaffir', 'sense': 'derogatory term for black person'},
#     {'word': 'macaca', 'sense': 'derogatory term for black person'},
#     {'word': 'nig-nog', 'sense': 'derogatory term for black person'},
#     {'word': 'porch monkey', 'sense': 'derogatory term for black person'},
#     {'word': 'sambo', 'sense': 'derogatory term for black person'},
#     {'word': 'shitskin', 'sense': 'derogatory term for black person'},
#     {'word': 'spade', 'sense': 'derogatory term for black person'},
#     {'word': 'spearchucker', 'sense': 'derogatory term for black person'},
#     {'word': 'spook', 'sense': 'derogatory term for black person'},
#     {'word': 'tar baby', 'sense': 'derogatory term for black person'},
#     {'word': 'wog', 'sense': 'derogatory term for black person'}]},
#   32: {'_id': ObjectId('60544a9511fe31d283dee194'),
#    'word': 'cod',
#    'synonyms': [{'word': 'milwell (many variants)', 'sense': 'Atlantic cod'},
#     {'word': 'Scotch cod', 'sense': 'Atlantic cod'},
#     {'word': 'common cod', 'sense': 'Atlantic cod'},
#     {'word': 'gray cod',
#      'tags': ['Greenland cod'],
#      'sense': 'other Gadus spp., esp. Pacific cod'},
#     {'word': 'grey cod',
#      'tags': ['Greenland cod'],
#      'sense': 'other Gadus spp., esp. Pacific cod'},
#     {'word': 'grayfish',
#      'tags': ['Greenland cod'],
#      'sense': 'other Gadus spp., esp. Pacific cod'},
#     {'word': 'greyfish',
#      'tags': ['Greenland cod'],
#      'sense': 'other Gadus spp., esp. Pacific cod'},
#     {'word': '(Greenland cod) ogac',
#      'tags': ['Greenland cod'],
#      'sense': 'other Gadus spp., esp. Pacific cod'},
#     {'word': 'haddock', 'sense': 'unrelated fish marketed as cod'},
#     {'word': 'whiting', 'sense': 'unrelated fish marketed as cod'},
#     {'word': 'hapuku', 'sense': 'similarly important local species'},
#     {'word': 'rock cod', 'sense': 'unrelated similar species'},
#     {'word': 'rockcod', 'sense': 'unrelated similar species'},
#     {'word': 'beardie (Lotella rhacina)',
#      'sense': 'unrelated similar species'},
#     {'word': 'cod icefish (the Nototheniidae)',
#      'sense': 'unrelated similar species'},
#     {'word': 'marbled rockcod (Notothenia rossii)',
#      'sense': 'unrelated similar species'},
#     {'word': 'emerald rockcod (Trematomus bernacchii)',
#      'sense': 'unrelated similar species'},
#     {'word': 'honeycomb rockcod', 'sense': 'unrelated similar species'},
#     {'word': 'dwarf spotted rockcod (Epinephelus merra)',
#      'sense': 'unrelated similar species'},
#     {'word': 'Maori cod', 'sense': 'unrelated similar species'},
#     {'word': 'Magellanic rockcod', 'sense': 'unrelated similar species'},
#     {'word': 'blue notothenia', 'sense': 'unrelated similar species'},
#     {'word': 'orange throat notothen (Paranotothenia magellanica)',
#      'sense': 'unrelated similar species'},
#     {'word': 'brown spotted reef cod', 'sense': 'unrelated similar species'},
#     {'word': 'brownspotted grouper (Epinephelus chlorostigma)',
#      'sense': 'unrelated similar species'},
#     {'word': 'red rock cod', 'sense': 'unrelated similar species'},
#     {'word': 'vermilion rockcod (Scorpaena papillosa)',
#      'sense': 'unrelated similar species'},
#     {'word': 'red snapper (Lutjanus spp.)',
#      'sense': 'unrelated similar species'},
#     {'word': 'vermilion seaperch', 'sense': 'unrelated similar species'},
#     {'word': 'vermilion rockfish (Sebastes miniatus)',
#      'sense': 'unrelated similar species'},
#     {'word': 'grouper (the Serranidae)', 'sense': 'unrelated similar species'},
#     {'word': 'thornyhead (Sebastidae)',
#      'sense': 'unrelated similar species'}]},
#   20: {'_id': ObjectId('60544a9511fe31d283dee281'),
#    'word': 'Germany',
#    'synonyms': [{'word': 'Federal Republic of Germany (FRG, BRD)',
#      'sense': 'present state'},
#     {'word': 'German Republic', 'sense': 'present state'},
#     {'word': 'See West Germany and East Germany', 'sense': '1949-1990'},
#     {'word': 'Nazi Germany', 'sense': '1933-1945'},
#     {'word': 'Third Reich', 'sense': '1933-1945'},
#     {'word': 'Weimar Republic', 'sense': '1919-1933'},
#     {'word': 'Weimar Germany', 'sense': '1919-1933'},
#     {'word': 'German Empire', 'sense': '1871-1918'},
#     {'word': 'German Reich', 'sense': '1871-1918'},
#     {'word': 'Second Reich', 'sense': '1871-1918'},
#     {'word': 'North German Confederation',
#      'sense': 'early 19th century, partial'},
#     {'word': 'German Confederation', 'sense': 'early 19th century, partial'},
#     {'word': 'Confederation of the Rhine',
#      'sense': 'early 19th century, partial'},
#     {'word': 'Holy Roman Empire', 'sense': 'earlier'},
#     {'word': 'First Reich', 'sense': 'earlier'},
#     {'word': 'East Francia', 'sense': 'earlier'},
#     {'word': 'Austrasia', 'sense': 'earlier'},
#     {'word': 'Germania', 'sense': 'earlier'},
#     {'word': 'Dutchland', 'sense': 'obsolete'},
#     {'word': 'Germanland', 'sense': 'obsolete'}]},
#   21: {'_id': ObjectId('60544a9511fe31d283dee2c5'),
#    'word': 'slow',
#    'synonyms': [{'word': 'deliberate',
#      'sense': 'taking a long time to move a short distance'},
#     {'word': 'moderate',
#      'sense': 'taking a long time to move a short distance'},
#     {'word': 'see also Thesaurus:slow',
#      'sense': 'taking a long time to move a short distance'},
#     {'word': 'gradual', 'sense': 'not happening in a short time'},
#     {'word': 'see also Thesaurus:gradual',
#      'sense': 'not happening in a short time'},
#     {'word': 'dull-witted', 'sense': 'of reduced intellectual capacity'},
#     {'word': 'see also Thesaurus:stupid',
#      'sense': 'of reduced intellectual capacity'},
#     {'word': 'careful', 'sense': 'acting with deliberation'},
#     {'word': 'deliberate', 'sense': 'acting with deliberation'},
#     {'word': 'prudent', 'sense': 'acting with deliberation'},
#     {'word': 'see also Thesaurus:cautious',
#      'sense': 'acting with deliberation'},
#     {'word': 'boring', 'sense': 'lacking spirit'},
#     {'word': 'dilatory', 'sense': 'lacking spirit'},
#     {'word': 'dull', 'sense': 'lacking spirit'},
#     {'word': 'inactive', 'sense': 'lacking spirit'},
#     {'word': 'tardy', 'sense': 'lacking spirit'},
#     {'word': 'slothful', 'sense': 'lacking spirit'},
#     {'word': 'sluggish', 'sense': 'lacking spirit'},
#     {'word': 'see also Thesaurus:inactive or Thesaurus:boring',
#      'sense': 'lacking spirit'},
#     {'word': 'quiet', 'sense': 'not busy'},
#     {'word': 'unbusy', 'sense': 'not busy'}]},
#   35: {'_id': ObjectId('60544a9711fe31d283dee5e8'),
#    'word': 'money',
#    'synonyms': [{'word': 'beer tickets'},
#     {'word': 'bread'},
#     {'word': 'bucks'},
#     {'word': 'cake'},
#     {'word': 'cash'},
#     {'word': 'cheddar'},
#     {'word': 'coin'},
#     {'word': 'cream'},
#     {'word': 'currency'},
#     {'word': 'dinars'},
#     {'word': 'dosh'},
#     {'word': 'dough'},
#     {'word': 'ducats'},
#     {'word': 'folding stuff'},
#     {'word': 'funds'},
#     {'word': 'geld'},
#     {'word': 'gelt'},
#     {'word': 'greenbacks'},
#     {'word': 'jack'},
#     {'word': 'legal tender'},
#     {'word': 'lolly'},
#     {'word': 'means'},
#     {'word': 'moolah'},
#     {'word': 'lucre'},
#     {'word': 'paper'},
#     {'word': 'pennies'},
#     {'word': 'readies'},
#     {'word': 'sheets'},
#     {'word': 'shrapnel'},
#     {'word': 'simoleons'},
#     {'word': 'spends'},
#     {'word': 'spondulicks'},
#     {'word': 'sterling'},
#     {'word': 'wonga'},
#     {'word': 'See also Thesaurus:money'}]},
#   26: {'_id': ObjectId('60544a9811fe31d283dee920'),
#    'word': 'fall',
#    'synonyms': [{'word': 'drop',
#      'sense': 'move to a lower position under the effect of gravity'},
#     {'word': 'plummet',
#      'sense': 'move to a lower position under the effect of gravity'},
#     {'word': 'plunge',
#      'sense': 'move to a lower position under the effect of gravity'},
#     {'word': 'come down', 'sense': 'come down'},
#     {'word': 'descend', 'sense': 'come down'},
#     {'word': 'drop', 'sense': 'come down'},
#     {'word': 'drop', 'sense': 'come to the ground deliberately'},
#     {'word': 'lower oneself', 'sense': 'come to the ground deliberately'},
#     {'word': 'prostrate oneself', 'sense': 'come to the ground deliberately'},
#     {'word': 'be beaten by',
#      'tags': ['collapse', 'be overthrown or defeated'],
#      'translation': 'collapse; be overthrown or defeated'},
#     {'word': 'be defeated by',
#      'tags': ['collapse', 'be overthrown or defeated'],
#      'translation': 'collapse; be overthrown or defeated'},
#     {'word': 'be overthrown by',
#      'tags': ['collapse', 'be overthrown or defeated'],
#      'translation': 'collapse; be overthrown or defeated'},
#     {'word': 'be smitten by',
#      'tags': ['collapse', 'be overthrown or defeated'],
#      'translation': 'collapse; be overthrown or defeated'},
#     {'word': 'be vanquished by',
#      'tags': ['collapse', 'be overthrown or defeated'],
#      'translation': 'collapse; be overthrown or defeated'},
#     {'word': 'dip',
#      'tags': ['become lower (in quantity, pitch, etc)'],
#      'translation': 'become lower (in quantity, pitch, etc)'},
#     {'word': 'drop',
#      'tags': ['become lower (in quantity, pitch, etc)'],
#      'translation': 'become lower (in quantity, pitch, etc)'},
#     {'word': 'cut down (of a tree)',
#      'topics': ['cause', 'property'],
#      'tags': ['cause (something) to descend to the ground'],
#      'translation': 'cause (something) to descend to the ground'},
#     {'word': 'fell',
#      'topics': ['cause', 'property'],
#      'tags': ['cause (something) to descend to the ground'],
#      'translation': 'cause (something) to descend to the ground'},
#     {'word': 'knock down',
#      'topics': ['cause', 'property'],
#      'tags': ['cause (something) to descend to the ground'],
#      'translation': 'cause (something) to descend to the ground'},
#     {'word': 'knock over',
#      'topics': ['cause', 'property'],
#      'tags': ['cause (something) to descend to the ground'],
#      'translation': 'cause (something) to descend to the ground'},
#     {'word': 'strike down',
#      'topics': ['cause', 'property'],
#      'tags': ['cause (something) to descend to the ground'],
#      'translation': 'cause (something) to descend to the ground'},
#     {'word': 'die', 'sense': 'die'},
#     {'word': 'be the responsibility of', 'sense': 'be allotted to'},
#     {'word': 'be up to', 'sense': 'be allotted to'},
#     {'word': 'become', 'sense': 'become'},
#     {'word': 'get', 'sense': 'become'}]},
#   52: {'_id': ObjectId('60544a9b11fe31d283deefc0'),
#    'word': 'bad',
#    'synonyms': [{'word': 'unfavorable', 'sense': 'not good'},
#     {'word': 'negative', 'sense': 'not good'},
#     {'word': 'see also Thesaurus:bad', 'sense': 'not good'},
#     {'word': 'unhealthful', 'sense': 'liable to cause health problems'},
#     {'word': 'unwholesome', 'sense': 'liable to cause health problems'},
#     {'word': 'see also Thesaurus:harmful',
#      'sense': 'liable to cause health problems'},
#     {'word': 'ill', 'sense': 'unhealthy; unwell'},
#     {'word': 'poorly', 'sense': 'unhealthy; unwell'},
#     {'word': 'sickly', 'sense': 'unhealthy; unwell'},
#     {'word': 'see also Thesaurus:ill', 'sense': 'unhealthy; unwell'},
#     {'word': 'faulty', 'sense': 'not functional'},
#     {'word': 'inoperative', 'sense': 'not functional'},
#     {'word': 'see also Thesaurus:out of order', 'sense': 'not functional'},
#     {'word': 'rotten', 'sense': 'of food'},
#     {'word': 'see also Thesaurus:rotten', 'sense': 'of food'},
#     {'word': 'malodorous', 'sense': 'of breath'},
#     {'word': 'foul', 'sense': 'of breath'},
#     {'word': 'see also Thesaurus:malodorous', 'sense': 'of breath'},
#     {'word': 'false', 'sense': 'false; counterfeit'},
#     {'word': 'spurious', 'sense': 'false; counterfeit'},
#     {'word': 'see also Thesaurus:fake', 'sense': 'false; counterfeit'},
#     {'word': 'bungling', 'sense': 'of limited ability'},
#     {'word': 'inept', 'sense': 'of limited ability'},
#     {'word': 'see also Thesaurus:unskilled', 'sense': 'of limited ability'},
#     {'word': 'badass', 'sense': 'bold, daring'},
#     {'word': 'see also Thesaurus:brave', 'sense': 'bold, daring'},
#     {'word': 'dire', 'sense': 'of a need or want'},
#     {'word': 'severe', 'sense': 'of a need or want'},
#     {'word': 'urgent', 'sense': 'of a need or want'},
#     {'word': 'see also Thesaurus:urgent', 'sense': 'of a need or want'},
#     {'word': 'rubber', 'sense': 'of a draft/check'},
#     {'word': 'hot', 'sense': 'of a draft/check'},
#     {'word': 'disgusting'},
#     {'word': 'wrong'},
#     {'word': 'corrupt'},
#     {'word': 'base'},
#     {'word': 'abandoned'},
#     {'word': 'vicious'},
#     {'word': 'abominable'},
#     {'word': 'detestable'},
#     {'word': 'deficient'},
#     {'word': 'inferior'},
#     {'word': 'lousy'},
#     {'word': 'off'},
#     {'word': 'poor'},
#     {'word': 'punk'},
#     {'word': 'substandard'},
#     {'word': 'unacceptable'},
#     {'word': 'ungodly'},
#     {'word': 'unsatisfactory'},
#     {'word': 'wanting'},
#     {'word': 'wretched'}]},
#   46: {'_id': ObjectId('60544a9c11fe31d283def2a0'),
#    'word': 'nationality',
#    'synonyms': [{'word': 'affiliation',
#      'sense': 'membership of a nation or state'},
#     {'word': 'allegiance', 'sense': 'membership of a nation or state'},
#     {'word': 'ancestry', 'sense': 'membership of a nation or state'},
#     {'word': 'citizenship', 'sense': 'membership of a nation or state'},
#     {'word': 'descent', 'sense': 'membership of a nation or state'},
#     {'word': 'enfranchisement', 'sense': 'membership of a nation or state'},
#     {'word': 'ethnicity', 'sense': 'membership of a nation or state'},
#     {'word': 'national status', 'sense': 'membership of a nation or state'},
#     {'word': 'naturalization', 'sense': 'membership of a nation or state'},
#     {'word': 'origin', 'sense': 'membership of a nation or state'},
#     {'word': 'parentage', 'sense': 'membership of a nation or state'},
#     {'word': 'race', 'sense': 'membership of a nation or state'},
#     {'word': 'residence', 'sense': 'membership of a nation or state'},
#     {'word': 'status', 'sense': 'membership of a nation or state'},
#     {'word': 'ancestry', 'sense': 'national character or identity'},
#     {'word': 'color', 'sense': 'national character or identity'},
#     {'word': 'colour', 'sense': 'national character or identity'},
#     {'word': 'ethnicity', 'sense': 'national character or identity'},
#     {'word': 'identity', 'sense': 'national character or identity'},
#     {'word': 'origin', 'sense': 'national character or identity'},
#     {'word': 'clan', 'sense': 'a people'},
#     {'word': 'confederation', 'sense': 'a people'},
#     {'word': 'cultural group', 'sense': 'a people'},
#     {'word': 'culture', 'sense': 'a people'},
#     {'word': 'denomination', 'sense': 'a people'},
#     {'word': 'ethnic group', 'sense': 'a people'},
#     {'word': 'ethnicity', 'sense': 'a people'},
#     {'word': 'faith', 'sense': 'a people'},
#     {'word': 'group', 'sense': 'a people'},
#     {'word': 'nation', 'sense': 'a people'},
#     {'word': 'people', 'sense': 'a people'},
#     {'word': 'persuasion', 'sense': 'a people'},
#     {'word': 'race', 'sense': 'a people'},
#     {'word': 'sect', 'sense': 'a people'},
#     {'word': 'tribe', 'sense': 'a people'},
#     {'word': 'autarchy', 'sense': 'political existence as a national entity'},
#     {'word': 'autonomy', 'sense': 'political existence as a national entity'},
#     {'word': 'freedom', 'sense': 'political existence as a national entity'},
#     {'word': 'independence',
#      'sense': 'political existence as a national entity'},
#     {'word': 'liberty', 'sense': 'political existence as a national entity'},
#     {'word': 'nationhood',
#      'sense': 'political existence as a national entity'},
#     {'word': 'self-determination',
#      'sense': 'political existence as a national entity'},
#     {'word': 'self-government',
#      'sense': 'political existence as a national entity'},
#     {'word': 'self-rule', 'sense': 'political existence as a national entity'},
#     {'word': 'separation',
#      'sense': 'political existence as a national entity'},
#     {'word': 'sovereignty',
#      'sense': 'political existence as a national entity'}]},
#   17: {'_id': ObjectId('60544a9c11fe31d283def2db'),
#    'word': 'jerk',
#    'synonyms': [{'word': 'jolt', 'sense': 'sudden movement'},
#     {'word': 'lurch', 'sense': 'sudden movement'},
#     {'word': 'jump', 'sense': 'sudden movement'},
#     {'word': 'yank', 'sense': 'quick tug'},
#     {'word': 'numbskull', 'sense': 'stupid person'},
#     {'word': 'asshole', 'sense': 'unlikable person'},
#     {'word': 'bastard', 'sense': 'unlikable person'},
#     {'word': 'twat', 'sense': 'unlikable person'},
#     {'word': 'knobhead', 'sense': 'unlikable person'},
#     {'word': 'tosser', 'sense': 'unlikable person'},
#     {'word': 'wanker', 'sense': 'unlikable person'},
#     {'word': 'git', 'sense': 'unlikable person'},
#     {'word': 'dick', 'sense': 'unlikable person'},
#     {'word': 'see Thesaurus:jerk.', 'sense': 'unlikable person'},
#     {'word': 'jolt (British)',
#      'tags': ['British'],
#      'sense': 'physics, change in acceleration'},
#     {'word': 'surge',
#      'tags': ['British'],
#      'sense': 'physics, change in acceleration'},
#     {'word': 'lurch',
#      'tags': ['British'],
#      'sense': 'physics, change in acceleration'}]},
#   30: {'_id': ObjectId('60544a9d11fe31d283def549'),
#    'word': 'hang',
#    'synonyms': [{'word': 'be suspended', 'sense': 'be or remain suspended'},
#     {'word': 'dangle', 'sense': 'be or remain suspended'},
#     {'word': 'float', 'sense': 'float as if suspended'},
#     {'word': 'hover', 'sense': 'float as if suspended'},
#     {'word': 'lynch',
#      'sense': 'execute (someone) by suspension from the neck'},
#     {'word': 'string up',
#      'sense': 'execute (someone) by suspension from the neck'},
#     {'word': 'see also Thesaurus:kill by hanging',
#      'sense': 'execute (someone) by suspension from the neck'},
#     {'word': 'go to the gallows', 'tags': ['archaic'], 'sense': 'be executed'},
#     {'word': 'swing (informal)', 'tags': ['archaic'], 'sense': 'be executed'},
#     {'word': 'take a ride to Tyburn (archaic)',
#      'tags': ['archaic'],
#      'sense': 'be executed'},
#     {'word': 'see also Thesaurus:die by hanging',
#      'tags': ['archaic'],
#      'sense': 'be executed'},
#     {'word': 'hang about', 'sense': 'loiter'},
#     {'word': 'hang around', 'sense': 'loiter'},
#     {'word': 'loiter', 'sense': 'loiter'},
#     {'word': 'freeze', 'sense': 'computing: stop responding'},
#     {'word': 'lock up', 'sense': 'computing: stop responding'},
#     {'word': 'suspend', 'sense': 'cause (something) to be suspended'},
#     {'word': 'drop',
#      'sense': 'hold or bear in a suspended or inclined manner or position instead of erect'},
#     {'word': 'lower',
#      'sense': 'hold or bear in a suspended or inclined manner or position instead of erect'},
#     {'word': 'hook', 'sense': 'to place on a hook'},
#     {'word': 'hook up', 'sense': 'to place on a hook'},
#     {'word': 'hang up', 'sense': 'to put a telephone handset back on a hook'},
#     {'word': 'exhibit', 'sense': 'exhibit'},
#     {'word': 'show', 'sense': 'exhibit'},
#     {'word': 'put up', 'sense': 'apply (wallpaper to a wall)'},
#     {'word': 'bedeck', 'sense': 'decorate (something) with hanging objects'},
#     {'word': 'deck', 'sense': 'decorate (something) with hanging objects'},
#     {'word': 'decorate', 'sense': 'decorate (something) with hanging objects'},
#     {'word': 'freeze',
#      'sense': 'computing: cause (a program or computer) to stop responding'},
#     {'word': 'lock up',
#      'sense': 'computing: cause (a program or computer) to stop responding'}]},
#   29: {'_id': ObjectId('60544aa011fe31d283defb33'),
#    'word': 'swallow',
#    'synonyms': [{'word': 'consume',
#      'sense': 'to cause to pass from the mouth into the stomach'},
#     {'word': 'devour',
#      'sense': 'to cause to pass from the mouth into the stomach'},
#     {'word': 'eat',
#      'sense': 'to cause to pass from the mouth into the stomach'},
#     {'word': 'gulp',
#      'sense': 'to cause to pass from the mouth into the stomach'},
#     {'word': 'absorb', 'sense': 'to take in'},
#     {'word': 'assimilate', 'sense': 'to take in'},
#     {'word': 'engulf', 'sense': 'to take in'},
#     {'word': 'incorporate', 'sense': 'to take in'},
#     {'word': 'swallow up', 'sense': 'to take in'},
#     {'word': 'overwhelm', 'sense': 'to take in'},
#     {'word': 'see also Thesaurus:integrate', 'sense': 'to take in'},
#     {'word': 'gulp',
#      'sense': 'to make muscular contractions of the oesophagus'},
#     {'word': 'buy', 'sense': 'to believe or accept'},
#     {'word': 'creed', 'sense': 'to believe or accept'},
#     {'word': 'credit', 'sense': 'to believe or accept'},
#     {'word': 'absorb', 'sense': 'to engross'},
#     {'word': 'engage', 'sense': 'to engross'},
#     {'word': 'immerse', 'sense': 'to engross'},
#     {'word': 'monopolize', 'sense': 'to engross'},
#     {'word': 'take over', 'sense': 'to engross'},
#     {'word': 'occupy', 'sense': 'to engross'},
#     {'word': 'disavow', 'sense': 'to retract'},
#     {'word': 'take back', 'sense': 'to retract'},
#     {'word': 'unsay', 'sense': 'to retract'},
#     {'word': 'See also Thesaurus:recant', 'sense': 'to retract'},
#     {'word': 'brook', 'sense': 'to put up with'},
#     {'word': 'endure', 'sense': 'to put up with'},
#     {'word': 'live with', 'sense': 'to put up with'},
#     {'word': 'See also Thesaurus:tolerate', 'sense': 'to put up with'}]},
#   41: {'_id': ObjectId('60544ab611fe31d283df2f9b'),
#    'word': 'shut up',
#    'synonyms': [{'word': 'close off', 'sense': 'close (a building)'},
#     {'word': 'seal up', 'sense': 'close (a building)'},
#     {'word': 'end', 'sense': 'terminate (a business)'},
#     {'word': 'terminate', 'sense': 'terminate (a business)'},
#     {'word': 'wind up', 'sense': 'terminate (a business)'},
#     {'word': 'lock in',
#      'sense': 'enclose (a person, animal or thing) in a room so that it cannot leave'},
#     {'word': 'seal in',
#      'sense': 'enclose (a person, animal or thing) in a room so that it cannot leave'},
#     {'word': 'lock up', 'sense': 'put (an object) in a secure enclosed place'},
#     {'word': 'stash', 'sense': 'put (an object) in a secure enclosed place'},
#     {'word': 'stash away',
#      'sense': 'put (an object) in a secure enclosed place'},
#     {'word': 'hush',
#      'sense': 'to stop (a person) from talking or (a person or thing) making noise'},
#     {'word': 'quieten',
#      'sense': 'to stop (a person) from talking or (a person or thing) making noise'},
#     {'word': 'shush',
#      'sense': 'to stop (a person) from talking or (a person or thing) making noise'},
#     {'word': 'silence',
#      'sense': 'to stop (a person) from talking or (a person or thing) making noise'},
#     {'word': 'be quiet',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'be silent',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'fall silent',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'hush',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'quieten down',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shush',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': '(in the imperative): be quiet!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'can it!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'hush!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'put a sock in it!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'quiet!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'sh!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shush!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shut it!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shut your face! (impolite)',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shut your mouth! (impolite)',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'shaddap',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'silence!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'st!',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'STFU',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'see also Thesaurus:stop talking',
#      'tags': ['impolite'],
#      'sense': 'to stop talking or making noise'},
#     {'word': 'get out!', 'sense': "I don't believe it"},
#     {'word': 'never!', 'sense': "I don't believe it"},
#     {'word': 'no!', 'sense': "I don't believe it"},
#     {'word': 'no way!', 'sense': "I don't believe it"},
#     {'word': 'yeah right!', 'sense': "I don't believe it"},
#     {'word': "you don't say!", 'sense': "I don't believe it"}]},
#   27: {'_id': ObjectId('60544ab611fe31d283df2fe8'),
#    'word': 'masturbate',
#    'synonyms': [{'word': 'bash the bishop'},
#     {'word': 'beat off'},
#     {'word': 'beat the meat'},
#     {'word': 'choke the chicken'},
#     {'word': 'diddle'},
#     {'word': 'fap'},
#     {'word': 'flog the dong'},
#     {'word': 'flick the bean'},
#     {'word': 'have fun with Dick and Jane'},
#     {'word': 'jack it'},
#     {'word': 'jack off'},
#     {'word': 'jerk off'},
#     {'word': 'jill'},
#     {'word': 'jill off'},
#     {'word': 'knock one off'},
#     {'word': 'knock one out'},
#     {'word': 'play with oneself'},
#     {'word': 'polish the pole'},
#     {'word': 'rub one out'},
#     {'word': 'slap the salami'},
#     {'word': 'spank the monkey'},
#     {'word': 'stroke it'},
#     {'word': 'tickle the sausage'},
#     {'word': 'toss off'},
#     {'word': 'wank'},
#     {'word': 'whack off'},
#     {'word': 'See Thesaurus:masturbate'}]},
#   38: {'_id': ObjectId('60544aea11fe31d283dfcc02'),
#    'word': 'fanny',
#    'synonyms': [{'word': 'bearded clam', 'sense': 'vulva or vagina'},
#     {'word': 'beaver', 'sense': 'vulva or vagina'},
#     {'word': 'beddemann shoe', 'sense': 'vulva or vagina'},
#     {'word': 'beef curtains', 'sense': 'vulva or vagina'},
#     {'word': 'box', 'sense': 'vulva or vagina'},
#     {'word': 'bush', 'sense': 'vulva or vagina'},
#     {'word': 'clunge', 'sense': 'vulva or vagina'},
#     {'word': 'cooch', 'sense': 'vulva or vagina'},
#     {'word': 'coochie', 'sense': 'vulva or vagina'},
#     {'word': 'cunt', 'sense': 'vulva or vagina'},
#     {'word': 'flange', 'sense': 'vulva or vagina'},
#     {'word': 'front bottom', 'sense': 'vulva or vagina'},
#     {'word': 'front bum', 'sense': 'vulva or vagina'},
#     {'word': 'gash', 'sense': 'vulva or vagina'},
#     {'word': 'ham wallet', 'sense': 'vulva or vagina'},
#     {'word': 'kebab', 'sense': 'vulva or vagina'},
#     {'word': 'lips', 'sense': 'vulva or vagina'},
#     {'word': 'minge', 'sense': 'vulva or vagina'},
#     {'word': 'muff', 'sense': 'vulva or vagina'},
#     {'word': 'pork pit', 'sense': 'vulva or vagina'},
#     {'word': 'pussy', 'sense': 'vulva or vagina'},
#     {'word': 'quim', 'sense': 'vulva or vagina'},
#     {'word': 'slit', 'sense': 'vulva or vagina'},
#     {'word': 'snatch', 'sense': 'vulva or vagina'},
#     {'word': 'the pink', 'sense': 'vulva or vagina'},
#     {'word': 'twat', 'sense': 'vulva or vagina'},
#     {'word': 'vertical smile', 'sense': 'vulva or vagina'},
#     {'word': 'see also Thesaurus:vagina and Thesaurus:vulva',
#      'sense': 'vulva or vagina'},
#     {'word': 'arse', 'sense': 'buttocks'},
#     {'word': 'ass', 'sense': 'buttocks'},
#     {'word': 'booty', 'sense': 'buttocks'},
#     {'word': 'bum', 'sense': 'buttocks'},
#     {'word': 'butt', 'sense': 'buttocks'},
#     {'word': 'hiney', 'sense': 'buttocks'},
#     {'word': 'keester', 'sense': 'buttocks'},
#     {'word': 'tush', 'sense': 'buttocks'},
#     {'word': 'tushie', 'sense': 'buttocks'},
#     {'word': 'see also Thesaurus:buttocks', 'sense': 'buttocks'}]}})

# %% [markdown]
# ## translations
# keep

# %%
cns = [{'lang': 'Chinese',
    'code': 'yue',
    'tags': ['Cantonese'],
    'sense': 'news items',
    'word': '時事'},
   {'lang': 'Chinese',
    'code': 'yue',
    'tags': ['Cantonese'],
    'sense': 'news items',
    'word': '时事',
    'roman': 'si^4 si^6'},
   {'lang': 'Chinese',
    'code': 'cmn',
    'tags': ['Mandarin'],
    'sense': 'news items',
    'word': '時事'},
   {'lang': 'Chinese',
    'code': 'cmn',
    'tags': ['Mandarin'],
    'sense': 'news items',
    'word': '时事',
    'roman': 'shíshì'}]

# %%
data = query_words_by_key('translations')
len(data)
# Out:
# 32146

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc23'),
#   'word': 'portmanteau',
#   'translations': [{'lang': 'Albanian',
#     'code': 'sq',
#     'sense': 'case',
#     'word': 'baule',
#     'tags': ['feminine']},
#    {'lang': 'Arabic', 'code': 'ar', 'sense': 'case', 'word': 'حقيبَة سفر'},
#    {'lang': 'Breton',
#     'code': 'br',
#     'sense': 'case',
#     'word': 'mal',
#     'tags': ['feminine']},
#    {'lang': 'Breton',
#     'code': 'br',
#     'sense': 'case',
#     'word': 'malizenn',
#     'tags': ['feminine']},
#    {'lang': 'Bulgarian',
#     'code': 'bg',
#     'sense': 'case',
#     'word': 'голям кожен куфар',
#     'roman': 'goljam kožen kufar'},
#    {'lang': 'Czech', 'code': 'cs', 'sense': 'case', 'word': 'kontaminace'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'case',
#     'word': 'koffer',
#     'tags': ['feminine']},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'case',
#     'word': 'valies',
#     'tags': ['feminine']},
#    {'lang': 'Finnish', 'code': 'fi', 'sense': 'case', 'word': 'matkalaukku'},
#    {'lang': 'French',
#     'code': 'fr',
#     'sense': 'case',
#     'word': 'portemanteau',
#     'tags': ['masculine']},
#    {'lang': 'French',
#     'code': 'fr',
#     'sense': 'case',
#     'word': 'valise',
#     'tags': ['feminine']},
#    {'lang': 'French',
#     'code': 'fr',
#     'sense': 'case',
#     'word': 'malle',
#     'tags': ['feminine']},
#    {'lang': 'German',
#     'code': 'de',
#     'sense': 'case',
#     'word': 'Koffer',
#     'tags': ['masculine']},
#    {'lang': 'Interlingua', 'code': None, 'sense': 'case', 'word': 'valise'},
#    {'lang': 'Norwegian',
#     'code': 'no',
#     'sense': 'case',
#     'word': 'koffert',
#     'tags': ['masculine']},
#    {'lang': 'Norwegian',
#     'code': 'no',
#     'tags': ['Bokmål', 'masculine'],
#     'sense': 'case',
#     'word': 'koffert'},
#    {'lang': 'Norwegian',
#     'code': 'nn',
#     'tags': ['Nynorsk', 'masculine'],
#     'sense': 'case',
#     'word': 'koffert'},
#    {'lang': 'Persian',
#     'code': 'fa',
#     'sense': 'case',
#     'word': 'چمدان',
#     'roman': 'chamedan'},
#    {'lang': 'Polish',
#     'code': 'pl',
#     'sense': 'case',
#     'word': 'waliza',
#     'tags': ['feminine']},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'case',
#     'word': 'maleta',
#     'tags': ['feminine']},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'case',
#     'word': 'valise',
#     'tags': ['feminine']},
#    {'lang': 'Romanian',
#     'code': 'ro',
#     'sense': 'case',
#     'word': 'valiză',
#     'tags': ['feminine']},
#    {'lang': 'Russian',
#     'code': 'ru',
#     'sense': 'case',
#     'word': 'чемода́н',
#     'tags': ['masculine'],
#     'roman': 'čemodán'},
#    {'lang': 'Russian',
#     'code': 'ru',
#     'sense': 'case',
#     'word': 'бау́л',
#     'tags': ['masculine'],
#     'roman': 'baúl'},
#    {'lang': 'Russian',
#     'code': 'ru',
#     'sense': 'case',
#     'word': 'дорожная су́мка',
#     'tags': ['feminine'],
#     'roman': 'súmka'},
#    {'lang': 'Serbo-Croatian',
#     'code': 'sh',
#     'tags': ['Cyrillic', 'masculine'],
#     'sense': 'case',
#     'word': 'кожни кофер',
#     'roman': 'kožni kofer'},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'case',
#     'word': 'maleta',
#     'tags': ['feminine']},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'case',
#     'word': 'valija',
#     'tags': ['feminine']},
#    {'lang': 'Turkish', 'code': 'tr', 'sense': 'case', 'word': 'bavul'},
#    {'lang': 'Vietnamese', 'code': 'vi', 'sense': 'case', 'word': 'va li'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc2c'),
#   'word': 'GDP',
#   'translations': [{'lang': 'Afrikaans',
#     'code': 'af',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BBP'},
#    {'lang': 'Albanian',
#     'code': 'sq',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BDV'},
#    {'lang': 'Aragonese',
#     'code': 'an',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Armenian',
#     'code': 'hy',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ՀՆԱ',
#     'roman': 'HNA'},
#    {'lang': 'Azerbaijani',
#     'code': 'az',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ÜDM'},
#    {'lang': 'Bambara',
#     'code': 'bm',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BSK'},
#    {'lang': 'Basque',
#     'code': 'eu',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BPG'},
#    {'lang': 'Bavarian',
#     'code': 'bar',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BIP'},
#    {'lang': 'Belarusian',
#     'code': 'be',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ВУП',
#     'roman': 'VUP'},
#    {'lang': 'Breton',
#     'code': 'br',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PDG'},
#    {'lang': 'Bulgarian',
#     'code': 'bg',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'БВП',
#     'roman': 'BVP'},
#    {'lang': 'Catalan',
#     'code': 'ca',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Czech',
#     'code': 'cs',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'HDP'},
#    {'lang': 'Danish',
#     'code': 'da',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BNP'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BBP'},
#    {'lang': 'Esperanto',
#     'code': 'eo',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'MEP'},
#    {'lang': 'Estonian',
#     'code': 'et',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'SKT'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BKT'},
#    {'lang': 'French',
#     'code': 'fr',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB',
#     'tags': ['masculine']},
#    {'lang': 'Galician',
#     'code': 'gl',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Georgian',
#     'code': 'ka',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'მშპ',
#     'roman': 'mšṗ'},
#    {'lang': 'German',
#     'code': 'de',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BIP'},
#    {'lang': 'Greek',
#     'code': 'el',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ΑΕΠ',
#     'roman': 'AEP'},
#    {'lang': 'Hebrew',
#     'code': 'he',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'תמ״ג',
#     'roman': 'T.M.G.'},
#    {'lang': 'Hungarian',
#     'code': 'hu',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BHT'},
#    {'lang': 'Ido',
#     'code': 'io',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'KLP'},
#    {'lang': 'Indonesian',
#     'code': 'id',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'GDP'},
#    {'lang': 'Indonesian',
#     'code': 'id',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PDB'},
#    {'lang': 'Irish',
#     'code': 'ga',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'OTI'},
#    {'lang': 'Italian',
#     'code': 'it',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIL'},
#    {'lang': 'Japanese',
#     'code': 'ja',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'GDP'},
#    {'lang': 'Javanese',
#     'code': 'jv',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PDB'},
#    {'lang': 'Karachay-Balkar',
#     'code': 'krc',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'БИП'},
#    {'lang': 'Kazakh',
#     'code': 'kk',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ЖІӨ',
#     'roman': 'JİÖ'},
#    {'lang': 'Kyrgyz',
#     'code': 'ky',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ИДП',
#     'roman': 'İDP'},
#    {'lang': 'Latin',
#     'code': 'la',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PDG'},
#    {'lang': 'Latvian',
#     'code': 'lv',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'IKP'},
#    {'lang': 'Lithuanian',
#     'code': 'lt',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BVP'},
#    {'lang': 'Macedonian',
#     'code': 'mk',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'БДП',
#     'roman': 'BDP'},
#    {'lang': 'Malay',
#     'code': 'ms',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'KDNK'},
#    {'lang': 'Manx',
#     'code': 'gv',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'LTS'},
#    {'lang': 'Occitan',
#     'code': 'oc',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Polish',
#     'code': 'pl',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PKB',
#     'tags': ['inanimate', 'masculine', 'neuter']},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Romanian',
#     'code': 'ro',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Russian',
#     'code': 'ru',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ВВП',
#     'tags': ['masculine'],
#     'roman': 'VVP'},
#    {'lang': 'Serbo-Croatian',
#     'code': 'sh',
#     'tags': ['Cyrillic'],
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'БДП'},
#    {'lang': 'Serbo-Croatian',
#     'code': 'sh',
#     'tags': ['Roman'],
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BDP'},
#    {'lang': 'Sicilian',
#     'code': 'scn',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PNL'},
#    {'lang': 'Slovak',
#     'code': 'sk',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'HDP'},
#    {'lang': 'Slovene',
#     'code': 'sl',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BDP'},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIB'},
#    {'lang': 'Swedish',
#     'code': 'sv',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'BNP'},
#    {'lang': 'Tagalog',
#     'code': 'tl',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PDP'},
#    {'lang': 'Turkish',
#     'code': 'tr',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'GSYİH'},
#    {'lang': 'Turkish',
#     'code': 'tr',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'GSMH'},
#    {'lang': 'Udmurt',
#     'code': 'udm',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ВВП',
#     'roman': 'VVP'},
#    {'lang': 'Ukrainian',
#     'code': 'uk',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'ВВП',
#     'roman': 'VVP'},
#    {'lang': 'Venetian',
#     'code': 'vec',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'PIL'},
#    {'lang': 'Welsh',
#     'code': 'cy',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'CMC'},
#    {'lang': 'Yakut',
#     'code': 'sah',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'БИО',
#     'roman': 'BİO'},
#    {'lang': 'Yoruba',
#     'code': 'yo',
#     'sense': 'abbreviation of gross domestic product See also translations at gross domestic product',
#     'word': 'GIO'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc2d'),
#   'word': 'denotation',
#   'translations': [{'lang': 'Bulgarian',
#     'code': 'bg',
#     'sense': 'act of denoting',
#     'word': 'означаване',
#     'tags': ['neuter'],
#     'roman': 'označavane'},
#    {'lang': 'Catalan',
#     'code': 'ca',
#     'sense': 'act of denoting',
#     'word': 'denotació',
#     'tags': ['feminine']},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'act of denoting',
#     'word': 'denotatie'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'act of denoting',
#     'word': 'beschrijving'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'act of denoting',
#     'word': 'merkitseminen',
#     'roman': 'act'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'act of denoting',
#     'word': 'merkki',
#     'roman': 'something that denotes'},
#    {'lang': 'Hungarian',
#     'code': 'hu',
#     'sense': 'act of denoting',
#     'word': 'megjelölés'},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'act of denoting',
#     'word': 'denotação',
#     'tags': ['feminine']},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'act of denoting',
#     'word': 'denotación',
#     'tags': ['feminine']},
#    {'lang': 'Bulgarian',
#     'code': 'bg',
#     'sense': 'primary or explicit meaning',
#     'word': 'главно значение',
#     'tags': ['neuter'],
#     'roman': 'glavno značenie'},
#    {'lang': 'Catalan',
#     'code': 'ca',
#     'sense': 'primary or explicit meaning',
#     'word': 'denotació',
#     'tags': ['feminine']},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'primary or explicit meaning',
#     'word': 'denotatie'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'primary or explicit meaning',
#     'word': 'betekenis'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'primary or explicit meaning',
#     'word': 'perusmerkitys'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'primary or explicit meaning',
#     'word': 'denotaatio'},
#    {'lang': 'Hungarian',
#     'code': 'hu',
#     'sense': 'primary or explicit meaning',
#     'word': 'jelentés'},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'primary or explicit meaning',
#     'word': 'denotação',
#     'tags': ['feminine']},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'primary or explicit meaning',
#     'word': 'denotación',
#     'tags': ['feminine']},
#    {'lang': 'Bulgarian',
#     'code': 'bg',
#     'sense': 'something signified or referred to',
#     'word': 'обозначение',
#     'tags': ['neuter'],
#     'roman': 'oboznačenie'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'something signified or referred to',
#     'word': 'aanduiding'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'something signified or referred to',
#     'word': 'denotatie'},
#    {'lang': 'Dutch',
#     'code': 'nl',
#     'sense': 'something signified or referred to',
#     'word': 'betekenis'},
#    {'lang': 'Finnish',
#     'code': 'fi',
#     'sense': 'something signified or referred to',
#     'word': 'merkitys'},
#    {'lang': 'Hungarian',
#     'code': 'hu',
#     'sense': 'something signified or referred to',
#     'word': 'jel'},
#    {'lang': 'Portuguese',
#     'code': 'pt',
#     'sense': 'something signified or referred to',
#     'word': 'denotação',
#     'tags': ['feminine']},
#    {'lang': 'Spanish',
#     'code': 'es',
#     'sense': 'something signified or referred to',
#     'word': 'denotación',
#     'tags': ['feminine']}]}]

# %%
all_items = []

for item in data:
    all_items.extend(item['translations'])

len(all_items)
# Out:
# 1210485

# %%
def word_contains_chinese(k='lang',v='Chinese'):
    n_cns = 0
    for item in data:
        translations = item['translations']
        for trans in translations:
            if trans['lang'] == 'Chinese':
                n_cns += 1
                continue
    return n_cns
word_contains_chinese()
# Out:
# 52484

# %%
word_contains_chinese(k='code',v='cmn'), word_contains_chinese(k='code',v='yue'),
# Out:
# (52484, 52484)

# %%
def count_word_(handler):
    n_cns = 0
    for item in data:
        translations = item['translations']
        for trans in translations:
            if handler(trans):
                n_cns += 1
                continue
    return n_cns

# %%
# mandarin 41391, cantonese 5296

# %%
# count mandarin
def _is_mandarin(item):
    return 'Mandarin' in item.get('tags',[])
print(
    count_word_(_is_mandarin)
)

def _is_cantonese(item):
    return 'Cantonese' in item.get('tags',[])
print(
    count_word_(_is_cantonese)
)

def _is_simplified_cns(item):
    return item['code'] == 'cmn' and Converter('zh-hans').convert(item['word']) == item['word']
print(
    count_word_(_is_simplified_cns)
)

def _is_traditional_cns(item):
    return item['code'] == 'cmn' and Converter('zh-hans').convert(item['word']) != item['word']

print(
    count_word_(_is_traditional_cns)
)
# Out:
# 41391
# 5296
# 26552
# 15147

# %%
# simplified cns with pinyin 24928  code == cmn
# simplified cns with optional pinyin 26552    code == cmn
# simplified cns                     33669  lang==Chinese

# %%
def _cns_without_word(item):
    converted = Converter('zh-hans').convert(item['word'])
    res = item['lang'] == 'Chinese' and converted == item['word']
    if item['code'] == 'cmn' and converted != item['word']:
        print(item['word'])
#     if item['code'] == 'cmn' and converted == item['word'] and item.get('roman') is None:
#         print(item)
    return res
count_word_(_cns_without_word)

# %% [markdown]
# ## troponyms
#
# discard

# %%
data = query_words_by_key('troponyms')
len(data)
# Out:
# 10

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9c11fe31d283def15b'),
#   'word': 'sale',
#   'troponyms': [{'word': 'cut-rate sale',
#     'sense': 'selling of goods at reduced prices'},
#    {'word': 'sales event', 'sense': 'selling of goods at reduced prices'},
#    {'word': 'auction',
#     'sense': 'act of putting up for auction to the highest bidder'},
#    {'word': 'public sale',
#     'sense': 'act of putting up for auction to the highest bidder'}]},
#  {'_id': ObjectId('60544a9d11fe31d283def4a3'),
#   'word': 'cut',
#   'troponyms': [{'word': 'chop'},
#    {'word': 'hack'},
#    {'word': 'slice'},
#    {'word': 'trim'}]},
#  {'_id': ObjectId('60544a9e11fe31d283def7a7'),
#   'word': 'sleep',
#   'troponyms': [{'word': 'nap',
#     'sense': 'rest in a state of reduced consciousness'},
#    {'word': 'doze', 'sense': 'rest in a state of reduced consciousness'},
#    {'word': 'snooze', 'sense': 'rest in a state of reduced consciousness'}]}]

# %% [markdown]
# ## senses

# %%
data = query_words_by_key('senses')

# %%
data[:3]
# Out:
# [{'_id': ObjectId('60544a9311fe31d283dedc17'),
#   'word': 'GNU FDL',
#   'senses': [{'glosses': ['Initialism of GNU Free Documentation License.'],
#     'tags': ['abbreviation', 'alt-of', 'initialism'],
#     'alt_of': ['GNU Free Documentation License'],
#     'id': 'GNU_FDL-name'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc18'),
#   'word': 'Pope Julius',
#   'senses': [{'categories': ['Card games'],
#     'tags': ['obsolete'],
#     'glosses': ['A sixteenth-century gambling card game about which little is known.'],
#     'id': 'Pope_Julius-name'}]},
#  {'_id': ObjectId('60544a9311fe31d283dedc19'),
#   'word': 'encyclopaedia',
#   'senses': [{'categories': ['Australian English', 'British English'],
#     'tags': ['Australia', 'Britain', 'alt-of', 'alternative', 'chiefly'],
#     'glosses': ['Alternative spelling of encyclopedia'],
#     'alt_of': ['encyclopedia'],
#     'id': 'encyclopaedia-noun'}]}]

# %%
all_items = []

for o in data:
    all_items.extend(o['senses'])

# %%
len(all_items)
# Out:
# 1212639

# %%
a,b,c = get_uniq_keys(all_items)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1212639' class='' max='1212639' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1212639/1212639 00:03<00:00]
#     </div>

# %%
b,c
# Out:
# ({'glosses': [['Initialism of GNU Free Documentation License.'],
#    ['A sixteenth-century gambling card game about which little is known.'],
#    ['Alternative spelling of encyclopedia']],
#   'tags': [['abbreviation', 'alt-of', 'initialism'],
#    ['obsolete'],
#    ['Australia', 'Britain', 'alt-of', 'alternative', 'chiefly']],
#   'alt_of': [['GNU Free Documentation License'],
#    ['encyclopedia'],
#    ['gross domestic product']],
#   'id': ['GNU_FDL-name', 'Pope_Julius-name', 'encyclopaedia-noun'],
#   'categories': [['Card games'],
#    ['Australian English', 'British English'],
#    ['English pluralia tantum']],
#   'form_of': [['pie'], ['pie'], ['pi']],
#   'translations': [[{'lang': 'Chinese',
#      'code': 'yue',
#      'tags': ['Cantonese'],
#      'sense': 'news items',
#      'word': '時事'},
#     {'lang': 'Chinese',
#      'code': 'yue',
#      'tags': ['Cantonese'],
#      'sense': 'news items',
#      'word': '时事',
#      'roman': 'si^4 si^6'},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'news items',
#      'word': '時事'},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'news items',
#      'word': '时事',
#      'roman': 'shíshì'},
#     {'lang': 'Danish',
#      'code': 'da',
#      'sense': 'news items',
#      'word': 'aktuelle begivenheder'},
#     {'lang': 'Dutch',
#      'code': 'nl',
#      'sense': 'news items',
#      'word': 'actualiteiten'},
#     {'lang': 'Finnish',
#      'code': 'fi',
#      'sense': 'news items',
#      'word': 'ajankohtaiset uutiset'},
#     {'lang': 'French',
#      'code': 'fr',
#      'sense': 'news items',
#      'word': 'actualités'},
#     {'lang': 'Georgian',
#      'code': 'ka',
#      'sense': 'news items',
#      'word': 'მიმდინარე მოვლენები',
#      'roman': 'mimdinare movlenebi'},
#     {'lang': 'Georgian',
#      'code': 'ka',
#      'sense': 'news items',
#      'word': 'ახლანდელი მოვლენები',
#      'roman': 'axlandeli movlenebi'},
#     {'lang': 'Georgian',
#      'code': 'ka',
#      'sense': 'news items',
#      'word': 'დღევანდელი მოვლენები',
#      'roman': 'dɣevandeli movlenebi'},
#     {'lang': 'German',
#      'code': 'de',
#      'sense': 'news items',
#      'word': 'aktuelles Tagesgeschehen',
#      'tags': ['neuter']},
#     {'lang': 'Hebrew',
#      'code': 'he',
#      'sense': 'news items',
#      'word': 'אֲקְטוּאַלְיָה',
#      'tags': ['feminine'],
#      'roman': 'aqtuálya'},
#     {'lang': 'Japanese',
#      'code': 'ja',
#      'sense': 'news items',
#      'word': '時事',
#      'roman': 'jiji'},
#     {'lang': 'Navajo',
#      'code': 'nv',
#      'sense': 'news items',
#      'word': 'ádahooníłígíí'},
#     {'lang': 'Norwegian',
#      'code': 'no',
#      'sense': 'news items',
#      'word': 'aktuelle hendelser'},
#     {'lang': 'Portuguese',
#      'code': 'pt',
#      'sense': 'news items',
#      'word': 'eventos atuais',
#      'tags': ['masculine', 'plural']},
#     {'lang': 'Portuguese',
#      'code': 'pt',
#      'sense': 'news items',
#      'word': 'acontecimentos recentes',
#      'tags': ['masculine', 'plural']},
#     {'lang': 'Portuguese',
#      'code': 'pt',
#      'sense': 'news items',
#      'word': 'atualidades',
#      'tags': ['feminine', 'plural']},
#     {'lang': 'Russian',
#      'code': 'ru',
#      'sense': 'news items',
#      'word': 'но́вости',
#      'tags': ['feminine', 'plural'],
#      'roman': 'nóvosti'},
#     {'lang': 'Russian',
#      'code': 'ru',
#      'sense': 'news items',
#      'word': 'теку́щие собы́тия',
#      'tags': ['neuter', 'plural'],
#      'roman': 'tekúščije sobýtija'},
#     {'lang': 'Spanish',
#      'code': None,
#      'sense': 'news items',
#      'word': 'acontecimientos de actualidad',
#      'tags': ['masculine', 'plural']},
#     {'lang': 'Swedish',
#      'code': 'sv',
#      'sense': 'news items',
#      'word': 'aktualiteter'},
#     {'lang': 'Swedish',
#      'code': 'sv',
#      'sense': 'news items',
#      'word': 'aktuella händelser'},
#     {'lang': 'Telugu',
#      'code': 'te',
#      'sense': 'news items',
#      'word': 'ప్రస్తుత ఘటనలు',
#      'roman': 'prastuta ghaṭanalu'},
#     {'lang': 'Vietnamese',
#      'code': 'vi',
#      'sense': 'news items',
#      'word': 'thời sự'}],
#    [{'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': '把某東西看作是無價值的'},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': '把某东西看作是无价值的',
#      'roman': 'bǎ mǒu dōngxi kànzuò shì wú jiàzhí de'},
#     {'lang': 'Dutch',
#      'code': 'nl',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'geringschatting'},
#     {'lang': 'Finnish',
#      'code': 'fi',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'vähättely'},
#     {'lang': 'German',
#      'code': 'de',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'Geringschätzung',
#      'tags': ['feminine']},
#     {'lang': 'Malay',
#      'code': 'ms',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'memperkecil'},
#     {'lang': 'Norwegian',
#      'code': 'no',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'bagatellisering',
#      'tags': ['masculine']},
#     {'lang': 'Polish',
#      'code': 'pl',
#      'sense': 'act or habit of describing or regarding something as unimportant',
#      'word': 'brak uznania dla'}],
#    [{'lang': 'Arabic',
#      'code': 'ar',
#      'sense': 'societal idea',
#      'word': 'اَلتَّعَدُّدِيَّةُ اَلثَّقَافِيَّة',
#      'tags': ['feminine'],
#      'roman': 'at-taʿaddudiyyatu ṯ-ṯaqāfiyya'},
#     {'lang': 'Azerbaijani',
#      'code': 'az',
#      'sense': 'societal idea',
#      'word': 'çoxmədəniyyətlilik'},
#     {'lang': 'Azerbaijani',
#      'code': 'az',
#      'sense': 'societal idea',
#      'word': 'multikulturalizm'},
#     {'lang': 'Bulgarian',
#      'code': 'bg',
#      'sense': 'societal idea',
#      'word': 'мултикултурали́зъм',
#      'tags': ['masculine'],
#      'roman': 'multikulturalízǎm'},
#     {'lang': 'Catalan',
#      'code': 'ca',
#      'sense': 'societal idea',
#      'word': 'multiculturalisme',
#      'tags': ['masculine']},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'societal idea',
#      'word': '多元文化',
#      'roman': 'duōyuán wénhuà'},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'societal idea',
#      'word': '多元文化主義'},
#     {'lang': 'Chinese',
#      'code': 'cmn',
#      'tags': ['Mandarin'],
#      'sense': 'societal idea',
#      'word': '多元文化主义',
#      'roman': 'duōyuánwénhuàzhǔyì'},
#     {'lang': 'Czech',
#      'code': 'cs',
#      'sense': 'societal idea',
#      'word': 'multikulturalismus',
#      'tags': ['masculine']},
#     {'lang': 'Dutch',
#      'code': 'nl',
#      'sense': 'societal idea',
#      'word': 'multiculturalisme',
#      'tags': ['neuter']},
#     {'lang': 'Esperanto',
#      'code': 'eo',
#      'sense': 'societal idea',
#      'word': 'multkulturismo'},
#     {'lang': 'Finnish',
#      'code': 'fi',
#      'sense': 'societal idea',
#      'word': 'monikulttuurisuus'},
#     {'lang': 'French',
#      'code': 'fr',
#      'sense': 'societal idea',
#      'word': 'multiculturalisme',
#      'tags': ['masculine']},
#     {'lang': 'Galician',
#      'code': 'gl',
#      'sense': 'societal idea',
#      'word': 'multiculturalismo',
#      'tags': ['masculine']},
#     {'lang': 'German',
#      'code': 'de',
#      'sense': 'societal idea',
#      'word': 'Multikulturalismus',
#      'tags': ['masculine']},
#     {'lang': 'Greek',
#      'code': 'el',
#      'sense': 'societal idea',
#      'word': 'πολυπολιτισμικότητα',
#      'tags': ['feminine'],
#      'roman': 'polypolitismikótita'},
#     {'lang': 'Hebrew',
#      'code': 'he',
#      'sense': 'societal idea',
#      'word': 'רב-תרבותיות'},
#     {'lang': 'Hungarian',
#      'code': 'hu',
#      'sense': 'societal idea',
#      'word': 'multikulturalizmus'},
#     {'lang': 'Irish',
#      'code': 'ga',
#      'sense': 'societal idea',
#      'word': 'ilchultúrachas',
#      'tags': ['masculine']},
#     {'lang': 'Irish',
#      'code': 'ga',
#      'sense': 'societal idea',
#      'word': 'ilchultúrthacht',
#      'tags': ['feminine']},
#     {'lang': 'Japanese',
#      'code': 'ja',
#      'sense': 'societal idea',
#      'word': '多元文化論',
#      'roman': 'tagen-bunka-ron'},
#     {'lang': 'Japanese',
#      'code': 'ja',
#      'sense': 'societal idea',
#      'word': '多文化',
#      'roman': 'ta-bunka'},
#     {'lang': 'Japanese',
#      'code': 'ja',
#      'sense': 'societal idea',
#      'word': '多文化主義',
#      'roman': 'tabunkashugi'},
#     {'lang': 'Japanese',
#      'code': 'ja',
#      'sense': 'societal idea',
#      'word': 'マルチカルチュラリズム',
#      'roman': 'maruchikaruchurarizumu'},
#     {'lang': 'Korean',
#      'code': 'ko',
#      'sense': 'societal idea',
#      'word': '다문화주의',
#      'roman': 'damunhwajuui'},
#     {'lang': 'Polish',
#      'code': 'pl',
#      'sense': 'societal idea',
#      'word': 'wielokulturowość',
#      'tags': ['feminine']},
#     {'lang': 'Portuguese',
#      'code': 'pt',
#      'sense': 'societal idea',
#      'word': 'multiculturalismo',
#      'tags': ['masculine']},
#     {'lang': 'Romanian',
#      'code': 'ro',
#      'sense': 'societal idea',
#      'word': 'multiculturalism'},
#     {'lang': 'Russian',
#      'code': 'ru',
#      'sense': 'societal idea',
#      'word': 'многокульту́рность',
#      'tags': ['feminine'],
#      'roman': 'mnogokulʹtúrnostʹ'},
#     {'lang': 'Russian',
#      'code': 'ru',
#      'sense': 'societal idea',
#      'word': 'мультикультурали́зм',
#      'tags': ['masculine'],
#      'roman': 'mulʹtikulʹturalízm'},
#     {'lang': 'Spanish',
#      'code': 'es',
#      'sense': 'societal idea',
#      'word': 'multiculturalismo',
#      'tags': ['masculine']},
#     {'lang': 'Spanish',
#      'code': 'es',
#      'sense': 'societal idea',
#      'word': 'pluriculturalismo',
#      'tags': ['masculine']},
#     {'lang': 'Swedish',
#      'code': 'sv',
#      'sense': 'societal idea',
#      'word': 'multikulturalism',
#      'tags': ['common']},
#     {'lang': 'Turkish',
#      'code': 'tr',
#      'sense': 'societal idea',
#      'word': 'çokkültürlülük'},
#     {'lang': 'Vietnamese',
#      'code': 'vi',
#      'sense': 'societal idea',
#      'word': 'chủ nghĩa đa văn hóa'}]],
#   'related': [[{'word': 'current affairs'}],
#    [{'word': 'floccinaucinihilipilificate'},
#     {'word': 'floccinaucinihilipilificatory'},
#     {'word': 'floccinaucinihilipilificatious'},
#     {'word': 'floccinaucinihilipilificatiousness'},
#     {'word': 'antidisestablishmentarianism'},
#     {'word': 'antidisestablishmentarianismists'},
#     {'word': 'dacryocystorhinostomy'},
#     {'word': 'hippopotomonstrosesquipedaliophobia'},
#     {'word': 'supercalifragilisticexpialidocious'},
#     {'word': 'pneumonoultramicroscopicsilicovolcanoconiosis'}],
#    [{'word': 'multicultural'},
#     {'word': 'multiculturally'},
#     {'word': 'multicultured'},
#     {'word': 'cosmopolitan'},
#     {'word': 'culturism'}]],
#   'wikipedia': [['Eton College'], ['multiculturalism'], ['Caterpillar Inc.']],
#   'synonyms': [[{'word': 'tome'}, {'word': 'volume'}],
#    [{'word': 'booklet'}],
#    [{'word': 'libretto'}]],
#   'topics': [['gambling', 'games'], ['arts', 'theater'], ['law', 'legal']],
#   'derived': [[{'word': 'portmanteau film'}, {'word': 'portmanteau word'}],
#    [{'word': 'portmanteau film'}, {'word': 'portmanteau word'}],
#    [{'word': 'cats and dogs'}]],
#   'senseid': [['en:magpie'], ['en:news, tidings'], ['en:noun']],
#   'hyponyms': [[{'word': 'merchandise', 'sense': 'goods for sale'},
#     {'word': 'products', 'sense': 'goods for sale'}],
#    [{'word': 'credit default swap', 'sense': 'financial derivative'},
#     {'word': 'total return swap', 'sense': 'financial derivative'}],
#    [{'word': 'Black Saturday'},
#     {'word': 'Dynamite Saturday'},
#     {'word': 'Easter Saturday'},
#     {'word': 'Egg Saturday'},
#     {'word': 'Holy Saturday'},
#     {'word': 'Hospital Saturday'},
#     {'word': 'Little Saturday'},
#     {'word': 'Pink Saturday'}]],
#   'hypernyms': [[{'word': 'pneumoconiosis'}, {'word': 'silicosis'}],
#    [{'word': 'day'}],
#    [{'word': 'day'}]],
#   'coordinate_terms': [[{'word': 'black lung'},
#     {'word': "potter's rot"},
#     {'word': 'miner cough'}],
#    [{'word': 'affranchi'}],
#    [{'word': 'FTA'}, {'word': 'USMCA'}]],
#   'wikidata': [['Q523'], ['Q24384'], ['Q3464665']],
#   'holonyms': [[{'word': 'word'}],
#    [{'word': 'Melanesia'}],
#    [{'word': 'Subsahara'}]],
#   'meronyms': [[{'word': 'Abu Dhabi'},
#     {'word': 'Ajman'},
#     {'word': 'Dubai'},
#     {'word': 'Fujairah'},
#     {'word': 'Ras al-Khaimah'},
#     {'word': 'Sharjah'},
#     {'word': 'Umm al-Quwain'}],
#    [{'word': 'Wallonia'},
#     {'word': 'Flanders'},
#     {'word': 'Brussels-Capital Region'},
#     {'word': 'Brussels',
#      'topics': ['city',
#       'cities',
#       'region',
#       'geography',
#       'location',
#       'property',
#       'natural-sciences',
#       'sciences'],
#      'translation': 'capital city'}],
#    [{'word': 'terreplein (level walkway)', 'sense': 'rampart'},
#     {'word': 'parapet', 'sense': 'rampart'},
#     {'word': 'crenellation (minor secondary wall protecting the terreplein)',
#      'sense': 'rampart'},
#     {'word': 'banquette (area elevated above the terreplein for use by defenders)',
#      'sense': 'rampart'}]],
#   'troponyms': [[{'word': 'pivot',
#      'sense': 'to rotate about an off-centre fixed point'},
#     {'word': 'swivel', 'sense': 'to rotate about an off-centre fixed point'}],
#    [{'word': 'rewire', 'sense': 'to fasten with wire'}],
#    [{'word': 'ogle', 'sense': 'to stare intently'}]],
#   'compound_of': [['genius and fool'],
#    ['sodium'],
#    ['what is already compounded']]},
#  {'glosses': 1211953,
#   'tags': 840874,
#   'alt_of': 86348,
#   'id': 1212639,
#   'categories': 362603,
#   'form_of': 339942,
#   'translations': 106929,
#   'related': 61017,
#   'wikipedia': 74048,
#   'synonyms': 62449,
#   'topics': 167040,
#   'derived': 22873,
#   'senseid': 1706,
#   'hyponyms': 2409,
#   'hypernyms': 3042,
#   'coordinate_terms': 3844,
#   'wikidata': 835,
#   'holonyms': 147,
#   'meronyms': 154,
#   'troponyms': 3,
#   'compound_of': 3})

# %%
sense_keys = { 'derived',
  'translations',
  'wikidata',
  'hypernyms',
  'wikipedia',
  'id',
  'related',
  'form_of',
  'holonyms',
  'categories',
  'synonyms',
  'alt_of',
  'hyponyms',
  'coordinate_terms',
  'meronyms',
  'tags',
  'troponyms',
  'glosses',
  'senseid',
  'compound_of',
  'topics'}
sense_keys.difference(set(all_keys))

# %%
differeniated = {'alt_of',
 'compound_of',
 'form_of',
 'glosses',
 'id',
 'senseid',
 'tags',
 'topics',
 'wikidata'}

# %%
intersected = {'categories',
 'coordinate_terms',
 'derived',
 'holonyms',
 'hypernyms',
 'hyponyms',
 'meronyms',
 'related',
 'synonyms',
 'translations',
 'troponyms',
 'wikipedia'}

# %%
senses_key_examples

# %% [markdown]
# - 'glosses': `string[]`
# - 'tags': `string[]`
# - 'alt_of': `string[]`
# - 'id': `string`
# - 'categories': `string[]`
# - 'form_of': `string[]`
# - 'translations': `{lang:string, code: string, tags:string[], sense:string, word: string, roman: string}[]`
# - 'related': `{word: string, tags?:string[]}[]`
# - 'wikipedia': `string[]`
# - 'synonyms': `{word: string}[]`
# - 'topics': `string[]`
# - 'derived': `{word: string}[]`
# - 'senseid': `string[]`
# - 'hyponyms': `{word: string, sense: string}[]`
# - 'hypernyms': `{word: string}[]`
# - 'coordinate_terms': `{word: string, sense?:string}[]`
# - 'wikidata': `string[]`
# - 'holonyms': `{word: string}[]`
# - 'meronyms': `{word: string, topics: string[], sense: string, tags: string[]}[]`
# - 'troponyms': `{word: string, sense: string}[]`
# - 'compound_of': `string[]`

# %% [markdown]
# ## check repeated words

# %%
data = query_words_by_key('word')
len(data)

# %%
all_words = [i['word'] for i in data]

# %%
all_words[:10]

# %%
len(set(all_words))

# %%
1021124-952502

# %%
data[0]

# %%
def get_repeated_words(data, words):
    repeated = []
    idxes_to_skip = set()
    for idx, item in enumerate(data):
        temp_repeated = []
        if idx in idxes_to_skip:
            continue
        for idx2, word in enumerate(words[idx+1:]):
            if item['word'] == word:
                idxes_to_skip.add(idx2)
                temp_repeated.append(item['_id'])
        if len(temp_repeated) > 0 :
            repeated.append(
                (item, temp_repeated)
            )
    return repeated

# %%
from multiprocessing import Pool, cpu_count
import math

# %%
def chunk_data(data, bs=10):
    sz =math.floor(len(data)/bs)
    res = []
    for i in range(bs):
        block = data[sz*i : sz*(i+1)] if i != bs-1 else data[sz*i :] 
        res.append(block)
    
    return res

# %%
res = []
num = 40
with Pool(num) as p:
    for i in range(num):
        chunked_words = chunk_data(all_words, num)
        chunked_data = chunk_data(data, num)
        r = p.apply_async(get_repeated_words, args=(chunked_data[i], chunked_words[i],))
        res.append(r.get())

# %%
res = sum(res,[])
len(res)

# %% [markdown]
# ## handler

# %%
class NoneValueException(Exception):
    pass

def _check_none_value(item,key_name):
    data = item.get(key_name)
    if data is None:
        raise NoneValueException
    
    return data

def _uniq_list(expre):
    return list(set(expre))

def _extract_value_from_arr(arr, key_name, uniq=True):
    res = [o[key_name] for o in arr]
    if uniq:
        return _uniq_list(res)
    else:
        return res
    

    
def _map_handler(val):
    if isinstance(val, str):
        return val
    
    if isinstance(val, list):
        return _arr_handler(val)
    
    if isinstance(val, object):
        return _obj_handler(val)
    
def _arr_handler(item):
    if len(item) == 0: return item 
    
    if isinstance(item[0], str):
        return _uniq_list(item)
    if isinstance(item[0], list):
        return [_arr_handler(o) for o in item]
        
    if isinstance(item[0], object):
        return [_obj_handler(o) for o in item]
    
    return item
    
def _obj_handler(obj):
    return {
        k: _map_handler(v)
        for k,v in obj.items()
    }
    
    
def _uniq_arr_with_obj(arr,key_names):
    res = []
    for item in arr:
        item2 = {}
        for k,v in item.items():
            if k in key_names:
                item2[k] = _arr_handler(v)
            else:
                item2[k] = v
        res.append(item2)
    return res

# basic attribution
def lang_handler(item):
    return {
        'lang': item['lang']
    }

def lang_code_handler(item):
    return {
        'lang_code': item['lang_code']
    }

def pos_handler(item):
    return {
        'all_pos': [item['pos']] if isinstance(item['pos'], str) else item['pos']
    }

def word_handler(item):
    return {
        'word':item['word']
    }


def senses_handler(item):
    pass

# end basic attribution
    
def abbreviations_handler(item):
    '''
     alternative
    '''
    try:
        abbr = _check_none_value(item, 'abbreviations')
        return {
        'abbrs': _uniq_list(o['word'] for o in abbr),
    }
    except NoneValueException:
        return {}


def antonyms_handler(item):
    '''
    relation
    '''
    data = _check_none_value(item, 'antonyms')
    return {
        'antonyms': _uniq_list(o['word'] for o in data),
        'antonyms_data': _map_handler(data)
    }  
    
def categories_handler(item):
    '''
    description
    '''
    data = _check_none_value(item, 'categories')
    return {
        'categories': _uniq_list(data)
    }

def derived_handler(item):
    '''
    relation
    '''
    data = _check_none_value(item, 'derived')
    return {
        'derived': _uniq_list(o['word'] for o in data),
        'derived_data': _map_handler(data)
    }

def forms_handler(item):
    '''
    alternative
    '''
    data = _check_none_value(item,'forms')
    data = [
        o
        for o in data
        if 'error-unknown-tag' not in o.get('tags',[])
    ]
    return {
        'forms': _uniq_list(o['form'] for o in data),
        'form_data': _map_handler(data)
    }

def hypernyms_handler(item):
    '''
    relation
    '''
    data = _check_none_value(item, 'hypernyms')
    return {
        'hypernyms': _uniq_list(o['word'] for o in data),
        'hypernyms_data': _map_handler(data)
    }

def hyphenation_handler(item):
    '''
    
    '''
    data =_check_none_value(item, 'hyphenation')
    return {
        'hyphenation': _uniq_list(data)
    }
    
def hyponyms_handler(item):
    '''
    relation
    '''
    data = _check_none_value(item, 'hyponyms')
    return {
        'hyponyms': _uniq_list(o['word'] for o in data),
        'hyponyms_data': _map_handler(data)
    }


def related_handler(item):
    '''
    relation
    '''
    data =_check_none_value(item,'related')
    
    return {
        'related': _uniq_list(o['word'] for o in data),
        'related_data': _map_handler(data)
    }

    
def _sound_item_processor(sound_item):
    sounds_tags_to_keep ={'US','UK','AU','Received Pronunciation','General American','Canada'}
    sounds_keys_to_remove = [ 'text', 'homophone', 'enpr', 'other', 'audio']
    res =  {
        k:v   
        for k,v in sound_item.items()
        if k not in sounds_keys_to_remove
    }
    
    if bool(res) is False:
        return None
    if res.get('tags') is None:
        return res
    else:
        res['tags'] = list(
            set(res['tags']).intersection(sounds_tags_to_keep)
        )
        if len(res['tags']) == 0:
            res.pop('tags')
        return res
    
def sounds_handler(item):
    '''
        all keys: 'other', 'audio', 'homophone', 'ipa', 'tags', 'rhymes', 'enpr', 'text'
    '''
    data = _check_none_value(item,'sounds')
    data = [o for o in data if o.get('ipa') is not None]
    if len(data) == 0: return {}
    sounds = [
        _sound_item_processor(sound_item)
        for sound_item in data
        if _sound_item_processor(sound_item) is not None
    ]
    if len(sounds) == 0:
        return {}
    return {
        'sounds': _map_handler(sounds)
    }
    
def synonyms_handler(item):
    '''
        related
    '''
    data = _check_none_value(item, 'synonyms')
    return {
        'synonyms': _extract_value_from_arr(data,'word'),
        'synonyms_data': _map_handler(data)
    }


def translations_hanlder(item):
    data = _check_none_value(item,'translations')
    cns = [o 
           for o in data 
           if o['code'] == 'cmn'
          ]
    if len(cns) ==0:
        return {}
    
    cns = sorted(cns, key=lambda x: len(x.keys()), reverse=True)
    res = cns[0]
    res['word'] = Converter('zh-hans').convert(res['word'])
    res = {
        k:v
        for k,v in res.items()
        if k in ['word','roman','lang','code','tags']
    }
    return { 
        'zh_cn': res
    }

# discard 

def compounds_handler(item):
    return {}

def coordinate_terms_handler(item):
    return {}


def troponyms_handler(item):
    '''
    discard
    '''
    return {}

def wikipedia_handler(item):
    '''
    discard
    '''
    return {}

def inflection_handler(item):
    return {}

def inflection_of_handler(item):
    return {}


def meronyms_handler(item):
    return {}


def proverbs_handler(item):
    return {}


def heads_handler(item):
    return {}

def holonyms_handler(item):
    '''
    discard
    '''
    return {}

    data = _check_none_value(item,'holonyms')
    return {
        'holonyms': _uniq_list(o['word'] for o in data),
        'holonyms_data': _map_handler(data)
    }

# end discard



word_handler = {
 'abbreviations': abbreviations_handler,
 'antonyms': antonyms_handler,
 'categories': categories_handler,
 'compounds': compounds_handler,
 'coordinate_terms': coordinate_terms_handler,
 'derived': derived_handler,
 'forms':forms_handler,
 'heads': heads_handler,
 'holonyms':holonyms_handler,
 'hypernyms': hypernyms_handler,
 'hyphenation':hyphenation_handler,
 'hyponyms': hyponyms_handler,
 'inflection': inflection_handler,
 'inflection_of': inflection_of_handler,
 'lang': lang_handler,
 'lang_code': lang_code_handler,
 'meronyms': meronyms_handler,
 'pos': pos_handler,
 'proverbs': proverbs_handler,
 'related': related_handler,
 'senses': senses_handler,
 'sounds': sounds_handler,
 'synonyms': synonyms_handler,
 'translations': translations_hanlder,
 'troponyms': troponyms_handler,
 'wikipedia': wikipedia_handler,
 'word': word_handler
}

# %% [markdown]
# ## sense handler

# %%
def alt_of_handler(item):
    data = _check_none_value(item,'alt_of')
    return {
        'alt_of': _uniq_list(data)
    }

def compound_of_handler(item):
    return {}


def form_of_handler(item):
    data = _check_none_value(item, 'form_of')
    return {
        'form_of': _uniq_list(data)
    }
    
def glosses_handler(item):
    data = _check_none_value(item, 'glosses')
    return {
        'glosses': _uniq_list(data)
    }
 
def id_handler(item):    
    data = _check_none_value(item, 'id')
    return {
        'sense_id': data
    }


def senseid_handler(item):
    return {}

def tags_handler(item):
    data = _check_none_value(item, 'tags')
    return {
        'tags': _uniq_list(data)
    } 

def topics_handler(item):
    data = _check_none_value(item, 'topics')
    return {
        'topics': _uniq_list(data)
    } 
def wikidata_handler(item):
    return {}

sense_handler = {
     'categories': categories_handler,
     'coordinate_terms':coordinate_terms_handler ,
     'derived': derived_handler,
     'holonyms': holonyms_handler,
     'hypernyms':hypernyms_handler ,
     'hyponyms': hyponyms_handler,
     'meronyms': meronyms_handler,
     'related': related_handler,
     'synonyms': synonyms_handler,
     'translations': translations_hanlder,
     'troponyms': troponyms_handler,
     'wikipedia': wikipedia_handler,
    
     'alt_of': alt_of_handler,
     'compound_of': compound_of_handler,
     'form_of': form_of_handler,
     'glosses': glosses_handler,
     'id': id_handler,
     'senseid': senseid_handler,
     'tags':tags_handler,
     'topics': topics_handler,
     'wikidata': wikidata_handler
}

# %%
def process_single_sense(sense, addons={}):
    res = {**addons}
    for k,v in sense.items():
        try:
            obj = sense_handler[k](sense)
            res.update(obj)
        except NoneValueException:
            pass
    return res

def process_single_word(word):
    senses = word['senses']
    _id = ObjectId()
    word_res = {
        '_id':_id
    }
    # word
    for k,v in word.items():
        try:
            if k in ['senses','_id']: continue
            word_res.update(
                word_handler[k](word)
            )
        except NoneValueException:
            pass
    
    # sense
    sense_addons = {
        'pos': word['pos'],
        'priority': 1,
        'word_id': _id
    }
    senses_res = [
        process_single_sense(s, addons=sense_addons)
        for s in senses
    ]
    return word_res, senses_res

# %% [markdown]
# ## test

# %%
def sample_words(n=5):
    return list(dict_col.aggregate([
        {
            '$match':{
                
            }
        },
        {
            '$sample':{'size':n}
        }
    ]))

# %%
sw = sample_words(50)

# %%
for i,o in enumerate(sw):
    try:
        process_single_word(o)
    except Exception as e:
        print(i)
        raise e

# %% [markdown]
# ## get duplicated words

# %%
all_words = query_words_by_key('pos')
len(all_words)
# Out:
# 1021124

# %%
dic = {}
for item in progress_bar(all_words):
    word = item['word']
    if dic.get(word) is None:
        dic[word] = [(item['_id'], item['pos'])]
    else:
        dic[word].append(
            (item['_id'], item['pos'])
        )
        
dic = {
    k:v
    for k,v in dic.items()
    if len(v) > 1
}
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1021124' class='' max='1021124' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1021124/1021124 00:03<00:00]
#     </div>

# %%
len(dic.keys())
# Out:
# 57303

# %%
temp_arr = sorted([
    (k, v)
    for k,v in dic.items()
],
key = lambda x: len(x[1]),
reverse = True
)
dic = {
    k:v
    for k,v in temp_arr
}

# %%
for k,v in list(dic.items())[:10]:
    print(k,len(v))
# Out:
# rout 13
# a 13
# stale 12
# -er 12
# dink 12
# cat 11
# pink 11
# X 11
# rake 11
# rack 11

# %%
res = list(dict_col.find({
    'word':'rout'
}))

# %%
[len(o['senses']) for o in res]
# Out:
# [7, 1, 2, 2, 3, 1, 3, 2, 6, 2, 1, 1, 1]

# %%
res_nouns = sorted([o for o in res if o['pos'] =='noun'], key= lambda x: len(x['senses']), reverse=True)
res_verbs = sorted([o for o in res if o['pos'] =='verb'], key= lambda x: len(x['senses']), reverse=True)
len(res_nouns), len(res_verbs)
# Out:
# (6, 7)

# %%
[len(o['senses']) for o in res_nouns], [len(o['senses']) for o in res_verbs]
# Out:
# ([7, 2, 2, 1, 1, 1], [6, 3, 3, 2, 2, 1, 1])

# %%
def _count_len_of_v(item):
    res = {}
    for k,v in item.items():
        if isinstance(v, list):
            res[k] = len(v)
        else:
            res[k] = v
    return res
res_nouns_cnt = [_count_len_of_v(o) for o in res_nouns]
res_verbs_cnt = [_count_len_of_v(o) for o in res_verbs]

# %%
res_nouns_cnt
# Out:
# [{'_id': ObjectId('60544ac611fe31d283df5cf2'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'categories': 1,
#   'translations': 13,
#   'derived': 2,
#   'senses': 7},
#  {'_id': ObjectId('60544ac611fe31d283df5cf4'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'categories': 2,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'translations': 12,
#   'senses': 2},
#  {'_id': ObjectId('60544ac611fe31d283df5cf9'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'categories': 4,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'senses': 2},
#  {'_id': ObjectId('60544ac611fe31d283df5cf7'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'categories': 1,
#   'senses': 1},
#  {'_id': ObjectId('60544ac611fe31d283df5cfd'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'categories': 1,
#   'senses': 1},
#  {'_id': ObjectId('60544ac611fe31d283df5cfe'),
#   'pos': 'noun',
#   'heads': 1,
#   'forms': 1,
#   'word': 'rout',
#   'lang': 'English',
#   'lang_code': 'en',
#   'sounds': 43,
#   'categories': 1,
#   'senses': 1}]

# %%
res_nouns[1]['categories']
# Out:
# ['Colors', 'Military']

# %% [markdown]
# ## handle word with multiple words
#
# 1. order by length of `senses`
# 2. get `pos` from parent
# 3. merge `forms` with `form_of`
# 3. merge `derived`

# %%
words_keys = [
 'abbreviations',
 'antonyms',
 'categories',
#  'compounds',
#  'coordinate_terms',
 'derived',
 'forms',
#  'heads',
#  'holonyms',
 'hypernyms',
 'hyphenation',
 'hyponyms',
#  'inflection',
#  'inflection_of',
 'lang',
 'lang_code',
#  'meronyms',
 'pos',
#  'proverbs',
 'related',
 'senses',
 'sounds',
 'synonyms',
 'translations',
#  'troponyms',
#  'wikipedia',
 'word']

# %%
def _merge_arr(*arrs):
    res = []
    for arr in arrs:
        res.extend(arr)
    res = set(json.dumps(o) for o in res)
    return [
        json.loads(o)
        for o in res
    ]

keys_to_merge = {
    'abbreviations',
    'antonyms',
    'categories',
    'derived',
    'forms',
    'hypernyms',
    'hyphenation',
    'hyponyms',
    'related',
    'sounds',
    'synonyms',
    'translations'
}
def merge_words(words):
    '''
        words should be ordered by length of senses
    '''
    main_word = {**words[0]}
    pos = list(set(o['pos'] for o in words))
    main_word['pos'] = pos
    
    for key in keys_to_merge:
        values = [
            o.get(key)
            for o in words[1:]
            if o.get(key) is not None
        ]
        res = _merge_arr(
            main_word.get(key,[]),
            *values
        )
        if len(res) >0:
            main_word[key] = res
    return main_word
        
            
            

keys_to_inherit = [
     'categories',
     'coordinate_terms',
     'derived',
     'hypernyms',
     'hyponyms',
     'related',
     'synonyms',
     'translations',
]

def _inherit(word,sense):
    res = {**sense}
    for k in keys_to_inherit:
        values = _merge_arr(res.get(k,[]), word.get(k,[]))
        if len(values) > 0:
            res[k] = values
            
    return res
    

def process_senses_with_multi_words(word, addons={}):
    '''
    
    '''
    senses = word['senses']
    word_forms = [
        o['form'] 
        for o in word.get('forms',[])
        if 'error-unknown-tag' not in o.get('tags',[])
    ]
    senses = [
        {
            **o,
            'form_of': o.get('form_if',[]) + word_forms
        }
        for o in senses
    ]
    attr_to_inherit = {
        k:v
        for k,v in word.items()
        if k in keys_to_inherit
    }
    
    senses = [
        _inherit(word, s)
        for s in senses
    ]
    
    return [
        process_single_sense(s,addons = addons)
        for s in senses
    ]
        
    
def _find_word_with_pos(words,pos):
    return [
        o
        for o in words
        if o['pos'] == pos
    ]

def _group_words_by_pos(sorted_words):
    poses = set(
        o['pos']
        for o in sorted_words
    )
    return [
        _find_word_with_pos(sorted_words,pos)
        for pos in poses
    ]
    
def process_multi_words(words):
    sorted_words = sorted(
        words, 
        key= lambda x: len(x['senses']), 
        reverse=True)
    main_word = merge_words(sorted_words)
    _id = ObjectId()
    word_res = {
        '_id':_id
    }
    # word
    for k,v in main_word.items():
        try:
            if k in ['senses','_id']: continue
            word_res.update(
                word_handler[k](main_word)
            )
        except NoneValueException:
            pass
    # word
    groups = _group_words_by_pos(sorted_words)
    
    # sense
    senses = []
    for grouped_words in groups:
        for idx,word in enumerate(grouped_words):
            sense_addons = {
                'pos': word['pos'],
                'priority': idx+1,
                'word_id':_id
            }
            if word.get('forms') is not None:
                sense_addons['form_data'] = forms_handler(word)['form_data']
                
            senses += process_senses_with_multi_words(word, addons=sense_addons)
    # sense
    return word_res, senses

# %% [markdown]
# ## test

# %%
duplicated_words = list(dict_col.find({
    'word':'pitch'
}))

# %%
word,senses = process_multi_words(duplicated_words)
senses
# Out:
# [{'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive'],
#   'glosses': ['To throw.'],
#   'sense_id': 'pitch-verb-en:to_throw',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Baseball'],
#   'tags': ['transitive', 'intransitive'],
#   'topics': ['baseball', 'sports'],
#   'glosses': ['To throw (the ball) toward a batter at home plate.'],
#   'sense_id': 'pitch-verb-en:baseball:_to_throw_the_ball_toward_home_plate',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Baseball'],
#   'tags': ['intransitive'],
#   'topics': ['baseball', 'sports'],
#   'glosses': ['To play baseball in the position of pitcher.'],
#   'sense_id': 'pitch-verb-0wHNNEhB',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive'],
#   'glosses': ['To throw away; discard.'],
#   'sense_id': 'pitch-verb-HurpwHda',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive'],
#   'glosses': ['To promote, advertise, or attempt to sell.'],
#   'sense_id': 'pitch-verb-7gke7LnU',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive'],
#   'glosses': ['To deliver in a certain tone or style, or with a certain audience in mind.'],
#   'sense_id': 'pitch-verb-w6C0Pp-e',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive'],
#   'glosses': ['To assemble or erect (a tent).'],
#   'sense_id': 'pitch-verb-wtRi2Yjk',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['intransitive'],
#   'glosses': ['To fix or place a tent or temporary habitation; to encamp.'],
#   'sense_id': 'pitch-verb-35i1lZs-',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Aviation', 'Nautical'],
#   'tags': ['transitive', 'intransitive'],
#   'topics': ['aviation', 'nautical', 'aeronautics'],
#   'glosses': ['To move so that the front of an aircraft or boat goes alternatively up and down. The typhoon pitched the deck of the ship.'],
#   'sense_id': 'pitch-verb-voROGpNV',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Golf'],
#   'tags': ['transitive'],
#   'topics': ['golf', 'sports', 'lifestyle'],
#   'glosses': ['To play a short, high, lofty shot that lands with backspin.'],
#   'sense_id': 'pitch-verb-LCAyjtng',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Cricket'],
#   'tags': ['intransitive'],
#   'topics': ['cricket', 'sports'],
#   'glosses': ['To bounce on the playing surface.'],
#   'sense_id': 'pitch-verb-699gwVwr',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Bristolian English'],
#   'tags': ['Bristol', 'of snow', 'intransitive'],
#   'glosses': ['To settle and build up, without melting.'],
#   'sense_id': 'pitch-verb-1JvK0hH.',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['archaic', 'intransitive'],
#   'glosses': ['To alight; to settle; to come to rest from flight.'],
#   'sense_id': 'pitch-verb--fWbLtPs',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['with on or upon'],
#   'glosses': ["To fix one's choice."],
#   'sense_id': 'pitch-verb-7MAHMABe',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['intransitive'],
#   'glosses': ['To plunge or fall; especially, to fall forward; to decline or slope.'],
#   'sense_id': 'pitch-verb-4sqYysZR',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive', 'of an embankment', 'roadway'],
#   'glosses': ['To set, face, or pave with rubble or undressed stones.'],
#   'sense_id': 'pitch-verb-WZHYNFhT',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'tags': ['transitive', 'of a price', 'value'],
#   'glosses': ['To set or fix.'],
#   'sense_id': 'pitch-verb-MqVTsM4D',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 1,
#   'categories': ['Card games'],
#   'tags': ['transitive', 'of a card', 'slang'],
#   'topics': ['games', 'card'],
#   'glosses': ['To discard for some gain.'],
#   'sense_id': 'pitch-verb-bstiCcXM',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'derived': ['pitchfork',
#    'pitcher',
#    'pitch upon',
#    'pitch up',
#    'pitch-a-fit',
#    'pitch and putt',
#    'pitch a tent',
#    'pitch in'],
#   'derived_data': [{'word': 'pitch and putt'},
#    {'word': 'pitch upon'},
#    {'word': 'pitch-a-fit'},
#    {'word': 'pitch up'},
#    {'word': 'pitcher'},
#    {'word': 'pitchfork'},
#    {'word': 'pitch in'},
#    {'word': 'pitch a tent'}]},
#  {'pos': 'verb',
#   'priority': 2,
#   'glosses': ['To cover or smear with pitch.'],
#   'sense_id': 'pitch-verb-lvLpRECB',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'related': ['piceous'],
#   'related_data': [{'word': 'piceous'}]},
#  {'pos': 'verb',
#   'priority': 2,
#   'glosses': ['To darken; to blacken; to obscure.'],
#   'sense_id': 'pitch-verb-ESzRO2Nv',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'related': ['piceous'],
#   'related_data': [{'word': 'piceous'}]},
#  {'pos': 'verb',
#   'priority': 3,
#   'tags': ['intransitive'],
#   'glosses': ['To produce a note of a given pitch.'],
#   'sense_id': 'pitch-verb-nDi.Y2eg',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'categories': ['Magic: The Gathering', 'Gums and resins']},
#  {'pos': 'verb',
#   'priority': 3,
#   'tags': ['transitive'],
#   'glosses': ['To fix or set the tone of.'],
#   'sense_id': 'pitch-verb-Rok2MHCl',
#   'form_of': ['pitching', 'pitched', 'pitches'],
#   'categories': ['Magic: The Gathering', 'Gums and resins']},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['A throw; a toss; a cast, as of something from the hand.'],
#   'sense_id': 'pitch-noun-fn7gUdcE',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['Baseball'],
#   'topics': ['baseball', 'sports'],
#   'glosses': ['The act of pitching a baseball.'],
#   'sense_id': 'pitch-noun-en:the_act_of_pitching_a_baseball',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['New Zealand English',
#    'Sports',
#    'British English',
#    'Australian English'],
#   'topics': ['sports'],
#   'tags': ['Britain', 'New Zealand', 'Australia'],
#   'glosses': ['The field on which cricket, soccer, rugby or field hockey is played. (In cricket, the pitch is in the centre of the field; see cricket pitch.) Not used in America, where "field" is the preferred word.'],
#   'sense_id': 'pitch-noun-TpBhhbbN',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['An effort to sell or promote something.'],
#   'sense_id': 'pitch-noun-vJAQ29v3',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['The distance between evenly spaced objects, e.g. the teeth of a saw or gear, the turns of a screw thread, the centres of holes, or letters in a monospace font.'],
#   'sense_id': 'pitch-noun-xIB0bSEx',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['The angle at which an object sits.'],
#   'sense_id': 'pitch-noun-zwz-5f0s',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'tags': ['broadly'],
#   'glosses': ['A level or degree, or, a peak or highest degree.'],
#   'sense_id': 'pitch-noun-nyf9kKBA',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['The degree to which a vehicle, especially a ship or aircraft, rotates on such an axis, tilting its bow or nose up or down. Compare with roll, yaw, and heave.',
#    'The rotation angle about the transverse axis.'],
#   'categories': ['Aviation', 'Nautical'],
#   'topics': ['aviation', 'nautical', 'aeronautics'],
#   'sense_id': 'pitch-noun-xMJkNuNd',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['A measure of the angle of attack of a propeller.',
#    'The rotation angle about the transverse axis.'],
#   'categories': ['Aviation'],
#   'topics': ['aviation', 'aeronautics'],
#   'sense_id': 'pitch-noun-hfSzeQ2-',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['The place where a busker performs.'],
#   'sense_id': 'pitch-noun-bcOXARmp',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['An area in a market (or similar) allocated to a particular trader.'],
#   'sense_id': 'pitch-noun-4yZnZPNv',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['An area on a campsite intended for occupation by a single tent, caravan or similar.'],
#   'sense_id': 'pitch-noun-L4pfiOyE',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['A point or peak; the extreme point of elevation or depression.'],
#   'sense_id': 'pitch-noun-FbHa4b4D',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['Prominence; importance.'],
#   'sense_id': 'pitch-noun-HO6w3bwB',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['Climbing'],
#   'topics': ['climbing', 'sports'],
#   'glosses': ['A section of a climb or rock face; specifically, the climbing distance between belays or stances.'],
#   'sense_id': 'pitch-noun-7bNzbOYq',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['Caving'],
#   'topics': ['caving', 'sports'],
#   'glosses': ['A vertical cave passage, only negotiable by using rope or ladders.'],
#   'sense_id': 'pitch-noun-i1PaDDKR',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['British English', 'Regional English'],
#   'tags': ['regional', 'Britain'],
#   'glosses': ["A person's or animal's height."],
#   'sense_id': 'pitch-noun-A-HAzWwd',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['Cricket'],
#   'topics': ['cricket', 'sports'],
#   'glosses': ['That point of the ground on which the ball pitches or lights when bowled.'],
#   'sense_id': 'pitch-noun-lmhitZAq',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['A descent; a fall; a thrusting down.'],
#   'sense_id': 'pitch-noun-h60tQ2GQ',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'glosses': ['The point where a declivity begins; hence, the declivity itself; a descending slope; the degree or rate of descent or slope; slant.'],
#   'sense_id': 'pitch-noun-XCpTqu0s',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 1,
#   'categories': ['Mining'],
#   'topics': ['mining', 'manufacturing', 'economics'],
#   'glosses': ['The limit of ground set to a miner who receives a share of the ore taken out.'],
#   'sense_id': 'pitch-noun-15h0tJxV',
#   'form_of': ['pitches'],
#   'derived': ['pitchmeter', 'sales pitch', 'pitchometer'],
#   'derived_data': [{'word': 'sales pitch'},
#    {'word': 'pitchmeter'},
#    {'word': 'pitchometer'}],
#   'hyponyms': ['football pitch'],
#   'hyponyms_data': [{'word': 'football pitch'}]},
#  {'pos': 'noun',
#   'priority': 2,
#   'tags': ['countable', 'uncountable'],
#   'glosses': ['A sticky, gummy substance secreted by trees; sap.'],
#   'sense_id': 'pitch-noun-StuiVBe2',
#   'form_of': ['pitches'],
#   'derived': ['pitch-black', 'pitch-dark', 'pitchblende', 'pitch darkness'],
#   'derived_data': [{'word': 'pitch darkness'},
#    {'word': 'pitchblende'},
#    {'word': 'pitch-black'},
#    {'word': 'pitch-dark'}],
#   'related': ['piceous'],
#   'related_data': [{'word': 'piceous'}]},
#  {'pos': 'noun',
#   'priority': 2,
#   'tags': ['countable', 'uncountable'],
#   'glosses': ['A dark, extremely viscous material remaining in still after distilling crude oil and tar.'],
#   'sense_id': 'pitch-noun-z1Xg-YXT',
#   'form_of': ['pitches'],
#   'derived': ['pitch-black', 'pitch-dark', 'pitchblende', 'pitch darkness'],
#   'derived_data': [{'word': 'pitch darkness'},
#    {'word': 'pitchblende'},
#    {'word': 'pitch-black'},
#    {'word': 'pitch-dark'}],
#   'related': ['piceous'],
#   'related_data': [{'word': 'piceous'}]},
#  {'pos': 'noun',
#   'priority': 2,
#   'categories': ['Geology'],
#   'topics': ['natural-sciences', 'geography', 'sciences', 'geology'],
#   'tags': ['countable', 'uncountable'],
#   'glosses': ['Pitchstone.'],
#   'sense_id': 'pitch-noun-fGzFs-6l',
#   'form_of': ['pitches'],
#   'derived': ['pitch-black', 'pitch-dark', 'pitchblende', 'pitch darkness'],
#   'derived_data': [{'word': 'pitch darkness'},
#    {'word': 'pitchblende'},
#    {'word': 'pitch-black'},
#    {'word': 'pitch-dark'}],
#   'related': ['piceous'],
#   'related_data': [{'word': 'piceous'}]},
#  {'pos': 'noun',
#   'priority': 3,
#   'categories': ['Magic: The Gathering',
#    'Gums and resins',
#    'Music',
#    'Phonetics'],
#   'topics': ['phonology',
#    'music',
#    'arts',
#    'publishing',
#    'linguistics',
#    'phonetics',
#    'media'],
#   'glosses': ['The perceived frequency of a sound or note.'],
#   'zh_cn': {'lang': 'Chinese',
#    'code': 'cmn',
#    'tags': ['Mandarin'],
#    'word': '音高',
#    'roman': 'yīn\u200bgāo'},
#   'sense_id': 'pitch-noun-SsQQUKoU',
#   'form_of': ['pitches'],
#   'derived': ['relative pitch',
#    'pitch class',
#    'pitch pipe',
#    'perfect pitch',
#    'absolute pitch',
#    'pitch-perfect'],
#   'derived_data': [{'word': 'pitch class'},
#    {'word': 'perfect pitch'},
#    {'word': 'pitch pipe'},
#    {'word': 'relative pitch'},
#    {'word': 'pitch-perfect'},
#    {'word': 'absolute pitch'}]},
#  {'pos': 'noun',
#   'priority': 3,
#   'categories': ['Magic: The Gathering', 'Gums and resins', 'Music'],
#   'topics': ['music', 'arts', 'media', 'publishing'],
#   'glosses': ['In an a cappella group, the singer responsible for singing a note for the other members to tune themselves by.'],
#   'sense_id': 'pitch-noun-ZTnmXpnB',
#   'form_of': ['pitches'],
#   'derived': ['relative pitch',
#    'pitch class',
#    'pitch pipe',
#    'perfect pitch',
#    'absolute pitch',
#    'pitch-perfect'],
#   'derived_data': [{'word': 'pitch class'},
#    {'word': 'perfect pitch'},
#    {'word': 'pitch pipe'},
#    {'word': 'relative pitch'},
#    {'word': 'pitch-perfect'},
#    {'word': 'absolute pitch'}]}]

# %%
word

# %%
exclude_keys = ['pos', 'word', 'lang', 'lang_code', 'derived','translations','_id','heads','sounds']
[
    {k:v for k,v in item.items() if k not in exclude_keys}
    for item in duplicated_words
]

# %%
[o['forms'] for o in duplicated_words]

# %% [markdown]
# ## create dict collection

# %%
all_words = query_words_by_key('pos')
len(all_words)
# Out:
# 1021124

# %%
repeated_dict = {}
for item in progress_bar(all_words):
    word = item['word']
    if repeated_dict.get(word) is None:
        repeated_dict[word] = [(item['_id'], item['pos'])]
    else:
        repeated_dict[word].append(
            (item['_id'], item['pos'])
        )
        
repeated_dict = {
    k:v
    for k,v in repeated_dict.items()
    if len(v) > 1
}
repeated_words = list(repeated_dict.keys())
len(repeated_words)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='1021124' class='' max='1021124' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [1021124/1021124 00:03<00:00]
#     </div>
# 57303

# %%
repeated_words = set(repeated_words)

# %%
len(repeated_words)
# Out:
# 57303

# %%
from datetime import datetime
from bson import ObjectId
def query_by_word(*words):
    return list(
    dict_col.find({
        'word':{
            '$in':words
        }
    },{
    k:1
    for k in words_keys
})
)

def get_date():
    return {
        'created_at':datetime.now(),
        'updated_at':datetime.now()
    }

# %%
# for item in progress_bar(all_words):
#     word = item['word'] 
#     is_multi = word in repeated_words
#     data = query_by_word(word)
#     for d in data:
#         d.pop('_id')
#     func = process_multi_words if is_multi else process_single_word
#     n_word,senses = func(
#         data if is_multi else data[0]
#     )
#     inserted_id = m_dict_col.insert_one({
#         **n_word,
#         **get_date()
#     }).inserted_id
    
#     m_sense_col.insert_many([
#         {**s, 'word_id':inserted_id, **get_date()}
#         for s in senses
#     ])
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='20' class='' max='20' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [20/20 00:19<00:00]
#     </div>

# %%
all_res_senses = []
def insert_data(words,senses):
#     global all_res_senses
#     all_res_senses += senses
    m_dict_col.insert_many([{
        **word,
        **get_date()
    }
        for word in words
    ])
    
    m_sense_col.insert_many([
        {**s, **get_date()}
        for s in senses
    ])

def handle_multi_single(word_datas):
    """
    [{},{}]
    """
    all_senses = []
    all_words = []
    for word in word_datas:
        wd,senses = process_single_word(word)
        all_words.append(wd)
        all_senses += senses
    return all_words, all_senses
    
def handle_multi_multi(word_datas):
    dic = {}
    for data in word_datas:
        if dic.get(data['word']) is None:
            dic[data['word']] = [data]
        else:
            dic[data['word']].append(data)
    all_senses = []
    all_words = []
    for words in dic.values():
        word, senses = process_multi_words(words)
        all_words.append(word)
        all_senses += senses
    return all_words, all_senses
    
def create_db(words):
    w_set = set(words)
    single_words = w_set.difference(repeated_words)
    multi_words = w_set.intersection(repeated_words)
    data = query_by_word(*w_set)
    for d in data:
        d.pop('_id')
    s_word_data = [
        d
        for d in data
        if d['word'] in single_words
    ]
    m_word_data = [
        d
        for d in data
        if d['word'] in multi_words
    ]
#     print(len(s_word_data),len(m_word_data),s_word_data, m_word_data)
    w1s,s1s = handle_multi_single(s_word_data)
    w2s, s2s = handle_multi_multi(m_word_data)
    insert_data(
        [*w1s,*w2s],
        [*s1s,*s2s]
    )

# %%
import math
def chunk_data(data, bs=10):
    sz =math.floor(len(data)/bs)
    res = []
    for i in range(bs):
        block = data[sz*i : sz*(i+1)] if i != bs-1 else data[sz*i :] 
        res.append(block)
    
    return res

# %%
m_dict_col.delete_many({})
m_sense_col.delete_many({})

# %%
pure_words = list(set(o['word'] for o in all_words))
len(pure_words)
# Out:
# 952502

# %%
bs=500
chunked = chunk_data(pure_words,bs=bs)
for words in progress_bar(chunked):
    create_db(words)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='500' class='' max='500' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [500/500 13:52<00:00]
#     </div>
